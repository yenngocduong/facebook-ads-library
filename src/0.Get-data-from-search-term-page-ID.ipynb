# %%
import requests, re, pandas as pd, numpy as np
from itertools import product
from bs4 import BeautifulSoup as bs
from scipy import stats
import pandas as pd
import numpy as np
from datetime import datetime
from xgboost import XGBClassifier, XGBRegressor

# %%
# ACCESS_TOKEN = 'EAAEau61SMogBAO4Lp0pJaYlJzc67wTychUcwF6gdpLWlet5TqpwnB6k6u0v8DuVAWFaMGO09CQlA7GoOjJnJzTdwzTCO2ZBtCQO721V5U1Qjy5vb7pZCEBC2N5AZAbzVWVYylg1bZCSehy28TTJP7QntMgpxGhD5einLmDxUz3pFfYHPmi47'
ACCESS_TOKEN = 'EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK'
def request(method='GET', full_url='', resource='', q={}):
    """
    resource: Endpoint on FB Graph API
    q: Access Token, Parameters and Fields according to FB Graph API documentation for specified endpoint
    """
    response = None
    if method == 'GET':
        if full_url:
            response = requests.get(full_url)
        if resource:
            response = requests.get(f'https://graph.facebook.com/v13.0/{resource}', q)
        if response.status_code==400:
            print(f'Error Status Code 400 for URL: {response.url}')
            return response
    return response.json()


def read_endpoint(id_, endpoint, access_token, fields=[], params={}, n=1000000):
    """
    read any endpoint for Facebook Graph API
    
    id_: identifier for any of Business, Account, Campaign, Ad Set, Ad, Creative, Ad Image, Ad Library
    endpoint: endpoint for any of the above according to Facebook Graph API
    access_token: required for usage of Facebook Graph API
    fields: fields to be read for the specified endpoint
    params: parameters to be passed for the specified endpoint
    n: number of desired results to be returned
    """
    q = dict({'access_token': access_token, 'fields': ','.join(fields)}, **params)
    if id_ == '':
        response = request(method='GET', resource=endpoint, q=q)
    else:
        response = request(method='GET', resource=f'{id_}/{endpoint}', q=q)
    if endpoint == '':
        return response
    
    data = []
    while True:
        try:
            data.extend(response['data'])
            if 'next' not in response['paging'].keys():
                break
            if len(data) >= n:
                break
            response = request(method='GET', full_url=response['paging']['next'])
        except Exception as e:
            break # not accessible
    return data

# %%
# fields available to read as defined by documentation
FIELDS = ['id','ad_creation_time','ad_delivery_start_time','ad_delivery_stop_time',
          'ad_snapshot_url','ad_creative_bodies','ad_creative_link_captions','ad_creative_link_titles','ad_creative_link_descriptions',
          'languages',
          'page_id','page_name','bylines','currency','spend','impressions','estimated_audience_size','publisher_platforms',
          'demographic_distribution','delivery_by_region']

# %%
def obtain_ads_page_name(search_term, country, fields, access_token):
    """
    a function to obtain ads from Ad Library based on given 'search_page_ids' and 'country'
    """
    params = {'search_terms': search_term,
              'search_type': 'KEYWORD_UNORDERED',
              'ad_active_status': 'ALL',
              'ad_reached_countries': [country]}
    
    ads = read_endpoint('', 'ads_archive', access_token, fields, params, 30000)
    
    for ad in ads: # add additional information
#         ad['search_page_ids'] = page_id 
        ad['topic'] = search_term 
        ad['country'] = country
    return ads

def obtain_ads_page_id(page_id, country, fields, access_token):
    """
    a function to obtain ads from Ad Library based on given 'search_page_ids' and 'country'
    """
    params = {'search_page_ids': page_id,
              'media_type': 'IMAGE',
              'ad_active_status': 'ALL',
              'ad_reached_countries': [country]}
    
    ads = read_endpoint('', 'ads_archive', access_token, fields, params, 30000)
    
    for ad in ads: # add additional information
        ad['search_page_ids'] = page_id 
        ad['country'] = country
    return ads

# %%
page_id_list_us = pd.read_csv('Y:/Internship/SoMin/Notebook/report/US-90-days.csv')
page_id_list_us.columns = ['page_id', 'page_name', 'disclaimer', 'amount_spent', 'number_of_ads']

page_id_list_br = pd.read_csv('Y:/Internship/SoMin/Notebook/report/BR-90-days.csv')
page_id_list_br.columns = ['page_id', 'page_name', 'disclaimer', 'amount_spent', 'number_of_ads']

page_id_list_gb = pd.read_csv('Y:/Internship/SoMin/Notebook/report/GB-90-days.csv')
page_id_list_gb.columns = ['page_id', 'page_name', 'disclaimer', 'amount_spent', 'number_of_ads']

# %%
page_id_list_us
# Out:
#                page_id                                        page_name  \
# 0      342294162453301                               Planned Parenthood
# 1      101828156534504                                       He Gets Us
# 2      102558898865449                           Don't Break What Works
# 3          87186661244  Johns Hopkins Bloomberg School of Public Health
# 4      134498556891640                                      Val Demings
# ...                ...                                              ...
# 17750  107274941522892                 East Feliciana Parish Local News
# 17751  102639252017167                         Warren County Local News
# 17752  163295937031815                                         Linh Nga
# 17753  107185384889782                           Winn Parish Local News
# 17754  100571402198653                             Nome Census Area, AK
#
#                                             disclaimer amount_spent  \
# 0             Planned Parenthood Federation of America      1585113
# 1                                       He Gets Us LLC       983154
# 2       COMPUTER & COMMUNICATIONS INDUSTRY ASSOCIATION       894552
# 3      Johns Hopkins Bloomberg School of Public Health       813164
# 4                          Val Demings for U.S. Senate       803990
# ...                                                ...          ...
# 17750               These ads ran without a disclaimer         ≤100
# 17751               These ads ran without a disclaimer         ≤100
# 17752               These ads ran without a disclaimer         ≤100
# 17753               These ads ran without a disclaimer         ≤100
# 17754               These ads ran without a disclaimer         ≤100
#
#        number_of_ads
# 0               1594
# 1                765
# 2                318
# 3                159
# 4                466
# ...              ...
# 17750              1
# 17751              1
# 17752              1
# 17753              1
# 17754              1
#
# [17755 rows x 5 columns]

# %%
page_id_list_br
# Out:
#                page_id          page_name  \
# 0      301774903545521    Brasil Paralelo
# 1      250792278286894       Simone Tebet
# 2      106558185227603          BP Select
# 3         159103797542  Greenpeace Brasil
# 4      411754008869486        Aécio Neves
# ...                ...                ...
# 11074  110904727326591      Search engine
# 11075  210181875766647    Mums in Science
# 11076  536483479771472        Danielzinho
# 11077  163050077800523     Ricardo Rangel
# 11078  784921801646396     Szymon Mierzwa
#
#                                           disclaimer amount_spent  \
# 0                                    Brasil Paralelo      2134607
# 1                   MOVIMENTO DEMOCRÁTICO BRASILEIRO       491596
# 2      Brasil Paralelo Entretenimento e Educação S/A       404418
# 3                                  Greenpeace Brasil       246796
# 4                                        Aécio Neves       184352
# ...                                              ...          ...
# 11074             These ads ran without a disclaimer         ≤100
# 11075             These ads ran without a disclaimer         ≤100
# 11076                           Daniel Silva De Lima         ≤100
# 11077             These ads ran without a disclaimer         ≤100
# 11078             These ads ran without a disclaimer         ≤100
#
#        number_of_ads
# 0               7510
# 1                 62
# 2               1032
# 3                326
# 4                 62
# ...              ...
# 11074              1
# 11075              1
# 11076              1
# 11077              1
# 11078              1
#
# [11079 rows x 5 columns]

# %%
page_id_list_gb
# Out:
#               page_id                                  page_name  \
# 0        311627208673                                     WWF UK
# 1         26698813123                          British Red Cross
# 2          7715002593                                  UNICEF UK
# 3     408582579294175                              UK government
# 4          9250349228                              Greenpeace UK
# ...               ...                                        ...
# 7453  111329294516219            United Kingdom News - NewsBreak
# 7454  233022620980830                              Ebrahim Sheik
# 7455  104124844567177                            The Urban Foxes
# 7456  110018661651101  Leadership Focus International Initiative
# 7457  101835809118348                   The Better Deal Alliance
#
#                               disclaimer amount_spent  number_of_ads
# 0                                 WWF UK       586511            978
# 1                      British Red Cross       471366            174
# 2                              Unicef UK       441495            124
# 3                          UK Government       415960            153
# 4                             Greenpeace       327378           1149
# ...                                  ...          ...            ...
# 7453  These ads ran without a disclaimer         ≤100              1
# 7454  These ads ran without a disclaimer         ≤100              1
# 7455  These ads ran without a disclaimer         ≤100              1
# 7456  These ads ran without a disclaimer         ≤100              1
# 7457  These ads ran without a disclaimer         ≤100              1
#
# [7458 rows x 5 columns]

# %%
page_id_us = page_id_list_us['page_id']
page_id_us = np.unique(page_id_us)[1:]

page_id_br = page_id_list_br['page_id']
page_id_br = np.unique(page_id_br)[1:]

page_id_gb = page_id_list_gb['page_id']
page_id_gb = np.unique(page_id_gb)[1:]

# %%
page_name_us = page_id_list_us['page_name']
page_name_us = np.unique(page_name_us)[1:]

page_name_br = page_id_list_br['page_name']
page_name_br = np.unique(page_name_br)[1:]

page_name_gb = page_id_list_gb['page_name']
page_name_gb = np.unique(page_name_gb)[1:]

# %%
print('US:', len(page_id_us))
print('BR:', len(page_id_br))
print('GB:', len(page_id_gb))
# Out:
# US: 16950
# BR: 9726
# GB: 6853

# %%
print('US:', len(page_name_us))
print('US:', len(page_name_br))
print('US:', len(page_name_gb))
# Out:
# US: 17257
# US: 10443
# US: 7050

# %%
for i in range(len(page_name_us)):
    page_name_us[i] = page_name_us[i].replace(' ', '-')

for i in range(len(page_name_br)):
    page_name_br[i] = page_name_br[i].replace(' ', '-')

for i in range(len(page_name_gb)):
    page_name_gb[i] = page_name_gb[i].replace(' ', '-')

# %%
name = page_name_us[0]
id = page_id_us[0]

# %%
ads = obtain_ads_page_name(name, 'US', FIELDS, ACCESS_TOKEN)
print(len(ads))
# Out:
# 90

# %%
ads2 = obtain_ads_page_id(id, 'US', FIELDS, ACCESS_TOKEN)
print(len(ads2))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-be10467609a1> in <module>
# ----> 1 ads2 = obtain_ads_page_id(id, 'US', FIELDS, ACCESS_TOKEN)
#       2 print(len(ads2))
#
# <ipython-input-4-922b3e71c49e> in obtain_ads_page_id(page_id, country, fields, access_token)
#      25               'ad_reached_countries': [country]}
#      26
# ---> 27     ads = read_endpoint('', 'ads_archive', access_token, fields, params, 30000)
#      28
#      29     for ad in ads: # add additional information
#
# <ipython-input-2-245143b61514> in read_endpoint(id_, endpoint, access_token, fields, params, n)
#      45             if len(data) >= n:
#      46                 break
# ---> 47             response = request(method='GET', full_url=response['paging']['next'])
#      48         except Exception as e:
#      49             break # not accessible
#
# <ipython-input-2-245143b61514> in request(method, full_url, resource, q)
#       9     if method == 'GET':
#      10         if full_url:
# ---> 11             response = requests.get(full_url)
#      12         if resource:
#      13             response = requests.get(f'https://graph.facebook.com/v13.0/{resource}', q)
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
page_id_us
# Out:
# array([       5435784683,        5633824547,        5634829153, ...,
#        10150127026615249, 10150132207935252, 10150157803280161],
#       dtype=int64)

# %%
import os
import pickle
from datetime import datetime
def ensure_folder_exists(folder_path):
    """
    Creates the specified folder if it does not already exist
    """
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)


def load_pickle(file_path):
    """
    Loads a pickle from the file system
    """
    return pickle.load(open(file_path, 'rb')) if os.path.isfile(file_path) else None


def save_pickle(file_path, data):
    """
    Saves the specified object as a pickle to the file system
    """
    with open(file_path, 'wb') as f:
        pickle.dump(data, f)

raw_dir = f'Y:/Internship/SoMin/Notebook/raw/{str(datetime.today().date()).replace("-","")}'
if not os.path.exists(raw_dir):
    os.makedirs(raw_dir)

# %% [markdown]
# # Great Britain

# %%
from itertools import product
# countries = ['US', 'GB', 'BR'] # all available countries for now
# themes = ['ad-tech','ed-tech','agri-tech','fin-tech','bio-tech','health-tech','electric-vehicles','clean-energy',
#           'cloud-computing','quantum-computing','artificial-intelligence','machine-learning','digital-assets',
#           'virtual-reality','cyber-security','software','social-trends','analytics']

all_ads = []
i = 0
for ct in product(page_id_gb, ['GB']):
    if i%100 == 0:
        print(f'Saving ..... batch {i//100}, current id: {i}')
        save_pickle(f'{raw_dir}/adlibrary_ads_gb_90_days_{i//1000}.pkl', all_ads)
        if i%1000 == 0:
            all_ads = []
    print(f'Retrieving Ads for: {ct}, number {i}')
    try:
        ads = obtain_ads_page_id(ct[0], ct[1], FIELDS, ACCESS_TOKEN)
        print('\t', len(ads), 'ads')
        all_ads.extend(ads)
        i+=1
    except Exception as e:
        print('Some error happened:', e)
        
save_pickle(f'{raw_dir}/adlibrary_ads_gb_90_days_{i//1000}.pkl', all_ads)
print(f'Retrieved {len(all_ads)} ads')
# Out:
# Saving ..... batch 0, current id: 0
# Retrieving Ads for: (5647744585, 'GB'), number 0
# 	 0 ads
# Retrieving Ads for: (5662929773, 'GB'), number 1
# 	 11 ads
# Retrieving Ads for: (5740844431, 'GB'), number 2
# 	 3 ads
# Retrieving Ads for: (5883973269, 'GB'), number 3
# 	 786 ads
# Retrieving Ads for: (5938132369, 'GB'), number 4
# 	 6 ads
# Retrieving Ads for: (6040534532, 'GB'), number 5
# 	 0 ads
# Retrieving Ads for: (6080640749, 'GB'), number 6
# 	 0 ads
# Retrieving Ads for: (6115848166, 'GB'), number 7
# 	 3 ads
# Retrieving Ads for: (6149699161, 'GB'), number 8
# 	 0 ads
# Retrieving Ads for: (6162236025, 'GB'), number 9
# 	 2 ads
# Retrieving Ads for: (6233536938, 'GB'), number 10
# 	 251 ads
# Retrieving Ads for: (6321018343, 'GB'), number 11
# 	 1 ads
# Retrieving Ads for: (6366026879, 'GB'), number 12
# 	 169 ads
# Retrieving Ads for: (6406164817, 'GB'), number 13
# 	 3 ads
# Retrieving Ads for: (6447117653, 'GB'), number 14
# 	 1267 ads
# Retrieving Ads for: (6574632957, 'GB'), number 15
# 	 8 ads
# Retrieving Ads for: (6587671199, 'GB'), number 16
# 	 31 ads
# Retrieving Ads for: (6707857033, 'GB'), number 17
# 	 930 ads
# Retrieving Ads for: (6708565748, 'GB'), number 18
# 	 24 ads
# Retrieving Ads for: (6808928485, 'GB'), number 19
# 	 29 ads
# Retrieving Ads for: (6940543981, 'GB'), number 20
# 	 0 ads
# Retrieving Ads for: (7043497714, 'GB'), number 21
# 	 126 ads
# Retrieving Ads for: (7214031395, 'GB'), number 22
# 	 14 ads
# Retrieving Ads for: (7268844551, 'GB'), number 23
# 	 2 ads
# Retrieving Ads for: (7302298100, 'GB'), number 24
# 	 0 ads
# Retrieving Ads for: (7382473689, 'GB'), number 25
# 	 7 ads
# Retrieving Ads for: (7383655823, 'GB'), number 26
# 	 30 ads
# Retrieving Ads for: (7419863487, 'GB'), number 27
# 	 17 ads
# Retrieving Ads for: (7527864602, 'GB'), number 28
# 	 427 ads
# Retrieving Ads for: (7569385657, 'GB'), number 29
# 	 48 ads
# Retrieving Ads for: (7619396355, 'GB'), number 30
# 	 0 ads
# Retrieving Ads for: (7624294394, 'GB'), number 31
# 	 3714 ads
# Retrieving Ads for: (7715002593, 'GB'), number 32
# 	 171 ads
# Retrieving Ads for: (7724542745, 'GB'), number 33
# 	 0 ads
# Retrieving Ads for: (7783116506, 'GB'), number 34
# 	 0 ads
# Retrieving Ads for: (7812277551, 'GB'), number 35
# 	 0 ads
# Retrieving Ads for: (7950759473, 'GB'), number 36
# 	 46 ads
# Retrieving Ads for: (8038902385, 'GB'), number 37
# 	 0 ads
# Retrieving Ads for: (8126393663, 'GB'), number 38
# 	 2 ads
# Retrieving Ads for: (8303218826, 'GB'), number 39
# 	 2 ads
# Retrieving Ads for: (8403816082, 'GB'), number 40
# 	 1 ads
# Retrieving Ads for: (8422578815, 'GB'), number 41
# 	 149 ads
# Retrieving Ads for: (8529136956, 'GB'), number 42
# 	 0 ads
# Retrieving Ads for: (8539814909, 'GB'), number 43
# 	 11 ads
# Retrieving Ads for: (8555757947, 'GB'), number 44
# 	 188 ads
# Retrieving Ads for: (8579062138, 'GB'), number 45
# 	 0 ads
# Retrieving Ads for: (8751993250, 'GB'), number 46
# 	 0 ads
# Retrieving Ads for: (8807334278, 'GB'), number 47
# 	 927 ads
# Retrieving Ads for: (8823630291, 'GB'), number 48
# 	 1 ads
# Retrieving Ads for: (8876787713, 'GB'), number 49
# 	 23 ads
# Retrieving Ads for: (8888079365, 'GB'), number 50
# 	 0 ads
# Retrieving Ads for: (8922464791, 'GB'), number 51
# 	 0 ads
# Retrieving Ads for: (9165824802, 'GB'), number 52
# 	 6 ads
# Retrieving Ads for: (9179830029, 'GB'), number 53
# 	 10 ads
# Retrieving Ads for: (9250349228, 'GB'), number 54
# 	 734 ads
# Retrieving Ads for: (9335029293, 'GB'), number 55
# 	 0 ads
# Retrieving Ads for: (10114144851, 'GB'), number 56
# 	 91 ads
# Retrieving Ads for: (10130470307, 'GB'), number 57
# 	 0 ads
# Retrieving Ads for: (10137900905, 'GB'), number 58
# 	 0 ads
# Retrieving Ads for: (10261403667, 'GB'), number 59
# 	 0 ads
# Retrieving Ads for: (10349463618, 'GB'), number 60
# 	 0 ads
# Retrieving Ads for: (10499876484, 'GB'), number 61
# 	 220 ads
# Retrieving Ads for: (10642639740, 'GB'), number 62
# 	 1 ads
# Retrieving Ads for: (10677003998, 'GB'), number 63
# 	 812 ads
# Retrieving Ads for: (10750083165, 'GB'), number 64
# 	 7 ads
# Retrieving Ads for: (11055104471, 'GB'), number 65
# 	 76 ads
# Retrieving Ads for: (11514518991, 'GB'), number 66
# 	 0 ads
# Retrieving Ads for: (11648177940, 'GB'), number 67
# 	 1 ads
# Retrieving Ads for: (11871609276, 'GB'), number 68
# 	 3 ads
# Retrieving Ads for: (11918108948, 'GB'), number 69
# 	 0 ads
# Retrieving Ads for: (11936918897, 'GB'), number 70
# 	 0 ads
# Retrieving Ads for: (11949538375, 'GB'), number 71
# 	 94 ads
# Retrieving Ads for: (11965205188, 'GB'), number 72
# 	 486 ads
# Retrieving Ads for: (12197920687, 'GB'), number 73
# 	 1 ads
# Retrieving Ads for: (12664262806, 'GB'), number 74
# 	 0 ads
# Retrieving Ads for: (13047522725, 'GB'), number 75
# 	 34 ads
# Retrieving Ads for: (13467389881, 'GB'), number 76
# 	 0 ads
# Retrieving Ads for: (13533633585, 'GB'), number 77
# 	 19 ads
# Retrieving Ads for: (13655260370, 'GB'), number 78
# 	 13 ads
# Retrieving Ads for: (13664477226, 'GB'), number 79
# 	 0 ads
# Retrieving Ads for: (13695746395, 'GB'), number 80
# 	 10 ads
# Retrieving Ads for: (14011689941, 'GB'), number 81
# 	 11 ads
# Retrieving Ads for: (14027365105, 'GB'), number 82
# 	 2 ads
# Retrieving Ads for: (14199013140, 'GB'), number 83
# 	 0 ads
# Retrieving Ads for: (14676447483, 'GB'), number 84
# 	 4 ads
# Retrieving Ads for: (15456537827, 'GB'), number 85
# 	 0 ads
# Retrieving Ads for: (15713980389, 'GB'), number 86
# 	 0 ads
# Retrieving Ads for: (15804222978, 'GB'), number 87
# 	 0 ads
# Retrieving Ads for: (15974534830, 'GB'), number 88
# 	 5 ads
# Retrieving Ads for: (16340868161, 'GB'), number 89
# 	 0 ads
# Retrieving Ads for: (16352623251, 'GB'), number 90
# 	 1 ads
# Retrieving Ads for: (16553417732, 'GB'), number 91
# 	 14 ads
# Retrieving Ads for: (16779918934, 'GB'), number 92
# 	 8 ads
# Retrieving Ads for: (17043549797, 'GB'), number 93
# 	 1 ads
# Retrieving Ads for: (17050705902, 'GB'), number 94
# 	 1 ads
# Retrieving Ads for: (17999726169, 'GB'), number 95
# 	 8 ads
# Retrieving Ads for: (18044497940, 'GB'), number 96
# 	 1212 ads
# Retrieving Ads for: (18135444535, 'GB'), number 97
# 	 10 ads
# Retrieving Ads for: (18168505158, 'GB'), number 98
# 	 239 ads
# Retrieving Ads for: (18366996074, 'GB'), number 99
# 	 387 ads
# Saving ..... batch 1, current id: 100
# Retrieving Ads for: (18933154958, 'GB'), number 100
# 	 92 ads
# Retrieving Ads for: (18933990398, 'GB'), number 101
# 	 308 ads
# Retrieving Ads for: (19097243336, 'GB'), number 102
# 	 23 ads
# Retrieving Ads for: (19106912829, 'GB'), number 103
# 	 0 ads
# Retrieving Ads for: (19110072263, 'GB'), number 104
# 	 51 ads
# Retrieving Ads for: (19308292644, 'GB'), number 105
# 	 2 ads
# Retrieving Ads for: (19895907944, 'GB'), number 106
# 	 31 ads
# Retrieving Ads for: (20101645677, 'GB'), number 107
# 	 1 ads
# Retrieving Ads for: (20298641808, 'GB'), number 108
# 	 2 ads
# Retrieving Ads for: (20329664449, 'GB'), number 109
# 	 0 ads
# Retrieving Ads for: (20374426684, 'GB'), number 110
# 	 8 ads
# Retrieving Ads for: (20550602416, 'GB'), number 111
# 	 6 ads
# Retrieving Ads for: (20583485166, 'GB'), number 112
# 	 0 ads
# Retrieving Ads for: (20665390582, 'GB'), number 113
# 	 394 ads
# Retrieving Ads for: (20781959145, 'GB'), number 114
# 	 0 ads
# Retrieving Ads for: (20795833032, 'GB'), number 115
# 	 1 ads
# Retrieving Ads for: (20892109576, 'GB'), number 116
# 	 1 ads
# Retrieving Ads for: (21019330647, 'GB'), number 117
# 	 155 ads
# Retrieving Ads for: (21038623537, 'GB'), number 118
# 	 0 ads
# Retrieving Ads for: (21242962092, 'GB'), number 119
# 	 174 ads
# Retrieving Ads for: (21251598643, 'GB'), number 120
# 	 14 ads
# Retrieving Ads for: (21506277966, 'GB'), number 121
# 	 0 ads
# Retrieving Ads for: (21517406388, 'GB'), number 122
# 	 11 ads
# Retrieving Ads for: (21591025194, 'GB'), number 123
# 	 0 ads
# Retrieving Ads for: (22550274088, 'GB'), number 124
# 	 0 ads
# Retrieving Ads for: (22951843398, 'GB'), number 125
# 	 0 ads
# Retrieving Ads for: (23565920773, 'GB'), number 126
# 	 0 ads
# Retrieving Ads for: (23661818476, 'GB'), number 127
# 	 9 ads
# Retrieving Ads for: (23820609833, 'GB'), number 128
# 	 1 ads
# Retrieving Ads for: (23965992328, 'GB'), number 129
# 	 30 ads
# Retrieving Ads for: (24287259392, 'GB'), number 130
# 	 1 ads
# Retrieving Ads for: (24303679841, 'GB'), number 131
# 	 0 ads
# Retrieving Ads for: (24496278123, 'GB'), number 132
# 	 8 ads
# Retrieving Ads for: (25010947137, 'GB'), number 133
# 	 21 ads
# Retrieving Ads for: (25348768148, 'GB'), number 134
# 	 0 ads
# Retrieving Ads for: (25749647410, 'GB'), number 135
# 	 650 ads
# Retrieving Ads for: (25852730092, 'GB'), number 136
# 	 5 ads
# Retrieving Ads for: (25919404073, 'GB'), number 137
# 	 17 ads
# Retrieving Ads for: (26416930992, 'GB'), number 138
# 	 22 ads
# Retrieving Ads for: (26698813123, 'GB'), number 139
# 	 802 ads
# Retrieving Ads for: (26806660922, 'GB'), number 140
# 	 12 ads
# Retrieving Ads for: (27560776046, 'GB'), number 141
# 	 0 ads
# Retrieving Ads for: (27678194634, 'GB'), number 142
# 	 2 ads
# Retrieving Ads for: (27770740767, 'GB'), number 143
# 	 0 ads
# Retrieving Ads for: (28748279914, 'GB'), number 144
# 	 0 ads
# Retrieving Ads for: (28750720737, 'GB'), number 145
# 	 5 ads
# Retrieving Ads for: (28928259418, 'GB'), number 146
# 	 0 ads
# Retrieving Ads for: (29261542197, 'GB'), number 147
# 	 12 ads
# Retrieving Ads for: (29952518646, 'GB'), number 148
# 	 0 ads
# Retrieving Ads for: (30028422818, 'GB'), number 149
# 	 0 ads
# Retrieving Ads for: (30100671591, 'GB'), number 150
# 	 0 ads
# Retrieving Ads for: (30394579038, 'GB'), number 151
# 	 0 ads
# Retrieving Ads for: (30601448467, 'GB'), number 152
# 	 0 ads
# Retrieving Ads for: (30651387304, 'GB'), number 153
# 	 0 ads
# Retrieving Ads for: (30661956224, 'GB'), number 154
# 	 1 ads
# Retrieving Ads for: (30664112362, 'GB'), number 155
# 	 0 ads
# Retrieving Ads for: (31121558686, 'GB'), number 156
# 	 2 ads
# Retrieving Ads for: (31292782350, 'GB'), number 157
# 	 9 ads
# Retrieving Ads for: (31722189824, 'GB'), number 158
# 	 1 ads
# Retrieving Ads for: (32514078659, 'GB'), number 159
# 	 476 ads
# Retrieving Ads for: (32954031974, 'GB'), number 160
# 	 0 ads
# Retrieving Ads for: (33130879085, 'GB'), number 161
# 	 3 ads
# Retrieving Ads for: (33268280976, 'GB'), number 162
# 	 8 ads
# Retrieving Ads for: (33448039733, 'GB'), number 163
# 	 0 ads
# Retrieving Ads for: (33497111948, 'GB'), number 164
# 	 0 ads
# Retrieving Ads for: (33942762466, 'GB'), number 165
# 	 0 ads
# Retrieving Ads for: (34042575517, 'GB'), number 166
# 	 2 ads
# Retrieving Ads for: (34044296391, 'GB'), number 167
# 	 197 ads
# Retrieving Ads for: (34341434454, 'GB'), number 168
# 	 10 ads
# Retrieving Ads for: (34816872973, 'GB'), number 169
# 	 0 ads
# Retrieving Ads for: (34994060032, 'GB'), number 170
# 	 1 ads
# Retrieving Ads for: (35671127597, 'GB'), number 171
# 	 0 ads
# Retrieving Ads for: (35671512696, 'GB'), number 172
# 	 157 ads
# Retrieving Ads for: (35731175856, 'GB'), number 173
# 	 0 ads
# Retrieving Ads for: (36082185007, 'GB'), number 174
# 	 2 ads
# Retrieving Ads for: (37117884425, 'GB'), number 175
# 	 19 ads
# Retrieving Ads for: (37166654192, 'GB'), number 176
# 	 0 ads
# Retrieving Ads for: (37673001601, 'GB'), number 177
# 	 0 ads
# Retrieving Ads for: (37981137361, 'GB'), number 178
# 	 608 ads
# Retrieving Ads for: (38347172398, 'GB'), number 179
# 	 0 ads
# Retrieving Ads for: (38877517657, 'GB'), number 180
# 	 28 ads
# Retrieving Ads for: (39556650565, 'GB'), number 181
# 	 75 ads
# Retrieving Ads for: (39605200520, 'GB'), number 182
# 	 1175 ads
# Retrieving Ads for: (40409120801, 'GB'), number 183
# 	 402 ads
# Retrieving Ads for: (40526249862, 'GB'), number 184
# 	 0 ads
# Retrieving Ads for: (40952091012, 'GB'), number 185
# 	 8 ads
# Retrieving Ads for: (41819722370, 'GB'), number 186
# 	 16 ads
# Retrieving Ads for: (41883361077, 'GB'), number 187
# 	 1 ads
# Retrieving Ads for: (42553600437, 'GB'), number 188
# 	 1 ads
# Retrieving Ads for: (42614454723, 'GB'), number 189
# 	 0 ads
# Retrieving Ads for: (42940254353, 'GB'), number 190
# 	 0 ads
# Retrieving Ads for: (43670248927, 'GB'), number 191
# 	 0 ads
# Retrieving Ads for: (43726922006, 'GB'), number 192
# 	 0 ads
# Retrieving Ads for: (43934405787, 'GB'), number 193
# 	 2 ads
# Retrieving Ads for: (43979526193, 'GB'), number 194
# 	 0 ads
# Retrieving Ads for: (44916667198, 'GB'), number 195
# 	 0 ads
# Retrieving Ads for: (45093379305, 'GB'), number 196
# 	 3 ads
# Retrieving Ads for: (45599299724, 'GB'), number 197
# 	 0 ads
# Retrieving Ads for: (45628695543, 'GB'), number 198
# 	 0 ads
# Retrieving Ads for: (45651091362, 'GB'), number 199
# 	 0 ads
# Saving ..... batch 2, current id: 200
# Retrieving Ads for: (45665414353, 'GB'), number 200
# 	 5 ads
# Retrieving Ads for: (46074836918, 'GB'), number 201
# 	 0 ads
# Retrieving Ads for: (46852258376, 'GB'), number 202
# 	 123 ads
# Retrieving Ads for: (47315397761, 'GB'), number 203
# 	 1 ads
# Retrieving Ads for: (47393489592, 'GB'), number 204
# 	 1 ads
# Retrieving Ads for: (47496679743, 'GB'), number 205
# 	 25 ads
# Retrieving Ads for: (47608130833, 'GB'), number 206
# 	 0 ads
# Retrieving Ads for: (47612991154, 'GB'), number 207
# 	 571 ads
# Retrieving Ads for: (47710652725, 'GB'), number 208
# 	 0 ads
# Retrieving Ads for: (48243507113, 'GB'), number 209
# 	 12 ads
# Retrieving Ads for: (48904400776, 'GB'), number 210
# 	 0 ads
# Retrieving Ads for: (48933285145, 'GB'), number 211
# 	 3 ads
# Retrieving Ads for: (49275915266, 'GB'), number 212
# 	 9 ads
# Retrieving Ads for: (49554048662, 'GB'), number 213
# 	 9 ads
# Retrieving Ads for: (49906865946, 'GB'), number 214
# 	 0 ads
# Retrieving Ads for: (50665971607, 'GB'), number 215
# 	 0 ads
# Retrieving Ads for: (51006491121, 'GB'), number 216
# 	 3 ads
# Retrieving Ads for: (52060705433, 'GB'), number 217
# 	 0 ads
# Retrieving Ads for: (52738181995, 'GB'), number 218
# 	 2 ads
# Retrieving Ads for: (53695835063, 'GB'), number 219
# 	 0 ads
# Retrieving Ads for: (54265089285, 'GB'), number 220
# 	 0 ads
# Retrieving Ads for: (54605029793, 'GB'), number 221
# 	 1 ads
# Retrieving Ads for: (54869840070, 'GB'), number 222
# 	 10 ads
# Retrieving Ads for: (54981101925, 'GB'), number 223
# 	 1 ads
# Retrieving Ads for: (55165122777, 'GB'), number 224
# 	 0 ads
# Retrieving Ads for: (55275672093, 'GB'), number 225
# 	 7 ads
# Retrieving Ads for: (55405987352, 'GB'), number 226
# 	 0 ads
# Retrieving Ads for: (55984857501, 'GB'), number 227
# 	 59 ads
# Retrieving Ads for: (56548182258, 'GB'), number 228
# 	 0 ads
# Retrieving Ads for: (56777943052, 'GB'), number 229
# 	 1 ads
# Retrieving Ads for: (56844830907, 'GB'), number 230
# 	 0 ads
# Retrieving Ads for: (57373793897, 'GB'), number 231
# 	 0 ads
# Retrieving Ads for: (58290604977, 'GB'), number 232
# 	 2 ads
# Retrieving Ads for: (59367068326, 'GB'), number 233
# 	 232 ads
# Retrieving Ads for: (61859997088, 'GB'), number 234
# 	 1 ads
# Retrieving Ads for: (61950489543, 'GB'), number 235
# 	 5 ads
# Retrieving Ads for: (63306224439, 'GB'), number 236
# 	 0 ads
# Retrieving Ads for: (63451405593, 'GB'), number 237
# 	 214 ads
# Retrieving Ads for: (64319383104, 'GB'), number 238
# 	 0 ads
# Retrieving Ads for: (64670453529, 'GB'), number 239
# 	 0 ads
# Retrieving Ads for: (64955332909, 'GB'), number 240
# 	 0 ads
# Retrieving Ads for: (65069115489, 'GB'), number 241
# 	 0 ads
# Retrieving Ads for: (66078591168, 'GB'), number 242
# 	 0 ads
# Retrieving Ads for: (66188945100, 'GB'), number 243
# 	 31 ads
# Retrieving Ads for: (66399762879, 'GB'), number 244
# 	 0 ads
# Retrieving Ads for: (67862815664, 'GB'), number 245
# 	 14 ads
# Retrieving Ads for: (67884984384, 'GB'), number 246
# 	 0 ads
# Retrieving Ads for: (68262948642, 'GB'), number 247
# 	 1 ads
# Retrieving Ads for: (68315632922, 'GB'), number 248
# 	 0 ads
# Retrieving Ads for: (68793499001, 'GB'), number 249
# 	 11 ads
# Retrieving Ads for: (68905458208, 'GB'), number 250
# 	 1 ads
# Retrieving Ads for: (69261051227, 'GB'), number 251
# 	 0 ads
# Retrieving Ads for: (69659999016, 'GB'), number 252
# 	 1 ads
# Retrieving Ads for: (70379958362, 'GB'), number 253
# 	 0 ads
# Retrieving Ads for: (70877580782, 'GB'), number 254
# 	 0 ads
# Retrieving Ads for: (71409503111, 'GB'), number 255
# 	 23 ads
# Retrieving Ads for: (72173293788, 'GB'), number 256
# 	 3 ads
# Retrieving Ads for: (72228529722, 'GB'), number 257
# 	 1 ads
# Retrieving Ads for: (72542290165, 'GB'), number 258
# 	 0 ads
# Retrieving Ads for: (72633666984, 'GB'), number 259
# 	 9 ads
# Retrieving Ads for: (72862798211, 'GB'), number 260
# 	 0 ads
# Retrieving Ads for: (73620441975, 'GB'), number 261
# 	 0 ads
# Retrieving Ads for: (73621126187, 'GB'), number 262
# 	 0 ads
# Retrieving Ads for: (75655742917, 'GB'), number 263
# 	 8 ads
# Retrieving Ads for: (75656822058, 'GB'), number 264
# 	 0 ads
# Retrieving Ads for: (76778808559, 'GB'), number 265
# 	 0 ads
# Retrieving Ads for: (76807881169, 'GB'), number 266
# 	 8 ads
# Retrieving Ads for: (77071765498, 'GB'), number 267
# 	 49 ads
# Retrieving Ads for: (77249349077, 'GB'), number 268
# 	 22 ads
# Retrieving Ads for: (77403447721, 'GB'), number 269
# 	 0 ads
# Retrieving Ads for: (77659749695, 'GB'), number 270
# 	 0 ads
# Retrieving Ads for: (77680316823, 'GB'), number 271
# 	 0 ads
# Retrieving Ads for: (77941253294, 'GB'), number 272
# 	 0 ads
# Retrieving Ads for: (78066290984, 'GB'), number 273
# 	 0 ads
# Retrieving Ads for: (78436661801, 'GB'), number 274
# 	 0 ads
# Retrieving Ads for: (78631091926, 'GB'), number 275
# 	 1 ads
# Retrieving Ads for: (79511407410, 'GB'), number 276
# 	 1 ads
# Retrieving Ads for: (80791482166, 'GB'), number 277
# 	 0 ads
# Retrieving Ads for: (81220709615, 'GB'), number 278
# 	 7 ads
# Retrieving Ads for: (81659621206, 'GB'), number 279
# 	 2 ads
# Retrieving Ads for: (81751285098, 'GB'), number 280
# 	 2 ads
# Retrieving Ads for: (83181195937, 'GB'), number 281
# 	 0 ads
# Retrieving Ads for: (84816113788, 'GB'), number 282
# 	 0 ads
# Retrieving Ads for: (85412112798, 'GB'), number 283
# 	 0 ads
# Retrieving Ads for: (85549822738, 'GB'), number 284
# 	 67 ads
# Retrieving Ads for: (85800829429, 'GB'), number 285
# 	 2 ads
# Retrieving Ads for: (86532198605, 'GB'), number 286
# 	 0 ads
# Retrieving Ads for: (86760241759, 'GB'), number 287
# 	 0 ads
# Retrieving Ads for: (87772838729, 'GB'), number 288
# 	 0 ads
# Retrieving Ads for: (87993564181, 'GB'), number 289
# 	 0 ads
# Retrieving Ads for: (88155763969, 'GB'), number 290
# 	 66 ads
# Retrieving Ads for: (88236679583, 'GB'), number 291
# 	 20 ads
# Retrieving Ads for: (88685707030, 'GB'), number 292
# 	 6 ads
# Retrieving Ads for: (88845925295, 'GB'), number 293
# 	 36 ads
# Retrieving Ads for: (89151782746, 'GB'), number 294
# 	 80 ads
# Retrieving Ads for: (89315678736, 'GB'), number 295
# 	 60 ads
# Retrieving Ads for: (89859403188, 'GB'), number 296
# 	 8 ads
# Retrieving Ads for: (91595289068, 'GB'), number 297
# 	 2 ads
# Retrieving Ads for: (91899893421, 'GB'), number 298
# 	 0 ads
# Retrieving Ads for: (91996682614, 'GB'), number 299
# 	 8 ads
# Saving ..... batch 3, current id: 300
# Retrieving Ads for: (92288319748, 'GB'), number 300
# 	 2 ads
# Retrieving Ads for: (92991708377, 'GB'), number 301
# 	 0 ads
# Retrieving Ads for: (94606675529, 'GB'), number 302
# 	 0 ads
# Retrieving Ads for: (94945123790, 'GB'), number 303
# 	 0 ads
# Retrieving Ads for: (95597922197, 'GB'), number 304
# 	 0 ads
# Retrieving Ads for: (95775573753, 'GB'), number 305
# 	 3 ads
# Retrieving Ads for: (95994239920, 'GB'), number 306
# 	 0 ads
# Retrieving Ads for: (96128889770, 'GB'), number 307
# 	 0 ads
# Retrieving Ads for: (96184651725, 'GB'), number 308
# 	 15 ads
# Retrieving Ads for: (96470993074, 'GB'), number 309
# 	 0 ads
# Retrieving Ads for: (97116898596, 'GB'), number 310
# 	 72 ads
# Retrieving Ads for: (97283538614, 'GB'), number 311
# 	 31 ads
# Retrieving Ads for: (97323256442, 'GB'), number 312
# 	 1 ads
# Retrieving Ads for: (97427310237, 'GB'), number 313
# 	 7 ads
# Retrieving Ads for: (97583546182, 'GB'), number 314
# 	 0 ads
# Retrieving Ads for: (97708339756, 'GB'), number 315
# 	 291 ads
# Retrieving Ads for: (97940337907, 'GB'), number 316
# 	 0 ads
# Retrieving Ads for: (97951440478, 'GB'), number 317
# 	 0 ads
# Retrieving Ads for: (97955320269, 'GB'), number 318
# 	 41 ads
# Retrieving Ads for: (98673036962, 'GB'), number 319
# 	 5 ads
# Retrieving Ads for: (99351789122, 'GB'), number 320
# 	 0 ads
# Retrieving Ads for: (99971523887, 'GB'), number 321
# 	 0 ads
# Retrieving Ads for: (100659091502, 'GB'), number 322
# 	 20 ads
# Retrieving Ads for: (100959719644, 'GB'), number 323
# 	 30 ads
# Retrieving Ads for: (101558386889, 'GB'), number 324
# 	 492 ads
# Retrieving Ads for: (102009642866, 'GB'), number 325
# 	 0 ads
# Retrieving Ads for: (102892417916, 'GB'), number 326
# 	 0 ads
# Retrieving Ads for: (103273814470, 'GB'), number 327
# 	 168 ads
# Retrieving Ads for: (103398468787, 'GB'), number 328
# 	 0 ads
# Retrieving Ads for: (103835971750, 'GB'), number 329
# 	 863 ads
# Retrieving Ads for: (105467477022, 'GB'), number 330
# 	 2 ads
# Retrieving Ads for: (105780677377, 'GB'), number 331
# 	 11 ads
# Retrieving Ads for: (106160005057, 'GB'), number 332
# 	 1 ads
# Retrieving Ads for: (106169896185, 'GB'), number 333
# 	 0 ads
# Retrieving Ads for: (106251878963, 'GB'), number 334
# 	 0 ads
# Retrieving Ads for: (106824832045, 'GB'), number 335
# 	 2 ads
# Retrieving Ads for: (106914875258, 'GB'), number 336
# 	 0 ads
# Retrieving Ads for: (107286223667, 'GB'), number 337
# 	 7 ads
# Retrieving Ads for: (107334993856, 'GB'), number 338
# 	 30 ads
# Retrieving Ads for: (107424993561, 'GB'), number 339
# 	 0 ads
# Retrieving Ads for: (107485499287, 'GB'), number 340
# 	 1596 ads
# Retrieving Ads for: (107584191543, 'GB'), number 341
# 	 0 ads
# Retrieving Ads for: (107716540019, 'GB'), number 342
# 	 0 ads
# Retrieving Ads for: (109169456059, 'GB'), number 343
# 	 0 ads
# Retrieving Ads for: (110205196570, 'GB'), number 344
# 	 0 ads
# Retrieving Ads for: (110784335387, 'GB'), number 345
# 	 0 ads
# Retrieving Ads for: (110900476454, 'GB'), number 346
# 	 0 ads
# Retrieving Ads for: (111064870140, 'GB'), number 347
# 	 2 ads
# Retrieving Ads for: (111361091313, 'GB'), number 348
# 	 0 ads
# Retrieving Ads for: (111654016067, 'GB'), number 349
# 	 10 ads
# Retrieving Ads for: (112845639376, 'GB'), number 350
# 	 3324 ads
# Retrieving Ads for: (113774459487, 'GB'), number 351
# 	 40 ads
# Retrieving Ads for: (114204346698, 'GB'), number 352
# 	 0 ads
# Retrieving Ads for: (114287484617, 'GB'), number 353
# 	 0 ads
# Retrieving Ads for: (114394640408, 'GB'), number 354
# 	 2 ads
# Retrieving Ads for: (115145985769, 'GB'), number 355
# 	 0 ads
# Retrieving Ads for: (115225703539, 'GB'), number 356
# 	 1 ads
# Retrieving Ads for: (115328583854, 'GB'), number 357
# 	 1 ads
# Retrieving Ads for: (115713518730, 'GB'), number 358
# 	 39 ads
# Retrieving Ads for: (115971144571, 'GB'), number 359
# 	 4 ads
# Retrieving Ads for: (116097341519, 'GB'), number 360
# 	 0 ads
# Retrieving Ads for: (116649450268, 'GB'), number 361
# 	 0 ads
# Retrieving Ads for: (117236562052, 'GB'), number 362
# 	 0 ads
# Retrieving Ads for: (117342423092, 'GB'), number 363
# 	 0 ads
# Retrieving Ads for: (117476785190, 'GB'), number 364
# 	 3 ads
# Retrieving Ads for: (117509421272, 'GB'), number 365
# 	 608 ads
# Retrieving Ads for: (119405895873, 'GB'), number 366
# 	 3 ads
# Retrieving Ads for: (120189635022, 'GB'), number 367
# 	 6 ads
# Retrieving Ads for: (120214361223, 'GB'), number 368
# 	 29 ads
# Retrieving Ads for: (120360501507, 'GB'), number 369
# 	 0 ads
# Retrieving Ads for: (121182673320, 'GB'), number 370
# 	 0 ads
# Retrieving Ads for: (121936349543, 'GB'), number 371
# 	 960 ads
# Retrieving Ads for: (122264711661, 'GB'), number 372
# 	 0 ads
# Retrieving Ads for: (122966210490, 'GB'), number 373
# 	 0 ads
# Retrieving Ads for: (123052189231, 'GB'), number 374
# 	 0 ads
# Retrieving Ads for: (123817579216, 'GB'), number 375
# 	 3 ads
# Retrieving Ads for: (124329456353, 'GB'), number 376
# 	 2 ads
# Retrieving Ads for: (124687302320, 'GB'), number 377
# 	 2 ads
# Retrieving Ads for: (124941131829, 'GB'), number 378
# 	 0 ads
# Retrieving Ads for: (125565308750, 'GB'), number 379
# 	 1 ads
# Retrieving Ads for: (125697538572, 'GB'), number 380
# 	 0 ads
# Retrieving Ads for: (126052760507, 'GB'), number 381
# 	 15 ads
# Retrieving Ads for: (126814579407, 'GB'), number 382
# 	 0 ads
# Retrieving Ads for: (126966249559, 'GB'), number 383
# 	 0 ads
# Retrieving Ads for: (127390450064, 'GB'), number 384
# 	 2 ads
# Retrieving Ads for: (127503852028, 'GB'), number 385
# 	 0 ads
# Retrieving Ads for: (128381069655, 'GB'), number 386
# 	 0 ads
# Retrieving Ads for: (128993570121, 'GB'), number 387
# 	 74 ads
# Retrieving Ads for: (129238125436, 'GB'), number 388
# 	 12 ads
# Retrieving Ads for: (131189377574, 'GB'), number 389
# 	 2 ads
# Retrieving Ads for: (131322692657, 'GB'), number 390
# 	 1 ads
# Retrieving Ads for: (131681033513, 'GB'), number 391
# 	 425 ads
# Retrieving Ads for: (134077510212, 'GB'), number 392
# 	 90 ads
# Retrieving Ads for: (134788098866, 'GB'), number 393
# 	 0 ads
# Retrieving Ads for: (135566753907, 'GB'), number 394
# 	 0 ads
# Retrieving Ads for: (135801383476, 'GB'), number 395
# 	 0 ads
# Retrieving Ads for: (136308776480, 'GB'), number 396
# 	 4 ads
# Retrieving Ads for: (136628555447, 'GB'), number 397
# 	 0 ads
# Retrieving Ads for: (136745423896, 'GB'), number 398
# 	 0 ads
# Retrieving Ads for: (137385490131, 'GB'), number 399
# 	 22 ads
# Saving ..... batch 4, current id: 400
# Retrieving Ads for: (138341914612, 'GB'), number 400
# 	 0 ads
# Retrieving Ads for: (138912573683, 'GB'), number 401
# 	 0 ads
# Retrieving Ads for: (139695000173, 'GB'), number 402
# 	 170 ads
# Retrieving Ads for: (139808374690, 'GB'), number 403
# 	 1 ads
# Retrieving Ads for: (140879763603, 'GB'), number 404
# 	 0 ads
# Retrieving Ads for: (141356803345, 'GB'), number 405
# 	 62 ads
# Retrieving Ads for: (142432831702, 'GB'), number 406
# 	 2 ads
# Retrieving Ads for: (142972967665, 'GB'), number 407
# 	 0 ads
# Retrieving Ads for: (143140920600, 'GB'), number 408
# 	 0 ads
# Retrieving Ads for: (143666524748, 'GB'), number 409
# 	 70 ads
# Retrieving Ads for: (143957883722, 'GB'), number 410
# 	 0 ads
# Retrieving Ads for: (145666450461, 'GB'), number 411
# 	 3 ads
# Retrieving Ads for: (146599948077, 'GB'), number 412
# 	 0 ads
# Retrieving Ads for: (146998042522, 'GB'), number 413
# 	 0 ads
# Retrieving Ads for: (148617879290, 'GB'), number 414
# 	 0 ads
# Retrieving Ads for: (150632371526, 'GB'), number 415
# 	 0 ads
# Retrieving Ads for: (152981462200, 'GB'), number 416
# 	 0 ads
# Retrieving Ads for: (153494835802, 'GB'), number 417
# 	 3 ads
# Retrieving Ads for: (153660100664, 'GB'), number 418
# 	 0 ads
# Retrieving Ads for: (154312505920, 'GB'), number 419
# 	 0 ads
# Retrieving Ads for: (156180324417, 'GB'), number 420
# 	 0 ads
# Retrieving Ads for: (156259257856, 'GB'), number 421
# 	 0 ads
# Retrieving Ads for: (156409912584, 'GB'), number 422
# 	 0 ads
# Retrieving Ads for: (157443945635, 'GB'), number 423
# 	 0 ads
# Retrieving Ads for: (157458295970, 'GB'), number 424
# 	 0 ads
# Retrieving Ads for: (158365557945, 'GB'), number 425
# 	 15 ads
# Retrieving Ads for: (158758150725, 'GB'), number 426
# 	 10 ads
# Retrieving Ads for: (159549257671, 'GB'), number 427
# 	 0 ads
# Retrieving Ads for: (161028272789, 'GB'), number 428
# 	 0 ads
# Retrieving Ads for: (163191302837, 'GB'), number 429
# 	 2 ads
# Retrieving Ads for: (163862575762, 'GB'), number 430
# 	 1 ads
# Retrieving Ads for: (164249401288, 'GB'), number 431
# 	 0 ads
# Retrieving Ads for: (164471235877, 'GB'), number 432
# 	 3 ads
# Retrieving Ads for: (164851239572, 'GB'), number 433
# 	 68 ads
# Retrieving Ads for: (165812612147, 'GB'), number 434
# 	 0 ads
# Retrieving Ads for: (166335402260, 'GB'), number 435
# 	 0 ads
# Retrieving Ads for: (169981156569, 'GB'), number 436
# 	 1 ads
# Retrieving Ads for: (169993388268, 'GB'), number 437
# 	 0 ads
# Retrieving Ads for: (171429910030, 'GB'), number 438
# 	 0 ads
# Retrieving Ads for: (172392210758, 'GB'), number 439
# 	 0 ads
# Retrieving Ads for: (173263326992, 'GB'), number 440
# 	 0 ads
# Retrieving Ads for: (175608624750, 'GB'), number 441
# 	 0 ads
# Retrieving Ads for: (175900643477, 'GB'), number 442
# 	 0 ads
# Retrieving Ads for: (176498653349, 'GB'), number 443
# 	 0 ads
# Retrieving Ads for: (176818498909, 'GB'), number 444
# 	 0 ads
# Retrieving Ads for: (180050601590, 'GB'), number 445
# 	 0 ads
# Retrieving Ads for: (184189558686, 'GB'), number 446
# 	 0 ads
# Retrieving Ads for: (184827895439, 'GB'), number 447
# 	 0 ads
# Retrieving Ads for: (185625017130, 'GB'), number 448
# 	 21 ads
# Retrieving Ads for: (185677149392, 'GB'), number 449
# 	 0 ads
# Retrieving Ads for: (185995523250, 'GB'), number 450
# 	 0 ads
# Retrieving Ads for: (186622728032, 'GB'), number 451
# 	 158 ads
# Retrieving Ads for: (187751468198, 'GB'), number 452
# 	 0 ads
# Retrieving Ads for: (188918654329, 'GB'), number 453
# 	 1 ads
# Retrieving Ads for: (189269999292, 'GB'), number 454
# 	 1 ads
# Retrieving Ads for: (190343006511, 'GB'), number 455
# 	 0 ads
# Retrieving Ads for: (190710539707, 'GB'), number 456
# 	 4 ads
# Retrieving Ads for: (192381083777, 'GB'), number 457
# 	 3 ads
# Retrieving Ads for: (193253236405, 'GB'), number 458
# 	 0 ads
# Retrieving Ads for: (193317391840, 'GB'), number 459
# 	 7 ads
# Retrieving Ads for: (193446504757, 'GB'), number 460
# 	 0 ads
# Retrieving Ads for: (193488666400, 'GB'), number 461
# 	 4 ads
# Retrieving Ads for: (198081311536, 'GB'), number 462
# 	 1 ads
# Retrieving Ads for: (198119003432, 'GB'), number 463
# 	 0 ads
# Retrieving Ads for: (200006375787, 'GB'), number 464
# 	 1879 ads
# Retrieving Ads for: (201398785149, 'GB'), number 465
# 	 5 ads
# Retrieving Ads for: (202472810443, 'GB'), number 466
# 	 0 ads
# Retrieving Ads for: (202480635550, 'GB'), number 467
# 	 165 ads
# Retrieving Ads for: (202798122688, 'GB'), number 468
# 	 9 ads
# Retrieving Ads for: (206329726880, 'GB'), number 469
# 	 0 ads
# Retrieving Ads for: (208189704820, 'GB'), number 470
# 	 12 ads
# Retrieving Ads for: (208202162442, 'GB'), number 471
# 	 1 ads
# Retrieving Ads for: (208267723853, 'GB'), number 472
# 	 0 ads
# Retrieving Ads for: (211389726295, 'GB'), number 473
# 	 0 ads
# Retrieving Ads for: (213441154663, 'GB'), number 474
# 	 0 ads
# Retrieving Ads for: (213798633764, 'GB'), number 475
# 	 0 ads
# Retrieving Ads for: (214351281833, 'GB'), number 476
# 	 2 ads
# Retrieving Ads for: (214435206012, 'GB'), number 477
# 	 4 ads
# Retrieving Ads for: (214684447891, 'GB'), number 478
# 	 0 ads
# Retrieving Ads for: (216311481960, 'GB'), number 479
# 	 6 ads
# Retrieving Ads for: (216550520609, 'GB'), number 480
# 	 0 ads
# Retrieving Ads for: (216600665159, 'GB'), number 481
# 	 0 ads
# Retrieving Ads for: (219483273768, 'GB'), number 482
# 	 0 ads
# Retrieving Ads for: (219947610085, 'GB'), number 483
# 	 51 ads
# Retrieving Ads for: (220353389618, 'GB'), number 484
# 	 0 ads
# Retrieving Ads for: (220543443746, 'GB'), number 485
# 	 188 ads
# Retrieving Ads for: (221115152587, 'GB'), number 486
# 	 3 ads
# Retrieving Ads for: (227177075721, 'GB'), number 487
# 	 0 ads
# Retrieving Ads for: (227427673437, 'GB'), number 488
# 	 47 ads
# Retrieving Ads for: (233829266799, 'GB'), number 489
# 	 0 ads
# Retrieving Ads for: (234881964773, 'GB'), number 490
# 	 4 ads
# Retrieving Ads for: (236215875884, 'GB'), number 491
# 	 1 ads
# Retrieving Ads for: (240864038889, 'GB'), number 492
# 	 4 ads
# Retrieving Ads for: (242363598572, 'GB'), number 493
# 	 20 ads
# Retrieving Ads for: (245418970510, 'GB'), number 494
# 	 0 ads
# Retrieving Ads for: (246872175166, 'GB'), number 495
# 	 70 ads
# Retrieving Ads for: (249425191947, 'GB'), number 496
# 	 0 ads
# Retrieving Ads for: (252437278217, 'GB'), number 497
# 	 0 ads
# Retrieving Ads for: (255545417167, 'GB'), number 498
# 	 0 ads
# Retrieving Ads for: (255568980598, 'GB'), number 499
# 	 4 ads
# Saving ..... batch 5, current id: 500
# Retrieving Ads for: (257186392196, 'GB'), number 500
# 	 7 ads
# Retrieving Ads for: (259375503112, 'GB'), number 501
# 	 0 ads
# Retrieving Ads for: (260556755653, 'GB'), number 502
# 	 0 ads
# Retrieving Ads for: (262370800536, 'GB'), number 503
# 	 0 ads
# Retrieving Ads for: (265465750722, 'GB'), number 504
# 	 0 ads
# Retrieving Ads for: (267800298660, 'GB'), number 505
# 	 0 ads
# Retrieving Ads for: (268801635305, 'GB'), number 506
# 	 246 ads
# Retrieving Ads for: (271154343382, 'GB'), number 507
# 	 29 ads
# Retrieving Ads for: (272030504867, 'GB'), number 508
# 	 8 ads
# Retrieving Ads for: (277250284532, 'GB'), number 509
# 	 0 ads
# Retrieving Ads for: (281392347872, 'GB'), number 510
# 	 3 ads
# Retrieving Ads for: (282646155930, 'GB'), number 511
# 	 5 ads
# Retrieving Ads for: (283013392396, 'GB'), number 512
# 	 0 ads
# Retrieving Ads for: (285558528926, 'GB'), number 513
# 	 2 ads
# Retrieving Ads for: (286055208242, 'GB'), number 514
# 	 11 ads
# Retrieving Ads for: (287501884208, 'GB'), number 515
# 	 0 ads
# Retrieving Ads for: (289690716457, 'GB'), number 516
# 	 41 ads
# Retrieving Ads for: (290995805692, 'GB'), number 517
# 	 1 ads
# Retrieving Ads for: (292707053344, 'GB'), number 518
# 	 0 ads
# Retrieving Ads for: (294717259146, 'GB'), number 519
# 	 0 ads
# Retrieving Ads for: (294958672345, 'GB'), number 520
# 	 1 ads
# Retrieving Ads for: (295893618176, 'GB'), number 521
# 	 0 ads
# Retrieving Ads for: (297581350312, 'GB'), number 522
# 	 2 ads
# Retrieving Ads for: (298888740822, 'GB'), number 523
# 	 0 ads
# Retrieving Ads for: (299389931883, 'GB'), number 524
# 	 0 ads
# Retrieving Ads for: (300174722367, 'GB'), number 525
# 	 0 ads
# Retrieving Ads for: (300800387392, 'GB'), number 526
# 	 0 ads
# Retrieving Ads for: (309859477095, 'GB'), number 527
# 	 8 ads
# Retrieving Ads for: (310841682576, 'GB'), number 528
# 	 2 ads
# Retrieving Ads for: (311627208673, 'GB'), number 529
# 	 1177 ads
# Retrieving Ads for: (312153035790, 'GB'), number 530
# 	 0 ads
# Retrieving Ads for: (313284356719, 'GB'), number 531
# 	 0 ads
# Retrieving Ads for: (314853454314, 'GB'), number 532
# 	 0 ads
# Retrieving Ads for: (315543515306, 'GB'), number 533
# 	 1 ads
# Retrieving Ads for: (315603771494, 'GB'), number 534
# 	 1 ads
# Retrieving Ads for: (316496640057, 'GB'), number 535
# 	 1 ads
# Retrieving Ads for: (319465674441, 'GB'), number 536
# 	 10 ads
# Retrieving Ads for: (320664054114, 'GB'), number 537
# 	 0 ads
# Retrieving Ads for: (323355734857, 'GB'), number 538
# 	 1 ads
# Retrieving Ads for: (323588103454, 'GB'), number 539
# 	 1 ads
# Retrieving Ads for: (324795704279, 'GB'), number 540
# 	 0 ads
# Retrieving Ads for: (326112022415, 'GB'), number 541
# 	 0 ads
# Retrieving Ads for: (326605791719, 'GB'), number 542
# 	 0 ads
# Retrieving Ads for: (329935353925, 'GB'), number 543
# 	 0 ads
# Retrieving Ads for: (330351984041, 'GB'), number 544
# 	 0 ads
# Retrieving Ads for: (331351247229, 'GB'), number 545
# 	 2 ads
# Retrieving Ads for: (332342972847, 'GB'), number 546
# 	 12 ads
# Retrieving Ads for: (334441960730, 'GB'), number 547
# 	 3 ads
# Retrieving Ads for: (339155437887, 'GB'), number 548
# 	 1 ads
# Retrieving Ads for: (342002108699, 'GB'), number 549
# 	 14 ads
# Retrieving Ads for: (342382261712, 'GB'), number 550
# 	 6 ads
# Retrieving Ads for: (343254621052, 'GB'), number 551
# 	 1 ads
# Retrieving Ads for: (343543623867, 'GB'), number 552
# 	 4 ads
# Retrieving Ads for: (345862640721, 'GB'), number 553
# 	 0 ads
# Retrieving Ads for: (346126507178, 'GB'), number 554
# 	 2 ads
# Retrieving Ads for: (347265340270, 'GB'), number 555
# 	 2 ads
# Retrieving Ads for: (349596960793, 'GB'), number 556
# 	 9 ads
# Retrieving Ads for: (350315546248, 'GB'), number 557
# 	 0 ads
# Retrieving Ads for: (352592201521, 'GB'), number 558
# 	 8 ads
# Retrieving Ads for: (353576190962, 'GB'), number 559
# 	 0 ads
# Retrieving Ads for: (354204393018, 'GB'), number 560
# 	 2 ads
# Retrieving Ads for: (355665009819, 'GB'), number 561
# 	 0 ads
# Retrieving Ads for: (357045667965, 'GB'), number 562
# 	 0 ads
# Retrieving Ads for: (358413825239, 'GB'), number 563
# 	 3 ads
# Retrieving Ads for: (358706239805, 'GB'), number 564
# 	 328 ads
# Retrieving Ads for: (360132447199, 'GB'), number 565
# 	 1 ads
# Retrieving Ads for: (361943268942, 'GB'), number 566
# 	 0 ads
# Retrieving Ads for: (363014980223, 'GB'), number 567
# 	 0 ads
# Retrieving Ads for: (363111098454, 'GB'), number 568
# 	 0 ads
# Retrieving Ads for: (371437675120, 'GB'), number 569
# 	 0 ads
# Retrieving Ads for: (400369320135, 'GB'), number 570
# 	 0 ads
# Retrieving Ads for: (470736210584, 'GB'), number 571
# 	 0 ads
# Retrieving Ads for: (474216685502, 'GB'), number 572
# 	 0 ads
# Retrieving Ads for: (491992065462, 'GB'), number 573
# 	 1 ads
# Retrieving Ads for: (100101609304817, 'GB'), number 574
# 	 0 ads
# Retrieving Ads for: (100103949013499, 'GB'), number 575
# 	 0 ads
# Retrieving Ads for: (100105322336334, 'GB'), number 576
# 	 0 ads
# Retrieving Ads for: (100106268772710, 'GB'), number 577
# 	 0 ads
# Retrieving Ads for: (100111526020214, 'GB'), number 578
# 	 0 ads
# Retrieving Ads for: (100114038071684, 'GB'), number 579
# 	 1 ads
# Retrieving Ads for: (100115905140667, 'GB'), number 580
# 	 3 ads
# Retrieving Ads for: (100118448122201, 'GB'), number 581
# 	 39 ads
# Retrieving Ads for: (100119159347078, 'GB'), number 582
# 	 0 ads
# Retrieving Ads for: (100120409172760, 'GB'), number 583
# 	 0 ads
# Retrieving Ads for: (100121085183882, 'GB'), number 584
# 	 0 ads
# Retrieving Ads for: (100124738518639, 'GB'), number 585
# 	 1 ads
# Retrieving Ads for: (100125769308263, 'GB'), number 586
# 	 0 ads
# Retrieving Ads for: (100129142148024, 'GB'), number 587
# 	 0 ads
# Retrieving Ads for: (100129659298153, 'GB'), number 588
# 	 0 ads
# Retrieving Ads for: (100130348421450, 'GB'), number 589
# 	 2 ads
# Retrieving Ads for: (100130668608060, 'GB'), number 590
# 	 1 ads
# Retrieving Ads for: (100134222618382, 'GB'), number 591
# 	 0 ads
# Retrieving Ads for: (100140032259963, 'GB'), number 592
# 	 0 ads
# Retrieving Ads for: (100140939244476, 'GB'), number 593
# 	 0 ads
# Retrieving Ads for: (100141185969300, 'GB'), number 594
# 	 0 ads
# Retrieving Ads for: (100144038249464, 'GB'), number 595
# 	 0 ads
# Retrieving Ads for: (100144631767255, 'GB'), number 596
# 	 0 ads
# Retrieving Ads for: (100147889315047, 'GB'), number 597
# 	 0 ads
# Retrieving Ads for: (100148269269886, 'GB'), number 598
# 	 0 ads
# Retrieving Ads for: (100158426845642, 'GB'), number 599
# 	 1 ads
# Saving ..... batch 6, current id: 600
# Retrieving Ads for: (100160455646015, 'GB'), number 600
# 	 0 ads
# Retrieving Ads for: (100161348196675, 'GB'), number 601
# 	 0 ads
# Retrieving Ads for: (100162738241949, 'GB'), number 602
# 	 2 ads
# Retrieving Ads for: (100162855873355, 'GB'), number 603
# 	 0 ads
# Retrieving Ads for: (100163218410243, 'GB'), number 604
# 	 0 ads
# Retrieving Ads for: (100164491403278, 'GB'), number 605
# 	 1 ads
# Retrieving Ads for: (100166225965518, 'GB'), number 606
# 	 0 ads
# Retrieving Ads for: (100175741977051, 'GB'), number 607
# 	 1 ads
# Retrieving Ads for: (100176941706075, 'GB'), number 608
# 	 0 ads
# Retrieving Ads for: (100177155707169, 'GB'), number 609
# 	 0 ads
# Retrieving Ads for: (100179315255606, 'GB'), number 610
# 	 0 ads
# Retrieving Ads for: (100180329283051, 'GB'), number 611
# 	 0 ads
# Retrieving Ads for: (100183052259966, 'GB'), number 612
# 	 0 ads
# Retrieving Ads for: (100188225976430, 'GB'), number 613
# 	 0 ads
# Retrieving Ads for: (100192671595055, 'GB'), number 614
# 	 8 ads
# Retrieving Ads for: (100197739330803, 'GB'), number 615
# 	 0 ads
# Retrieving Ads for: (100198332632407, 'GB'), number 616
# 	 0 ads
# Retrieving Ads for: (100199529349867, 'GB'), number 617
# 	 0 ads
# Retrieving Ads for: (100201645665075, 'GB'), number 618
# 	 0 ads
# Retrieving Ads for: (100202634981422, 'GB'), number 619
# 	 0 ads
# Retrieving Ads for: (100203912319663, 'GB'), number 620
# 	 0 ads
# Retrieving Ads for: (100206048480066, 'GB'), number 621
# 	 0 ads
# Retrieving Ads for: (100211962255903, 'GB'), number 622
# 	 0 ads
# Retrieving Ads for: (100214094741022, 'GB'), number 623
# 	 0 ads
# Retrieving Ads for: (100219068498989, 'GB'), number 624
# 	 1 ads
# Retrieving Ads for: (100225122485834, 'GB'), number 625
# 	 6 ads
# Retrieving Ads for: (100226310084172, 'GB'), number 626
# 	 0 ads
# Retrieving Ads for: (100230235963191, 'GB'), number 627
# 	 0 ads
# Retrieving Ads for: (100232709295400, 'GB'), number 628
# 	 0 ads
# Retrieving Ads for: (100237022298668, 'GB'), number 629
# 	 0 ads
# Retrieving Ads for: (100237779307999, 'GB'), number 630
# 	 0 ads
# Retrieving Ads for: (100238429289981, 'GB'), number 631
# 	 0 ads
# Retrieving Ads for: (100246568358272, 'GB'), number 632
# 	 0 ads
# Retrieving Ads for: (100249929286262, 'GB'), number 633
# 	 0 ads
# Retrieving Ads for: (100255935742623, 'GB'), number 634
# 	 2 ads
# Retrieving Ads for: (100259452351097, 'GB'), number 635
# 	 0 ads
# Retrieving Ads for: (100260661461455, 'GB'), number 636
# 	 0 ads
# Retrieving Ads for: (100278769243803, 'GB'), number 637
# 	 0 ads
# Retrieving Ads for: (100284999235325, 'GB'), number 638
# 	 0 ads
# Retrieving Ads for: (100285905884915, 'GB'), number 639
# 	 0 ads
# Retrieving Ads for: (100287575725411, 'GB'), number 640
# 	 0 ads
# Retrieving Ads for: (100289129232814, 'GB'), number 641
# 	 0 ads
# Retrieving Ads for: (100292169032764, 'GB'), number 642
# 	 0 ads
# Retrieving Ads for: (100294524873469, 'GB'), number 643
# 	 8 ads
# Retrieving Ads for: (100309889277789, 'GB'), number 644
# 	 0 ads
# Retrieving Ads for: (100310892619087, 'GB'), number 645
# 	 0 ads
# Retrieving Ads for: (100314628249064, 'GB'), number 646
# 	 0 ads
# Retrieving Ads for: (100315005951145, 'GB'), number 647
# 	 0 ads
# Retrieving Ads for: (100320358288904, 'GB'), number 648
# 	 3 ads
# Retrieving Ads for: (100321609236517, 'GB'), number 649
# 	 0 ads
# Retrieving Ads for: (100324641807745, 'GB'), number 650
# 	 0 ads
# Retrieving Ads for: (100325452593212, 'GB'), number 651
# 	 0 ads
# Retrieving Ads for: (100331275937341, 'GB'), number 652
# 	 0 ads
# Retrieving Ads for: (100335678742581, 'GB'), number 653
# 	 0 ads
# Retrieving Ads for: (100339322647106, 'GB'), number 654
# 	 0 ads
# Retrieving Ads for: (100341195925376, 'GB'), number 655
# 	 0 ads
# Retrieving Ads for: (100347578837862, 'GB'), number 656
# 	 14 ads
# Retrieving Ads for: (100348935473436, 'GB'), number 657
# 	 1 ads
# Retrieving Ads for: (100350269269979, 'GB'), number 658
# 	 0 ads
# Retrieving Ads for: (100357038882159, 'GB'), number 659
# 	 0 ads
# Retrieving Ads for: (100360472587403, 'GB'), number 660
# 	 0 ads
# Retrieving Ads for: (100361525931330, 'GB'), number 661
# 	 1 ads
# Retrieving Ads for: (100363206016607, 'GB'), number 662
# 	 0 ads
# Retrieving Ads for: (100367289280319, 'GB'), number 663
# 	 0 ads
# Retrieving Ads for: (100368052650872, 'GB'), number 664
# 	 0 ads
# Retrieving Ads for: (100370028939571, 'GB'), number 665
# 	 0 ads
# Retrieving Ads for: (100370395071722, 'GB'), number 666
# 	 1 ads
# Retrieving Ads for: (100370632125172, 'GB'), number 667
# 	 6 ads
# Retrieving Ads for: (100372965583571, 'GB'), number 668
# 	 0 ads
# Retrieving Ads for: (100375849312830, 'GB'), number 669
# 	 0 ads
# Retrieving Ads for: (100377438914840, 'GB'), number 670
# 	 0 ads
# Retrieving Ads for: (100378135104746, 'GB'), number 671
# 	 0 ads
# Retrieving Ads for: (100378402126532, 'GB'), number 672
# 	 0 ads
# Retrieving Ads for: (100380472560649, 'GB'), number 673
# 	 0 ads
# Retrieving Ads for: (100381842216738, 'GB'), number 674
# 	 0 ads
# Retrieving Ads for: (100385135914587, 'GB'), number 675
# 	 0 ads
# Retrieving Ads for: (100385685908702, 'GB'), number 676
# 	 1 ads
# Retrieving Ads for: (100386805172215, 'GB'), number 677
# 	 1 ads
# Retrieving Ads for: (100388512594029, 'GB'), number 678
# 	 0 ads
# Retrieving Ads for: (100389245921278, 'GB'), number 679
# 	 0 ads
# Retrieving Ads for: (100396318770585, 'GB'), number 680
# 	 0 ads
# Retrieving Ads for: (100396558104513, 'GB'), number 681
# 	 0 ads
# Retrieving Ads for: (100397228533925, 'GB'), number 682
# 	 5 ads
# Retrieving Ads for: (100398235855791, 'GB'), number 683
# 	 0 ads
# Retrieving Ads for: (100398502450362, 'GB'), number 684
# 	 0 ads
# Retrieving Ads for: (100405978669241, 'GB'), number 685
# 	 0 ads
# Retrieving Ads for: (100408255975108, 'GB'), number 686
# 	 0 ads
# Retrieving Ads for: (100413392378474, 'GB'), number 687
# 	 3 ads
# Retrieving Ads for: (100413474991540, 'GB'), number 688
# 	 0 ads
# Retrieving Ads for: (100416419104176, 'GB'), number 689
# 	 0 ads
# Retrieving Ads for: (100424115621359, 'GB'), number 690
# 	 1 ads
# Retrieving Ads for: (100424815836930, 'GB'), number 691
# 	 1 ads
# Retrieving Ads for: (100425305937986, 'GB'), number 692
# 	 0 ads
# Retrieving Ads for: (100429025742191, 'GB'), number 693
# 	 1 ads
# Retrieving Ads for: (100434704664847, 'GB'), number 694
# 	 24 ads
# Retrieving Ads for: (100437961561505, 'GB'), number 695
# 	 1 ads
# Retrieving Ads for: (100440738971194, 'GB'), number 696
# 	 0 ads
# Retrieving Ads for: (100442005543087, 'GB'), number 697
# 	 0 ads
# Retrieving Ads for: (100445518354593, 'GB'), number 698
# 	 0 ads
# Retrieving Ads for: (100447235921916, 'GB'), number 699
# 	 0 ads
# Saving ..... batch 7, current id: 700
# Retrieving Ads for: (100460115820499, 'GB'), number 700
# 	 56 ads
# Retrieving Ads for: (100463891682806, 'GB'), number 701
# 	 1 ads
# Retrieving Ads for: (100466349002967, 'GB'), number 702
# 	 0 ads
# Retrieving Ads for: (100480825586733, 'GB'), number 703
# 	 0 ads
# Retrieving Ads for: (100484462291162, 'GB'), number 704
# 	 0 ads
# Retrieving Ads for: (100484742091484, 'GB'), number 705
# 	 0 ads
# Retrieving Ads for: (100489675619092, 'GB'), number 706
# 	 0 ads
# Retrieving Ads for: (100491608109877, 'GB'), number 707
# 	 0 ads
# Retrieving Ads for: (100493628095701, 'GB'), number 708
# 	 2 ads
# Retrieving Ads for: (100494092648053, 'GB'), number 709
# 	 0 ads
# Retrieving Ads for: (100494141820053, 'GB'), number 710
# 	 0 ads
# Retrieving Ads for: (100496161692888, 'GB'), number 711
# 	 0 ads
# Retrieving Ads for: (100504129316270, 'GB'), number 712
# 	 1 ads
# Retrieving Ads for: (100505632609194, 'GB'), number 713
# 	 0 ads
# Retrieving Ads for: (100508905886807, 'GB'), number 714
# 	 0 ads
# Retrieving Ads for: (100509185400546, 'GB'), number 715
# 	 0 ads
# Retrieving Ads for: (100512582645954, 'GB'), number 716
# 	 0 ads
# Retrieving Ads for: (100514969297204, 'GB'), number 717
# 	 0 ads
# Retrieving Ads for: (100518362602440, 'GB'), number 718
# 	 0 ads
# Retrieving Ads for: (100528172388744, 'GB'), number 719
# 	 0 ads
# Retrieving Ads for: (100528241856492, 'GB'), number 720
# 	 1 ads
# Retrieving Ads for: (100528749265038, 'GB'), number 721
# 	 0 ads
# Retrieving Ads for: (100530419092283, 'GB'), number 722
# 	 0 ads
# Retrieving Ads for: (100530518833475, 'GB'), number 723
# 	 12 ads
# Retrieving Ads for: (100538978233025, 'GB'), number 724
# 	 3 ads
# Retrieving Ads for: (100540138319049, 'GB'), number 725
# 	 0 ads
# Retrieving Ads for: (100546535874042, 'GB'), number 726
# 	 0 ads
# Retrieving Ads for: (100546785903517, 'GB'), number 727
# 	 0 ads
# Retrieving Ads for: (100549282533605, 'GB'), number 728
# 	 0 ads
# Retrieving Ads for: (100553032399423, 'GB'), number 729
# 	 56 ads
# Retrieving Ads for: (100555615400606, 'GB'), number 730
# 	 0 ads
# Retrieving Ads for: (100557085831252, 'GB'), number 731
# 	 2 ads
# Retrieving Ads for: (100557668459561, 'GB'), number 732
# 	 31 ads
# Retrieving Ads for: (100557691977208, 'GB'), number 733
# 	 0 ads
# Retrieving Ads for: (100559541708765, 'GB'), number 734
# 	 11 ads
# Retrieving Ads for: (100560031577284, 'GB'), number 735
# 	 1 ads
# Retrieving Ads for: (100561108094636, 'GB'), number 736
# 	 61 ads
# Retrieving Ads for: (100562875359612, 'GB'), number 737
# 	 0 ads
# Retrieving Ads for: (100564878176633, 'GB'), number 738
# 	 0 ads
# Retrieving Ads for: (100566665978336, 'GB'), number 739
# 	 0 ads
# Retrieving Ads for: (100572082466290, 'GB'), number 740
# 	 0 ads
# Retrieving Ads for: (100572178316299, 'GB'), number 741
# 	 0 ads
# Retrieving Ads for: (100573668896649, 'GB'), number 742
# 	 0 ads
# Retrieving Ads for: (100574382093839, 'GB'), number 743
# 	 13 ads
# Retrieving Ads for: (100581728519001, 'GB'), number 744
# 	 0 ads
# Retrieving Ads for: (100582752669563, 'GB'), number 745
# 	 0 ads
# Retrieving Ads for: (100585135900364, 'GB'), number 746
# 	 0 ads
# Retrieving Ads for: (100589709272222, 'GB'), number 747
# 	 1 ads
# Retrieving Ads for: (100589872069077, 'GB'), number 748
# 	 0 ads
# Retrieving Ads for: (100599588438419, 'GB'), number 749
# 	 0 ads
# Retrieving Ads for: (100610515930904, 'GB'), number 750
# 	 2 ads
# Retrieving Ads for: (100611055457322, 'GB'), number 751
# 	 0 ads
# Retrieving Ads for: (100611061313198, 'GB'), number 752
# 	 1 ads
# Retrieving Ads for: (100615564841361, 'GB'), number 753
# 	 4 ads
# Retrieving Ads for: (100635045334350, 'GB'), number 754
# 	 2 ads
# Retrieving Ads for: (100636035641753, 'GB'), number 755
# 	 0 ads
# Retrieving Ads for: (100636905333544, 'GB'), number 756
# 	 4 ads
# Retrieving Ads for: (100638209253255, 'GB'), number 757
# 	 0 ads
# Retrieving Ads for: (100640258224194, 'GB'), number 758
# 	 0 ads
# Retrieving Ads for: (100642139288880, 'GB'), number 759
# 	 0 ads
# Retrieving Ads for: (100642739277970, 'GB'), number 760
# 	 1 ads
# Retrieving Ads for: (100648072588465, 'GB'), number 761
# 	 0 ads
# Retrieving Ads for: (100650025704014, 'GB'), number 762
# 	 12 ads
# Retrieving Ads for: (100650331412931, 'GB'), number 763
# 	 0 ads
# Retrieving Ads for: (100651718058538, 'GB'), number 764
# 	 3 ads
# Retrieving Ads for: (100655749224838, 'GB'), number 765
# 	 0 ads
# Retrieving Ads for: (100661818730059, 'GB'), number 766
# 	 0 ads
# Retrieving Ads for: (100664309287507, 'GB'), number 767
# 	 0 ads
# Retrieving Ads for: (100664660010739, 'GB'), number 768
# 	 0 ads
# Retrieving Ads for: (100668452626453, 'GB'), number 769
# 	 0 ads
# Retrieving Ads for: (100670269257758, 'GB'), number 770
# 	 0 ads
# Retrieving Ads for: (100674019243402, 'GB'), number 771
# 	 0 ads
# Retrieving Ads for: (100678085968477, 'GB'), number 772
# 	 0 ads
# Retrieving Ads for: (100680448846923, 'GB'), number 773
# 	 0 ads
# Retrieving Ads for: (100683335965492, 'GB'), number 774
# 	 0 ads
# Retrieving Ads for: (100685605367774, 'GB'), number 775
# 	 0 ads
# ...
# 	 0 ads
# Retrieving Ads for: (1795876867305362, 'GB'), number 6613
# 	 8 ads
# Retrieving Ads for: (1796668280595377, 'GB'), number 6614
# 	 2 ads
# Retrieving Ads for: (1798435463807088, 'GB'), number 6615
# 	 15 ads
# Retrieving Ads for: (1798657933733433, 'GB'), number 6616
# 	 2 ads
# Retrieving Ads for: (1798882800328461, 'GB'), number 6617
# 	 3 ads
# Retrieving Ads for: (1801406803477239, 'GB'), number 6618
# 	 1 ads
# Retrieving Ads for: (1801592156725861, 'GB'), number 6619
# 	 0 ads
# Retrieving Ads for: (1802392483364750, 'GB'), number 6620
# 	 0 ads
# Retrieving Ads for: (1802752836609283, 'GB'), number 6621
# 	 20 ads
# Retrieving Ads for: (1805775919692905, 'GB'), number 6622
# 	 0 ads
# Retrieving Ads for: (1805989776387256, 'GB'), number 6623
# 	 0 ads
# Retrieving Ads for: (1807202219340548, 'GB'), number 6624
# 	 0 ads
# Retrieving Ads for: (1807878362871697, 'GB'), number 6625
# 	 1 ads
# Retrieving Ads for: (1807970796086865, 'GB'), number 6626
# 	 47 ads
# Retrieving Ads for: (1809959715954022, 'GB'), number 6627
# 	 1 ads
# Retrieving Ads for: (1813998201966420, 'GB'), number 6628
# 	 0 ads
# Retrieving Ads for: (1814207775556201, 'GB'), number 6629
# 	 0 ads
# Retrieving Ads for: (1814609685478552, 'GB'), number 6630
# 	 2 ads
# Retrieving Ads for: (1820626967965490, 'GB'), number 6631
# 	 0 ads
# Retrieving Ads for: (1821433204789422, 'GB'), number 6632
# 	 0 ads
# Retrieving Ads for: (1821596368102541, 'GB'), number 6633
# 	 0 ads
# Retrieving Ads for: (1823011484621630, 'GB'), number 6634
# 	 4 ads
# Retrieving Ads for: (1825469291098849, 'GB'), number 6635
# 	 3 ads
# Retrieving Ads for: (1829323197287728, 'GB'), number 6636
# 	 0 ads
# Retrieving Ads for: (1831352797151874, 'GB'), number 6637
# 	 15 ads
# Retrieving Ads for: (1834464963478547, 'GB'), number 6638
# 	 80 ads
# Retrieving Ads for: (1834548586875556, 'GB'), number 6639
# 	 13 ads
# Retrieving Ads for: (1835584336725074, 'GB'), number 6640
# 	 0 ads
# Retrieving Ads for: (1835682750061760, 'GB'), number 6641
# 	 2 ads
# Retrieving Ads for: (1835947569789247, 'GB'), number 6642
# 	 0 ads
# Retrieving Ads for: (1836487223242759, 'GB'), number 6643
# 	 0 ads
# Retrieving Ads for: (1836684129761998, 'GB'), number 6644
# 	 0 ads
# Retrieving Ads for: (1837120569879342, 'GB'), number 6645
# 	 9 ads
# Retrieving Ads for: (1837126036303443, 'GB'), number 6646
# 	 0 ads
# Retrieving Ads for: (1837867162955811, 'GB'), number 6647
# 	 1 ads
# Retrieving Ads for: (1837972526279355, 'GB'), number 6648
# 	 0 ads
# Retrieving Ads for: (1839868602960559, 'GB'), number 6649
# 	 0 ads
# Retrieving Ads for: (1840850652840595, 'GB'), number 6650
# 	 9 ads
# Retrieving Ads for: (1840967549564053, 'GB'), number 6651
# 	 12 ads
# Retrieving Ads for: (1843125999340616, 'GB'), number 6652
# 	 0 ads
# Retrieving Ads for: (1846526838930401, 'GB'), number 6653
# 	 44 ads
# Retrieving Ads for: (1846971942211465, 'GB'), number 6654
# 	 0 ads
# Retrieving Ads for: (1847912222147101, 'GB'), number 6655
# 	 56 ads
# Retrieving Ads for: (1848473425410239, 'GB'), number 6656
# 	 1 ads
# Retrieving Ads for: (1849286755152187, 'GB'), number 6657
# 	 0 ads
# Retrieving Ads for: (1850988528483461, 'GB'), number 6658
# 	 1 ads
# Retrieving Ads for: (1852355425034162, 'GB'), number 6659
# 	 1 ads
# Retrieving Ads for: (1854348168157126, 'GB'), number 6660
# 	 0 ads
# Retrieving Ads for: (1858078747757980, 'GB'), number 6661
# 	 3 ads
# Retrieving Ads for: (1859156700879249, 'GB'), number 6662
# 	 0 ads
# Retrieving Ads for: (1863944713844924, 'GB'), number 6663
# 	 175 ads
# Retrieving Ads for: (1867999873471173, 'GB'), number 6664
# 	 0 ads
# Retrieving Ads for: (1868848946716900, 'GB'), number 6665
# 	 5 ads
# Retrieving Ads for: (1869644296692918, 'GB'), number 6666
# 	 0 ads
# Retrieving Ads for: (1870441883201516, 'GB'), number 6667
# 	 3 ads
# Retrieving Ads for: (1873753972862377, 'GB'), number 6668
# 	 5 ads
# Retrieving Ads for: (1876775545882918, 'GB'), number 6669
# 	 1 ads
# Retrieving Ads for: (1878226819079566, 'GB'), number 6670
# 	 0 ads
# Retrieving Ads for: (1879815185574670, 'GB'), number 6671
# 	 18 ads
# Retrieving Ads for: (1881644798734277, 'GB'), number 6672
# 	 3 ads
# Retrieving Ads for: (1884100795206861, 'GB'), number 6673
# 	 2 ads
# Retrieving Ads for: (1885310528359578, 'GB'), number 6674
# 	 0 ads
# Retrieving Ads for: (1892602737632638, 'GB'), number 6675
# 	 0 ads
# Retrieving Ads for: (1893948487508557, 'GB'), number 6676
# 	 0 ads
# Retrieving Ads for: (1894701650796426, 'GB'), number 6677
# 	 0 ads
# Retrieving Ads for: (1894814410844115, 'GB'), number 6678
# 	 0 ads
# Retrieving Ads for: (1896179463730113, 'GB'), number 6679
# 	 0 ads
# Retrieving Ads for: (1896944163889991, 'GB'), number 6680
# 	 0 ads
# Retrieving Ads for: (1897296080565904, 'GB'), number 6681
# 	 0 ads
# Retrieving Ads for: (1898893497056165, 'GB'), number 6682
# 	 0 ads
# Retrieving Ads for: (1900550333517031, 'GB'), number 6683
# 	 0 ads
# Retrieving Ads for: (1905365642814544, 'GB'), number 6684
# 	 5 ads
# Retrieving Ads for: (1905839139653253, 'GB'), number 6685
# 	 0 ads
# Retrieving Ads for: (1906233176145248, 'GB'), number 6686
# 	 11 ads
# Retrieving Ads for: (1906339949624267, 'GB'), number 6687
# 	 6 ads
# Retrieving Ads for: (1907029486217579, 'GB'), number 6688
# 	 0 ads
# Retrieving Ads for: (1908112089264826, 'GB'), number 6689
# 	 0 ads
# Retrieving Ads for: (1910300655894009, 'GB'), number 6690
# 	 10 ads
# Retrieving Ads for: (1910956635829127, 'GB'), number 6691
# 	 0 ads
# Retrieving Ads for: (1911055515774107, 'GB'), number 6692
# 	 0 ads
# Retrieving Ads for: (1911220882491847, 'GB'), number 6693
# 	 0 ads
# Retrieving Ads for: (1912738935713798, 'GB'), number 6694
# 	 0 ads
# Retrieving Ads for: (1913594715565688, 'GB'), number 6695
# 	 0 ads
# Retrieving Ads for: (1913983672169026, 'GB'), number 6696
# 	 0 ads
# Retrieving Ads for: (1916531728594458, 'GB'), number 6697
# 	 1 ads
# Retrieving Ads for: (1918779481666854, 'GB'), number 6698
# 	 110 ads
# Retrieving Ads for: (1923371311278106, 'GB'), number 6699
# 	 150 ads
# Saving ..... batch 67, current id: 6700
# Retrieving Ads for: (1923608401265180, 'GB'), number 6700
# 	 0 ads
# Retrieving Ads for: (1928866947332662, 'GB'), number 6701
# 	 0 ads
# Retrieving Ads for: (1929320457384716, 'GB'), number 6702
# 	 3 ads
# Retrieving Ads for: (1929801517326480, 'GB'), number 6703
# 	 0 ads
# Retrieving Ads for: (1929915730481059, 'GB'), number 6704
# 	 2 ads
# Retrieving Ads for: (1930410900543324, 'GB'), number 6705
# 	 0 ads
# Retrieving Ads for: (1930888720475126, 'GB'), number 6706
# 	 2 ads
# Retrieving Ads for: (1931209670264436, 'GB'), number 6707
# 	 0 ads
# Retrieving Ads for: (1933283223404242, 'GB'), number 6708
# 	 0 ads
# Retrieving Ads for: (1934566156780439, 'GB'), number 6709
# 	 78 ads
# Retrieving Ads for: (1935310150039577, 'GB'), number 6710
# 	 0 ads
# Retrieving Ads for: (1935868476637300, 'GB'), number 6711
# 	 4 ads
# Retrieving Ads for: (1937193049741596, 'GB'), number 6712
# 	 1 ads
# Retrieving Ads for: (1937547913206353, 'GB'), number 6713
# 	 0 ads
# Retrieving Ads for: (1938243163146543, 'GB'), number 6714
# 	 10 ads
# Retrieving Ads for: (1938353656292930, 'GB'), number 6715
# 	 12 ads
# Retrieving Ads for: (1942379969344042, 'GB'), number 6716
# 	 0 ads
# Retrieving Ads for: (1943466022628856, 'GB'), number 6717
# 	 3 ads
# Retrieving Ads for: (1947797465248414, 'GB'), number 6718
# 	 0 ads
# Retrieving Ads for: (1952937738335006, 'GB'), number 6719
# 	 0 ads
# Retrieving Ads for: (1962163720729466, 'GB'), number 6720
# 	 1 ads
# Retrieving Ads for: (1966304943658597, 'GB'), number 6721
# 	 0 ads
# Retrieving Ads for: (1969428133109555, 'GB'), number 6722
# 	 0 ads
# Retrieving Ads for: (1970210346596365, 'GB'), number 6723
# 	 3 ads
# Retrieving Ads for: (1976113166003623, 'GB'), number 6724
# 	 3 ads
# Retrieving Ads for: (1981313815438939, 'GB'), number 6725
# 	 2 ads
# Retrieving Ads for: (1983482121886461, 'GB'), number 6726
# 	 0 ads
# Retrieving Ads for: (1986067581667173, 'GB'), number 6727
# 	 1 ads
# Retrieving Ads for: (1986627441582712, 'GB'), number 6728
# 	 1 ads
# Retrieving Ads for: (1991625787771213, 'GB'), number 6729
# 	 0 ads
# Retrieving Ads for: (1992016361080933, 'GB'), number 6730
# 	 33 ads
# Retrieving Ads for: (1993203874076024, 'GB'), number 6731
# 	 0 ads
# Retrieving Ads for: (1999866856913740, 'GB'), number 6732
# 	 0 ads
# Retrieving Ads for: (2001214513501519, 'GB'), number 6733
# 	 1 ads
# Retrieving Ads for: (2012016282357890, 'GB'), number 6734
# 	 0 ads
# Retrieving Ads for: (2015674312067406, 'GB'), number 6735
# 	 0 ads
# Retrieving Ads for: (2015966338421658, 'GB'), number 6736
# 	 5 ads
# Retrieving Ads for: (2020995364818033, 'GB'), number 6737
# 	 0 ads
# Retrieving Ads for: (2027808590821761, 'GB'), number 6738
# 	 0 ads
# Retrieving Ads for: (2032749120284118, 'GB'), number 6739
# 	 0 ads
# Retrieving Ads for: (2034179520134606, 'GB'), number 6740
# 	 5 ads
# Retrieving Ads for: (2039928666277902, 'GB'), number 6741
# 	 0 ads
# Retrieving Ads for: (2041168786130516, 'GB'), number 6742
# 	 0 ads
# Retrieving Ads for: (2044907289072381, 'GB'), number 6743
# 	 1 ads
# Retrieving Ads for: (2047468768889440, 'GB'), number 6744
# 	 0 ads
# Retrieving Ads for: (2047806148766050, 'GB'), number 6745
# 	 88 ads
# Retrieving Ads for: (2048412005194670, 'GB'), number 6746
# 	 0 ads
# Retrieving Ads for: (2054508318105644, 'GB'), number 6747
# 	 17 ads
# Retrieving Ads for: (2055032824723695, 'GB'), number 6748
# 	 0 ads
# Retrieving Ads for: (2061195944161110, 'GB'), number 6749
# 	 0 ads
# Retrieving Ads for: (2066178160274531, 'GB'), number 6750
# 	 0 ads
# Retrieving Ads for: (2066869553538286, 'GB'), number 6751
# 	 0 ads
# Retrieving Ads for: (2070328539677218, 'GB'), number 6752
# 	 0 ads
# Retrieving Ads for: (2075226069210106, 'GB'), number 6753
# 	 1 ads
# Retrieving Ads for: (2079497235397580, 'GB'), number 6754
# 	 45 ads
# Retrieving Ads for: (2079991985390610, 'GB'), number 6755
# 	 0 ads
# Retrieving Ads for: (2106229486080849, 'GB'), number 6756
# 	 0 ads
# Retrieving Ads for: (2106418116083890, 'GB'), number 6757
# 	 0 ads
# Retrieving Ads for: (2114118688620707, 'GB'), number 6758
# 	 1 ads
# Retrieving Ads for: (2117936378468973, 'GB'), number 6759
# 	 0 ads
# Retrieving Ads for: (2119732698342937, 'GB'), number 6760
# 	 0 ads
# Retrieving Ads for: (2120886978187969, 'GB'), number 6761
# 	 0 ads
# Retrieving Ads for: (2123165084466010, 'GB'), number 6762
# 	 60 ads
# Retrieving Ads for: (2128860527140764, 'GB'), number 6763
# 	 0 ads
# Retrieving Ads for: (2129873687278535, 'GB'), number 6764
# 	 0 ads
# Retrieving Ads for: (2133052633587160, 'GB'), number 6765
# 	 0 ads
# Retrieving Ads for: (2140254722872713, 'GB'), number 6766
# 	 1 ads
# Retrieving Ads for: (2141955389450051, 'GB'), number 6767
# 	 0 ads
# Retrieving Ads for: (2143041932437875, 'GB'), number 6768
# 	 3 ads
# Retrieving Ads for: (2144446745867511, 'GB'), number 6769
# 	 0 ads
# Retrieving Ads for: (2149766915268880, 'GB'), number 6770
# 	 0 ads
# Retrieving Ads for: (2150420018610597, 'GB'), number 6771
# 	 0 ads
# Retrieving Ads for: (2150928525165564, 'GB'), number 6772
# 	 0 ads
# Retrieving Ads for: (2150953788497217, 'GB'), number 6773
# 	 1 ads
# Retrieving Ads for: (2152911878328719, 'GB'), number 6774
# 	 0 ads
# Retrieving Ads for: (2154263754684422, 'GB'), number 6775
# 	 0 ads
# Retrieving Ads for: (2155136124614558, 'GB'), number 6776
# 	 0 ads
# Retrieving Ads for: (2155508351328103, 'GB'), number 6777
# 	 0 ads
# Retrieving Ads for: (2158024184290553, 'GB'), number 6778
# 	 0 ads
# Retrieving Ads for: (2158771450885821, 'GB'), number 6779
# 	 0 ads
# Retrieving Ads for: (2161767840813114, 'GB'), number 6780
# 	 0 ads
# Retrieving Ads for: (2161807350747523, 'GB'), number 6781
# 	 1 ads
# Retrieving Ads for: (2164917423563981, 'GB'), number 6782
# 	 0 ads
# Retrieving Ads for: (2167397843350631, 'GB'), number 6783
# 	 0 ads
# Retrieving Ads for: (2168480816734086, 'GB'), number 6784
# 	 0 ads
# Retrieving Ads for: (2170929039690706, 'GB'), number 6785
# 	 0 ads
# Retrieving Ads for: (2174517772657414, 'GB'), number 6786
# 	 0 ads
# Retrieving Ads for: (2176498509289644, 'GB'), number 6787
# 	 3 ads
# Retrieving Ads for: (2176776452554271, 'GB'), number 6788
# 	 1 ads
# Retrieving Ads for: (2184001344989532, 'GB'), number 6789
# 	 12 ads
# Retrieving Ads for: (2185781521490288, 'GB'), number 6790
# 	 2 ads
# Retrieving Ads for: (2191933467738825, 'GB'), number 6791
# 	 1 ads
# Retrieving Ads for: (2196159327275532, 'GB'), number 6792
# 	 0 ads
# Retrieving Ads for: (2196474460607659, 'GB'), number 6793
# 	 2 ads
# Retrieving Ads for: (2198816277068655, 'GB'), number 6794
# 	 0 ads
# Retrieving Ads for: (2214417322106497, 'GB'), number 6795
# 	 0 ads
# Retrieving Ads for: (2216058205283965, 'GB'), number 6796
# 	 0 ads
# Retrieving Ads for: (2217967698531116, 'GB'), number 6797
# 	 0 ads
# Retrieving Ads for: (2222965154687775, 'GB'), number 6798
# 	 0 ads
# Retrieving Ads for: (2225627931013092, 'GB'), number 6799
# 	 0 ads
# Saving ..... batch 68, current id: 6800
# Retrieving Ads for: (2229394477372065, 'GB'), number 6800
# 	 0 ads
# Retrieving Ads for: (2236871059963655, 'GB'), number 6801
# 	 0 ads
# Retrieving Ads for: (2251046518495382, 'GB'), number 6802
# 	 0 ads
# Retrieving Ads for: (2254806871505243, 'GB'), number 6803
# 	 0 ads
# Retrieving Ads for: (2254880268120528, 'GB'), number 6804
# 	 0 ads
# Retrieving Ads for: (2255317184685198, 'GB'), number 6805
# 	 2 ads
# Retrieving Ads for: (2255712224695032, 'GB'), number 6806
# 	 0 ads
# Retrieving Ads for: (2257401724319295, 'GB'), number 6807
# 	 1 ads
# Retrieving Ads for: (2257684664518343, 'GB'), number 6808
# 	 0 ads
# Retrieving Ads for: (2259750964278363, 'GB'), number 6809
# 	 0 ads
# Retrieving Ads for: (2262530897298854, 'GB'), number 6810
# 	 0 ads
# Retrieving Ads for: (2273566356288325, 'GB'), number 6811
# 	 5 ads
# Retrieving Ads for: (2273870836190298, 'GB'), number 6812
# 	 0 ads
# Retrieving Ads for: (2276450902416740, 'GB'), number 6813
# 	 0 ads
# Retrieving Ads for: (2279966602282911, 'GB'), number 6814
# 	 13 ads
# Retrieving Ads for: (2281374155290329, 'GB'), number 6815
# 	 0 ads
# Retrieving Ads for: (2283373971903553, 'GB'), number 6816
# 	 0 ads
# Retrieving Ads for: (2284510861809649, 'GB'), number 6817
# 	 0 ads
# Retrieving Ads for: (2287375864623568, 'GB'), number 6818
# 	 1 ads
# Retrieving Ads for: (2288555854704433, 'GB'), number 6819
# 	 1 ads
# Retrieving Ads for: (2292442047693325, 'GB'), number 6820
# 	 0 ads
# Retrieving Ads for: (2294307307482349, 'GB'), number 6821
# 	 2 ads
# Retrieving Ads for: (2295244603868252, 'GB'), number 6822
# 	 12 ads
# Retrieving Ads for: (2296555250567080, 'GB'), number 6823
# 	 0 ads
# Retrieving Ads for: (2296667497229041, 'GB'), number 6824
# 	 1 ads
# Retrieving Ads for: (2297926640486522, 'GB'), number 6825
# 	 363 ads
# Retrieving Ads for: (2303250593259491, 'GB'), number 6826
# 	 26 ads
# Retrieving Ads for: (2307838149231785, 'GB'), number 6827
# 	 2 ads
# Retrieving Ads for: (2328990920656003, 'GB'), number 6828
# 	 0 ads
# Retrieving Ads for: (2347565375570069, 'GB'), number 6829
# 	 0 ads
# Retrieving Ads for: (2375299949384184, 'GB'), number 6830
# 	 3 ads
# Retrieving Ads for: (2378768448836033, 'GB'), number 6831
# 	 0 ads
# Retrieving Ads for: (2382280078671812, 'GB'), number 6832
# 	 0 ads
# Retrieving Ads for: (2389668497727588, 'GB'), number 6833
# 	 25 ads
# Retrieving Ads for: (2422768761084748, 'GB'), number 6834
# 	 0 ads
# Retrieving Ads for: (2435680456708504, 'GB'), number 6835
# 	 0 ads
# Retrieving Ads for: (2443299312347521, 'GB'), number 6836
# 	 72 ads
# Retrieving Ads for: (2449574395105133, 'GB'), number 6837
# 	 3 ads
# Retrieving Ads for: (2500473679971930, 'GB'), number 6838
# 	 0 ads
# Retrieving Ads for: (2509210462438737, 'GB'), number 6839
# 	 0 ads
# Retrieving Ads for: (2510918305634950, 'GB'), number 6840
# 	 0 ads
# Retrieving Ads for: (2532198326804011, 'GB'), number 6841
# 	 0 ads
# Retrieving Ads for: (2533624963365836, 'GB'), number 6842
# 	 0 ads
# Retrieving Ads for: (2547292971969055, 'GB'), number 6843
# 	 0 ads
# Retrieving Ads for: (2558329857727118, 'GB'), number 6844
# 	 0 ads
# Retrieving Ads for: (2577614072252813, 'GB'), number 6845
# 	 0 ads
# Retrieving Ads for: (2628571130493882, 'GB'), number 6846
# 	 0 ads
# Retrieving Ads for: (2638983929506493, 'GB'), number 6847
# 	 4 ads
# Retrieving Ads for: (2822106091195542, 'GB'), number 6848
# 	 0 ads
# Retrieving Ads for: (2872972349409576, 'GB'), number 6849
# 	 0 ads
# Retrieving Ads for: (2924272814275805, 'GB'), number 6850
# 	 3 ads
# Retrieving Ads for: (2998477143711696, 'GB'), number 6851
# 	 13 ads
# Retrieving Ads for: (3190660567626119, 'GB'), number 6852
# 	 0 ads
# Retrieved 5980 ads

# %% [markdown]
# # Brazil

# %%
from itertools import product
# countries = ['US', 'GB', 'BR'] # all available countries for now
# themes = ['ad-tech','ed-tech','agri-tech','fin-tech','bio-tech','health-tech','electric-vehicles','clean-energy',
#           'cloud-computing','quantum-computing','artificial-intelligence','machine-learning','digital-assets',
#           'virtual-reality','cyber-security','software','social-trends','analytics']

all_ads = []
i = 0
total_ads = 0
for ct in product(page_id_br, ['BR']):
    if i%100 == 0:
        print(f'Saving ..... batch {i//100}, current id: {i}')
        save_pickle(f'{raw_dir}/adlibrary_ads_br_90_days_{i//1000}.pkl', all_ads)
        if i%1000 == 0:
            all_ads = []
    print(f'Retrieving Ads for: {ct}, number {i}')
    try:
        ads = obtain_ads_page_id(ct[0], ct[1], FIELDS, ACCESS_TOKEN)
        total_ads += len(ads)
        print('\t', len(ads), 'ads, total', total_ads)
        all_ads.extend(ads)
        i+=1
    except Exception as e:
        print('Some error happened:', e)
        
save_pickle(f'{raw_dir}/adlibrary_ads_br_90_days_{i//1000}.pkl', all_ads)
print(f'Retrieved {len(all_ads)} ads')
# Out:
# Saving ..... batch 0, current id: 0
# Retrieving Ads for: (5647744585, 'BR'), number 0
# 	 3 ads, total 3
# Retrieving Ads for: (6085906515, 'BR'), number 1
# 	 0 ads, total 3
# Retrieving Ads for: (7619396355, 'BR'), number 2
# 	 0 ads, total 3
# Retrieving Ads for: (7783116506, 'BR'), number 3
# 	 0 ads, total 3
# Retrieving Ads for: (8539814909, 'BR'), number 4
# 	 0 ads, total 3
# Retrieving Ads for: (12185972707, 'BR'), number 5
# 	 0 ads, total 3
# Retrieving Ads for: (17043549797, 'BR'), number 6
# 	 4 ads, total 7
# Retrieving Ads for: (22760563564, 'BR'), number 7
# 	 2 ads, total 9
# Retrieving Ads for: (24287259392, 'BR'), number 8
# 	 0 ads, total 9
# Retrieving Ads for: (26897053321, 'BR'), number 9
# 	 0 ads, total 9
# Retrieving Ads for: (27678194634, 'BR'), number 10
# 	 2 ads, total 11
# Retrieving Ads for: (31292782350, 'BR'), number 11
# 	 26 ads, total 37
# Retrieving Ads for: (36085812354, 'BR'), number 12
# 	 2 ads, total 39
# Retrieving Ads for: (39644961958, 'BR'), number 13
# 	 0 ads, total 39
# Retrieving Ads for: (39759254594, 'BR'), number 14
# 	 0 ads, total 39
# Retrieving Ads for: (44409199155, 'BR'), number 15
# 	 4 ads, total 43
# Retrieving Ads for: (45628695543, 'BR'), number 16
# 	 0 ads, total 43
# Retrieving Ads for: (46847613149, 'BR'), number 17
# 	 0 ads, total 43
# Retrieving Ads for: (47565718326, 'BR'), number 18
# 	 0 ads, total 43
# Retrieving Ads for: (55805876860, 'BR'), number 19
# 	 0 ads, total 43
# Retrieving Ads for: (56777943052, 'BR'), number 20
# 	 0 ads, total 43
# Retrieving Ads for: (68793499001, 'BR'), number 21
# 	 16 ads, total 59
# Retrieving Ads for: (70877580782, 'BR'), number 22
# 	 0 ads, total 59
# Retrieving Ads for: (71613839321, 'BR'), number 23
# 	 6 ads, total 65
# Retrieving Ads for: (72149536933, 'BR'), number 24
# 	 1 ads, total 66
# Retrieving Ads for: (73620441975, 'BR'), number 25
# 	 0 ads, total 66
# Retrieving Ads for: (73970658023, 'BR'), number 26
# 	 12 ads, total 78
# Retrieving Ads for: (77403447721, 'BR'), number 27
# 	 0 ads, total 78
# Retrieving Ads for: (78066290984, 'BR'), number 28
# 	 0 ads, total 78
# Retrieving Ads for: (79511407410, 'BR'), number 29
# 	 1 ads, total 79
# Retrieving Ads for: (80591352579, 'BR'), number 30
# 	 0 ads, total 79
# Retrieving Ads for: (85291563763, 'BR'), number 31
# 	 1 ads, total 80
# Retrieving Ads for: (88054178212, 'BR'), number 32
# 	 0 ads, total 80
# Retrieving Ads for: (89859403188, 'BR'), number 33
# 	 13 ads, total 93
# Retrieving Ads for: (90740178223, 'BR'), number 34
# 	 11 ads, total 104
# Retrieving Ads for: (91754571355, 'BR'), number 35
# 	 0 ads, total 104
# Retrieving Ads for: (92227023652, 'BR'), number 36
# 	 1 ads, total 105
# Retrieving Ads for: (92288319748, 'BR'), number 37
# 	 2 ads, total 107
# Retrieving Ads for: (93745060700, 'BR'), number 38
# 	 1 ads, total 108
# Retrieving Ads for: (97323256442, 'BR'), number 39
# 	 1 ads, total 109
# Retrieving Ads for: (101095043361, 'BR'), number 40
# 	 0 ads, total 109
# Retrieving Ads for: (104102576882, 'BR'), number 41
# 	 2 ads, total 111
# Retrieving Ads for: (105015822454, 'BR'), number 42
# 	 0 ads, total 111
# Retrieving Ads for: (105181842883, 'BR'), number 43
# 	 0 ads, total 111
# Retrieving Ads for: (107286223667, 'BR'), number 44
# 	 1 ads, total 112
# Retrieving Ads for: (109597815616, 'BR'), number 45
# 	 80 ads, total 192
# Retrieving Ads for: (109789152161, 'BR'), number 46
# 	 71 ads, total 263
# Retrieving Ads for: (111361091313, 'BR'), number 47
# 	 0 ads, total 263
# Retrieving Ads for: (113184216339, 'BR'), number 48
# 	 0 ads, total 263
# Retrieving Ads for: (113455336434, 'BR'), number 49
# 	 0 ads, total 263
# Retrieving Ads for: (114287484617, 'BR'), number 50
# 	 0 ads, total 263
# Retrieving Ads for: (115137755498, 'BR'), number 51
# 	 1 ads, total 264
# Retrieving Ads for: (119405895873, 'BR'), number 52
# 	 0 ads, total 264
# Retrieving Ads for: (125565308750, 'BR'), number 53
# 	 1 ads, total 265
# Retrieving Ads for: (126052760507, 'BR'), number 54
# 	 6 ads, total 271
# Retrieving Ads for: (130097745578, 'BR'), number 55
# 	 6 ads, total 277
# Retrieving Ads for: (131189377574, 'BR'), number 56
# 	 2 ads, total 279
# Retrieving Ads for: (132674867692, 'BR'), number 57
# 	 0 ads, total 279
# Retrieving Ads for: (138341914612, 'BR'), number 58
# 	 0 ads, total 279
# Retrieving Ads for: (140879763603, 'BR'), number 59
# 	 0 ads, total 279
# Retrieving Ads for: (141287742160, 'BR'), number 60
# 	 2 ads, total 281
# Retrieving Ads for: (147846104842, 'BR'), number 61
# 	 1 ads, total 282
# Retrieving Ads for: (149079507181, 'BR'), number 62
# 	 0 ads, total 282
# Retrieving Ads for: (159097782605, 'BR'), number 63
# 	 0 ads, total 282
# Retrieving Ads for: (159103797542, 'BR'), number 64
# 	 2 ads, total 284
# Retrieving Ads for: (161409009309, 'BR'), number 65
# 	 0 ads, total 284
# Retrieving Ads for: (165476513965, 'BR'), number 66
# 	 0 ads, total 284
# Retrieving Ads for: (174547583316, 'BR'), number 67
# 	 0 ads, total 284
# Retrieving Ads for: (176871714093, 'BR'), number 68
# 	 0 ads, total 284
# Retrieving Ads for: (180050601590, 'BR'), number 69
# 	 0 ads, total 284
# Retrieving Ads for: (182916843151, 'BR'), number 70
# 	 0 ads, total 284
# Retrieving Ads for: (185875761943, 'BR'), number 71
# 	 154 ads, total 438
# Retrieving Ads for: (189269999292, 'BR'), number 72
# 	 0 ads, total 438
# Retrieving Ads for: (191032704071, 'BR'), number 73
# 	 1 ads, total 439
# Retrieving Ads for: (200773697350, 'BR'), number 74
# 	 0 ads, total 439
# Retrieving Ads for: (205362186029, 'BR'), number 75
# 	 12 ads, total 451
# Retrieving Ads for: (216311481960, 'BR'), number 76
# 	 3 ads, total 454
# Retrieving Ads for: (220353389618, 'BR'), number 77
# 	 0 ads, total 454
# Retrieving Ads for: (224335474975, 'BR'), number 78
# 	 0 ads, total 454
# Retrieving Ads for: (233826257775, 'BR'), number 79
# 	 0 ads, total 454
# Retrieving Ads for: (239982637475, 'BR'), number 80
# 	 0 ads, total 454
# Retrieving Ads for: (240734989375, 'BR'), number 81
# 	 0 ads, total 454
# Retrieving Ads for: (249425191947, 'BR'), number 82
# 	 0 ads, total 454
# Retrieving Ads for: (260107092232, 'BR'), number 83
# 	 0 ads, total 454
# Retrieving Ads for: (262370800536, 'BR'), number 84
# 	 0 ads, total 454
# Retrieving Ads for: (267813379784, 'BR'), number 85
# 	 0 ads, total 454
# Retrieving Ads for: (292780334633, 'BR'), number 86
# 	 0 ads, total 454
# Retrieving Ads for: (295940566431, 'BR'), number 87
# 	 0 ads, total 454
# Retrieving Ads for: (299102027305, 'BR'), number 88
# 	 0 ads, total 454
# Retrieving Ads for: (300746227635, 'BR'), number 89
# 	 0 ads, total 454
# Retrieving Ads for: (312641429340, 'BR'), number 90
# 	 0 ads, total 454
# Retrieving Ads for: (315035249496, 'BR'), number 91
# 	 0 ads, total 454
# Retrieving Ads for: (315543515306, 'BR'), number 92
# 	 1 ads, total 455
# Retrieving Ads for: (315603771494, 'BR'), number 93
# 	 1 ads, total 456
# Retrieving Ads for: (316496640057, 'BR'), number 94
# 	 2 ads, total 458
# Retrieving Ads for: (330207313222, 'BR'), number 95
# 	 1 ads, total 459
# Retrieving Ads for: (333776090315, 'BR'), number 96
# 	 106 ads, total 565
# Retrieving Ads for: (334445814722, 'BR'), number 97
# 	 0 ads, total 565
# Retrieving Ads for: (347265340270, 'BR'), number 98
# 	 2 ads, total 567
# Retrieving Ads for: (347742876973, 'BR'), number 99
# 	 0 ads, total 567
# Saving ..... batch 1, current id: 100
# Retrieving Ads for: (364966627159, 'BR'), number 100
# 	 0 ads, total 567
# Retrieving Ads for: (376243256164, 'BR'), number 101
# 	 0 ads, total 567
# Retrieving Ads for: (470736210584, 'BR'), number 102
# 	 0 ads, total 567
# Retrieving Ads for: (470750715303, 'BR'), number 103
# 	 56 ads, total 623
# Retrieving Ads for: (100063501289209, 'BR'), number 104
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=100063501289209&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 623
# Retrieving Ads for: (100076366921990, 'BR'), number 105
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=100076366921990&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 623
# Retrieving Ads for: (100100305866299, 'BR'), number 106
# 	 0 ads, total 623
# Retrieving Ads for: (100103949013499, 'BR'), number 107
# 	 0 ads, total 623
# Retrieving Ads for: (100106159009340, 'BR'), number 108
# 	 3 ads, total 626
# Retrieving Ads for: (100113698236734, 'BR'), number 109
# 	 3 ads, total 629
# Retrieving Ads for: (100113751630378, 'BR'), number 110
# 	 3 ads, total 632
# Retrieving Ads for: (100114543363891, 'BR'), number 111
# 	 0 ads, total 632
# Retrieving Ads for: (100114559384425, 'BR'), number 112
# 	 1 ads, total 633
# Retrieving Ads for: (100115701334781, 'BR'), number 113
# 	 0 ads, total 633
# Retrieving Ads for: (100117012467065, 'BR'), number 114
# 	 0 ads, total 633
# Retrieving Ads for: (100117348854103, 'BR'), number 115
# 	 0 ads, total 633
# Retrieving Ads for: (100119095165423, 'BR'), number 116
# 	 2 ads, total 635
# Retrieving Ads for: (100120285928399, 'BR'), number 117
# 	 0 ads, total 635
# Retrieving Ads for: (100121991741943, 'BR'), number 118
# 	 5 ads, total 640
# Retrieving Ads for: (100130812154502, 'BR'), number 119
# 	 0 ads, total 640
# Retrieving Ads for: (100133892425014, 'BR'), number 120
# 	 0 ads, total 640
# Retrieving Ads for: (100134025955843, 'BR'), number 121
# 	 2 ads, total 642
# Retrieving Ads for: (100134385923671, 'BR'), number 122
# 	 0 ads, total 642
# Retrieving Ads for: (100136441554971, 'BR'), number 123
# 	 0 ads, total 642
# Retrieving Ads for: (100137228199210, 'BR'), number 124
# 	 0 ads, total 642
# Retrieving Ads for: (100139882504540, 'BR'), number 125
# 	 0 ads, total 642
# Retrieving Ads for: (100140259335224, 'BR'), number 126
# 	 1 ads, total 643
# Retrieving Ads for: (100140939244476, 'BR'), number 127
# 	 0 ads, total 643
# Retrieving Ads for: (100142305930876, 'BR'), number 128
# 	 3 ads, total 646
# Retrieving Ads for: (100142328690775, 'BR'), number 129
# 	 0 ads, total 646
# Retrieving Ads for: (100142459164291, 'BR'), number 130
# 	 0 ads, total 646
# Retrieving Ads for: (100145909336494, 'BR'), number 131
# 	 0 ads, total 646
# Retrieving Ads for: (100148871956220, 'BR'), number 132
# 	 0 ads, total 646
# Retrieving Ads for: (100149625995444, 'BR'), number 133
# 	 0 ads, total 646
# Retrieving Ads for: (100149818404464, 'BR'), number 134
# 	 17 ads, total 663
# Retrieving Ads for: (100150228376589, 'BR'), number 135
# 	 102 ads, total 765
# Retrieving Ads for: (100153769212360, 'BR'), number 136
# 	 0 ads, total 765
# Retrieving Ads for: (100160871738919, 'BR'), number 137
# 	 0 ads, total 765
# Retrieving Ads for: (100161351991012, 'BR'), number 138
# 	 2 ads, total 767
# Retrieving Ads for: (100162112686423, 'BR'), number 139
# 	 0 ads, total 767
# Retrieving Ads for: (100162448248917, 'BR'), number 140
# 	 0 ads, total 767
# Retrieving Ads for: (100162705232292, 'BR'), number 141
# 	 0 ads, total 767
# Retrieving Ads for: (100162738241949, 'BR'), number 142
# 	 5 ads, total 772
# Retrieving Ads for: (100165724716819, 'BR'), number 143
# 	 0 ads, total 772
# Retrieving Ads for: (100166062605045, 'BR'), number 144
# 	 0 ads, total 772
# Retrieving Ads for: (100166375147375, 'BR'), number 145
# 	 4 ads, total 776
# Retrieving Ads for: (100166632533194, 'BR'), number 146
# 	 0 ads, total 776
# Retrieving Ads for: (100168485433453, 'BR'), number 147
# 	 0 ads, total 776
# Retrieving Ads for: (100172352675383, 'BR'), number 148
# 	 0 ads, total 776
# Retrieving Ads for: (100173495228851, 'BR'), number 149
# 	 0 ads, total 776
# Retrieving Ads for: (100174255950895, 'BR'), number 150
# 	 0 ads, total 776
# Retrieving Ads for: (100178435901111, 'BR'), number 151
# 	 0 ads, total 776
# Retrieving Ads for: (100179145489145, 'BR'), number 152
# 	 2 ads, total 778
# Retrieving Ads for: (100182702588628, 'BR'), number 153
# 	 0 ads, total 778
# Retrieving Ads for: (100184808436340, 'BR'), number 154
# 	 1 ads, total 779
# Retrieving Ads for: (100189585116003, 'BR'), number 155
# 	 0 ads, total 779
# Retrieving Ads for: (100191035056570, 'BR'), number 156
# 	 0 ads, total 779
# Retrieving Ads for: (100191775024351, 'BR'), number 157
# 	 3 ads, total 782
# Retrieving Ads for: (100192575152720, 'BR'), number 158
# 	 5 ads, total 787
# Retrieving Ads for: (100195245992854, 'BR'), number 159
# 	 0 ads, total 787
# Retrieving Ads for: (100197638345022, 'BR'), number 160
# 	 1 ads, total 788
# Retrieving Ads for: (100200362171068, 'BR'), number 161
# 	 3 ads, total 791
# Retrieving Ads for: (100202634981422, 'BR'), number 162
# 	 0 ads, total 791
# Retrieving Ads for: (100207665005656, 'BR'), number 163
# 	 1 ads, total 792
# Retrieving Ads for: (100209282298570, 'BR'), number 164
# 	 0 ads, total 792
# Retrieving Ads for: (100211855097278, 'BR'), number 165
# 	 0 ads, total 792
# Retrieving Ads for: (100212561752911, 'BR'), number 166
# 	 0 ads, total 792
# Retrieving Ads for: (100213982559177, 'BR'), number 167
# 	 0 ads, total 792
# Retrieving Ads for: (100217788465087, 'BR'), number 168
# 	 0 ads, total 792
# Retrieving Ads for: (100219245857449, 'BR'), number 169
# 	 0 ads, total 792
# Retrieving Ads for: (100219619129181, 'BR'), number 170
# 	 0 ads, total 792
# Retrieving Ads for: (100219665411715, 'BR'), number 171
# 	 0 ads, total 792
# Retrieving Ads for: (100221835178558, 'BR'), number 172
# 	 0 ads, total 792
# Retrieving Ads for: (100222508113288, 'BR'), number 173
# 	 0 ads, total 792
# Retrieving Ads for: (100224626022749, 'BR'), number 174
# 	 0 ads, total 792
# Retrieving Ads for: (100225342578975, 'BR'), number 175
# 	 0 ads, total 792
# Retrieving Ads for: (100225352113621, 'BR'), number 176
# 	 0 ads, total 792
# Retrieving Ads for: (100227685834492, 'BR'), number 177
# 	 0 ads, total 792
# Retrieving Ads for: (100229085517346, 'BR'), number 178
# 	 0 ads, total 792
# Retrieving Ads for: (100229324876697, 'BR'), number 179
# 	 0 ads, total 792
# Retrieving Ads for: (100229475912903, 'BR'), number 180
# 	 0 ads, total 792
# Retrieving Ads for: (100230579224406, 'BR'), number 181
# 	 0 ads, total 792
# Retrieving Ads for: (100236928781937, 'BR'), number 182
# 	 0 ads, total 792
# Retrieving Ads for: (100238429289981, 'BR'), number 183
# 	 0 ads, total 792
# Retrieving Ads for: (100240962631974, 'BR'), number 184
# 	 1 ads, total 793
# Retrieving Ads for: (100243131390334, 'BR'), number 185
# 	 0 ads, total 793
# Retrieving Ads for: (100248249278128, 'BR'), number 186
# 	 0 ads, total 793
# Retrieving Ads for: (100257088166537, 'BR'), number 187
# 	 0 ads, total 793
# Retrieving Ads for: (100258439238516, 'BR'), number 188
# 	 0 ads, total 793
# Retrieving Ads for: (100260985221269, 'BR'), number 189
# 	 0 ads, total 793
# Retrieving Ads for: (100264302662053, 'BR'), number 190
# 	 0 ads, total 793
# Retrieving Ads for: (100265121565521, 'BR'), number 191
# 	 12 ads, total 805
# Retrieving Ads for: (100265282588841, 'BR'), number 192
# 	 0 ads, total 805
# Retrieving Ads for: (100265562609843, 'BR'), number 193
# 	 0 ads, total 805
# Retrieving Ads for: (100266515129036, 'BR'), number 194
# 	 0 ads, total 805
# Retrieving Ads for: (100268101723896, 'BR'), number 195
# 	 0 ads, total 805
# Retrieving Ads for: (100270759072188, 'BR'), number 196
# 	 1 ads, total 806
# Retrieving Ads for: (100271692648521, 'BR'), number 197
# 	 0 ads, total 806
# Retrieving Ads for: (100271922263757, 'BR'), number 198
# 	 0 ads, total 806
# Retrieving Ads for: (100272378719563, 'BR'), number 199
# 	 0 ads, total 806
# Saving ..... batch 2, current id: 200
# Retrieving Ads for: (100273016728909, 'BR'), number 200
# 	 0 ads, total 806
# Retrieving Ads for: (100273806001620, 'BR'), number 201
# 	 0 ads, total 806
# Retrieving Ads for: (100275083494691, 'BR'), number 202
# 	 16 ads, total 822
# Retrieving Ads for: (100275178876108, 'BR'), number 203
# 	 0 ads, total 822
# Retrieving Ads for: (100279589321213, 'BR'), number 204
# 	 0 ads, total 822
# Retrieving Ads for: (100281858452239, 'BR'), number 205
# 	 0 ads, total 822
# Retrieving Ads for: (100282012031785, 'BR'), number 206
# 	 0 ads, total 822
# Retrieving Ads for: (100283312645780, 'BR'), number 207
# 	 0 ads, total 822
# Retrieving Ads for: (100285212597283, 'BR'), number 208
# 	 0 ads, total 822
# Retrieving Ads for: (100293621704902, 'BR'), number 209
# 	 0 ads, total 822
# Retrieving Ads for: (100294668152772, 'BR'), number 210
# 	 0 ads, total 822
# Retrieving Ads for: (100295402695450, 'BR'), number 211
# 	 1 ads, total 823
# Retrieving Ads for: (100296319269692, 'BR'), number 212
# 	 1 ads, total 824
# Retrieving Ads for: (100300555155590, 'BR'), number 213
# 	 0 ads, total 824
# Retrieving Ads for: (100306552231937, 'BR'), number 214
# 	 1 ads, total 825
# Retrieving Ads for: (100308005591904, 'BR'), number 215
# 	 0 ads, total 825
# Retrieving Ads for: (100308035003468, 'BR'), number 216
# 	 0 ads, total 825
# Retrieving Ads for: (100308622165800, 'BR'), number 217
# 	 0 ads, total 825
# Retrieving Ads for: (100308948548999, 'BR'), number 218
# 	 0 ads, total 825
# Retrieving Ads for: (100311892627240, 'BR'), number 219
# 	 0 ads, total 825
# Retrieving Ads for: (100312752604845, 'BR'), number 220
# 	 0 ads, total 825
# Retrieving Ads for: (100313605093201, 'BR'), number 221
# 	 1 ads, total 826
# Retrieving Ads for: (100318709287418, 'BR'), number 222
# 	 0 ads, total 826
# Retrieving Ads for: (100321494992982, 'BR'), number 223
# 	 1 ads, total 827
# Retrieving Ads for: (100323028514837, 'BR'), number 224
# 	 0 ads, total 827
# Retrieving Ads for: (100328205111009, 'BR'), number 225
# 	 0 ads, total 827
# Retrieving Ads for: (100328575160090, 'BR'), number 226
# 	 0 ads, total 827
# Retrieving Ads for: (100328766978187, 'BR'), number 227
# 	 10 ads, total 837
# Retrieving Ads for: (100331819324783, 'BR'), number 228
# 	 0 ads, total 837
# Retrieving Ads for: (100332882670597, 'BR'), number 229
# 	 0 ads, total 837
# Retrieving Ads for: (100335762124018, 'BR'), number 230
# 	 0 ads, total 837
# Retrieving Ads for: (100336898694570, 'BR'), number 231
# 	 0 ads, total 837
# Retrieving Ads for: (100336935877169, 'BR'), number 232
# 	 0 ads, total 837
# Retrieving Ads for: (100340052629467, 'BR'), number 233
# 	 0 ads, total 837
# Retrieving Ads for: (100341865935056, 'BR'), number 234
# 	 0 ads, total 837
# Retrieving Ads for: (100344248360500, 'BR'), number 235
# 	 0 ads, total 837
# Retrieving Ads for: (100346095949719, 'BR'), number 236
# 	 0 ads, total 837
# Retrieving Ads for: (100346314742474, 'BR'), number 237
# 	 0 ads, total 837
# Retrieving Ads for: (100349301672599, 'BR'), number 238
# 	 0 ads, total 837
# Retrieving Ads for: (100351452588134, 'BR'), number 239
# 	 0 ads, total 837
# Retrieving Ads for: (100353309360986, 'BR'), number 240
# 	 0 ads, total 837
# Retrieving Ads for: (100353941322511, 'BR'), number 241
# 	 0 ads, total 837
# Retrieving Ads for: (100355411410875, 'BR'), number 242
# 	 1 ads, total 838
# Retrieving Ads for: (100355699230899, 'BR'), number 243
# 	 0 ads, total 838
# Retrieving Ads for: (100355911461900, 'BR'), number 244
# 	 0 ads, total 838
# Retrieving Ads for: (100356588277155, 'BR'), number 245
# 	 1 ads, total 839
# Retrieving Ads for: (100359201951930, 'BR'), number 246
# 	 0 ads, total 839
# Retrieving Ads for: (100359566010068, 'BR'), number 247
# 	 0 ads, total 839
# Retrieving Ads for: (100362412461656, 'BR'), number 248
# 	 0 ads, total 839
# Retrieving Ads for: (100362659134830, 'BR'), number 249
# 	 0 ads, total 839
# Retrieving Ads for: (100362912629349, 'BR'), number 250
# 	 1 ads, total 840
# Retrieving Ads for: (100364081812814, 'BR'), number 251
# 	 3 ads, total 843
# Retrieving Ads for: (100365655944150, 'BR'), number 252
# 	 2 ads, total 845
# Retrieving Ads for: (100367068159844, 'BR'), number 253
# 	 3 ads, total 848
# Retrieving Ads for: (100368631479576, 'BR'), number 254
# 	 71 ads, total 919
# Retrieving Ads for: (100369288054394, 'BR'), number 255
# 	 3 ads, total 922
# Retrieving Ads for: (100369772595013, 'BR'), number 256
# 	 1 ads, total 923
# Retrieving Ads for: (100372545422728, 'BR'), number 257
# 	 1 ads, total 924
# Retrieving Ads for: (100374259127963, 'BR'), number 258
# 	 0 ads, total 924
# Retrieving Ads for: (100376298249463, 'BR'), number 259
# 	 10 ads, total 934
# Retrieving Ads for: (100376992469454, 'BR'), number 260
# 	 0 ads, total 934
# Retrieving Ads for: (100381658780941, 'BR'), number 261
# 	 0 ads, total 934
# Retrieving Ads for: (100384708754245, 'BR'), number 262
# 	 0 ads, total 934
# Retrieving Ads for: (100388212572911, 'BR'), number 263
# 	 1 ads, total 935
# Retrieving Ads for: (100389319329846, 'BR'), number 264
# 	 0 ads, total 935
# Retrieving Ads for: (100391268449984, 'BR'), number 265
# 	 0 ads, total 935
# Retrieving Ads for: (100393289290856, 'BR'), number 266
# 	 0 ads, total 935
# Retrieving Ads for: (100400499225045, 'BR'), number 267
# 	 0 ads, total 935
# Retrieving Ads for: (100401895982254, 'BR'), number 268
# 	 0 ads, total 935
# Retrieving Ads for: (100403765970621, 'BR'), number 269
# 	 0 ads, total 935
# Retrieving Ads for: (100404205760725, 'BR'), number 270
# 	 0 ads, total 935
# Retrieving Ads for: (100405652683012, 'BR'), number 271
# 	 0 ads, total 935
# Retrieving Ads for: (100406519262763, 'BR'), number 272
# 	 1 ads, total 936
# Retrieving Ads for: (100413892667625, 'BR'), number 273
# 	 0 ads, total 936
# Retrieving Ads for: (100418485359223, 'BR'), number 274
# 	 0 ads, total 936
# Retrieving Ads for: (100418845055485, 'BR'), number 275
# 	 0 ads, total 936
# Retrieving Ads for: (100421044649941, 'BR'), number 276
# 	 0 ads, total 936
# Retrieving Ads for: (100423922624119, 'BR'), number 277
# 	 0 ads, total 936
# Retrieving Ads for: (100424768870196, 'BR'), number 278
# 	 2 ads, total 938
# Retrieving Ads for: (100429111698632, 'BR'), number 279
# 	 0 ads, total 938
# Retrieving Ads for: (100429345833451, 'BR'), number 280
# 	 0 ads, total 938
# Retrieving Ads for: (100431181316321, 'BR'), number 281
# 	 2 ads, total 940
# Retrieving Ads for: (100431834854769, 'BR'), number 282
# 	 0 ads, total 940
# Retrieving Ads for: (100434428687372, 'BR'), number 283
# 	 0 ads, total 940
# Retrieving Ads for: (100434535890185, 'BR'), number 284
# 	 0 ads, total 940
# Retrieving Ads for: (100434681806345, 'BR'), number 285
# 	 25 ads, total 965
# Retrieving Ads for: (100437801524133, 'BR'), number 286
# 	 0 ads, total 965
# Retrieving Ads for: (100438945177886, 'BR'), number 287
# 	 0 ads, total 965
# Retrieving Ads for: (100441569307110, 'BR'), number 288
# 	 0 ads, total 965
# Retrieving Ads for: (100441632644020, 'BR'), number 289
# 	 0 ads, total 965
# Retrieving Ads for: (100442905634476, 'BR'), number 290
# 	 0 ads, total 965
# Retrieving Ads for: (100443909012264, 'BR'), number 291
# 	 0 ads, total 965
# Retrieving Ads for: (100447489031314, 'BR'), number 292
# 	 0 ads, total 965
# Retrieving Ads for: (100449265412063, 'BR'), number 293
# 	 0 ads, total 965
# Retrieving Ads for: (100452562571422, 'BR'), number 294
# 	 0 ads, total 965
# Retrieving Ads for: (100453619313281, 'BR'), number 295
# 	 0 ads, total 965
# Retrieving Ads for: (100453629161275, 'BR'), number 296
# 	 0 ads, total 965
# Retrieving Ads for: (100455722629449, 'BR'), number 297
# 	 0 ads, total 965
# Retrieving Ads for: (100455745405560, 'BR'), number 298
# 	 0 ads, total 965
# Retrieving Ads for: (100457485904082, 'BR'), number 299
# 	 0 ads, total 965
# Saving ..... batch 3, current id: 300
# Retrieving Ads for: (100459902106274, 'BR'), number 300
# 	 0 ads, total 965
# Retrieving Ads for: (100461681862985, 'BR'), number 301
# 	 0 ads, total 965
# Retrieving Ads for: (100462031858922, 'BR'), number 302
# 	 1 ads, total 966
# Retrieving Ads for: (100463018794349, 'BR'), number 303
# 	 0 ads, total 966
# Retrieving Ads for: (100467221879248, 'BR'), number 304
# 	 3 ads, total 969
# Retrieving Ads for: (100469365542976, 'BR'), number 305
# 	 0 ads, total 969
# Retrieving Ads for: (100470085776947, 'BR'), number 306
# 	 0 ads, total 969
# Retrieving Ads for: (100471782499807, 'BR'), number 307
# 	 0 ads, total 969
# Retrieving Ads for: (100474221848197, 'BR'), number 308
# 	 44 ads, total 1013
# Retrieving Ads for: (100475082251155, 'BR'), number 309
# 	 0 ads, total 1013
# Retrieving Ads for: (100475402294243, 'BR'), number 310
# 	 0 ads, total 1013
# Retrieving Ads for: (100478009254664, 'BR'), number 311
# 	 0 ads, total 1013
# Retrieving Ads for: (100478458356433, 'BR'), number 312
# 	 2 ads, total 1015
# Retrieving Ads for: (100479411618465, 'BR'), number 313
# 	 0 ads, total 1015
# Retrieving Ads for: (100480825586733, 'BR'), number 314
# 	 0 ads, total 1015
# Retrieving Ads for: (100481471619855, 'BR'), number 315
# 	 0 ads, total 1015
# Retrieving Ads for: (100484845123222, 'BR'), number 316
# 	 0 ads, total 1015
# Retrieving Ads for: (100485415109106, 'BR'), number 317
# 	 0 ads, total 1015
# Retrieving Ads for: (100485928025444, 'BR'), number 318
# 	 0 ads, total 1015
# Retrieving Ads for: (100487282049483, 'BR'), number 319
# 	 0 ads, total 1015
# Retrieving Ads for: (100489464695466, 'BR'), number 320
# 	 0 ads, total 1015
# Retrieving Ads for: (100493319325173, 'BR'), number 321
# 	 0 ads, total 1015
# Retrieving Ads for: (100505289289765, 'BR'), number 322
# 	 0 ads, total 1015
# Retrieving Ads for: (100505418999694, 'BR'), number 323
# 	 0 ads, total 1015
# Retrieving Ads for: (100506212659974, 'BR'), number 324
# 	 0 ads, total 1015
# Retrieving Ads for: (100509705346931, 'BR'), number 325
# 	 0 ads, total 1015
# Retrieving Ads for: (100513511837101, 'BR'), number 326
# 	 0 ads, total 1015
# Retrieving Ads for: (100513715984630, 'BR'), number 327
# 	 0 ads, total 1015
# Retrieving Ads for: (100514315816180, 'BR'), number 328
# 	 0 ads, total 1015
# Retrieving Ads for: (100514515013810, 'BR'), number 329
# 	 12 ads, total 1027
# Retrieving Ads for: (100516889134775, 'BR'), number 330
# 	 0 ads, total 1027
# Retrieving Ads for: (100518531513820, 'BR'), number 331
# 	 0 ads, total 1027
# Retrieving Ads for: (100518882637136, 'BR'), number 332
# 	 0 ads, total 1027
# Retrieving Ads for: (100520825048827, 'BR'), number 333
# 	 0 ads, total 1027
# Retrieving Ads for: (100522681454252, 'BR'), number 334
# 	 0 ads, total 1027
# Retrieving Ads for: (100526075546062, 'BR'), number 335
# 	 0 ads, total 1027
# Retrieving Ads for: (100527502548024, 'BR'), number 336
# 	 0 ads, total 1027
# Retrieving Ads for: (100529705553104, 'BR'), number 337
# 	 0 ads, total 1027
# Retrieving Ads for: (100529808604172, 'BR'), number 338
# 	 1 ads, total 1028
# Retrieving Ads for: (100531458484300, 'BR'), number 339
# 	 0 ads, total 1028
# Retrieving Ads for: (100535322029249, 'BR'), number 340
# 	 0 ads, total 1028
# Retrieving Ads for: (100535502255665, 'BR'), number 341
# 	 0 ads, total 1028
# Retrieving Ads for: (100538454704487, 'BR'), number 342
# 	 0 ads, total 1028
# Retrieving Ads for: (100538552171453, 'BR'), number 343
# 	 0 ads, total 1028
# Retrieving Ads for: (100539379230539, 'BR'), number 344
# 	 0 ads, total 1028
# Retrieving Ads for: (100543139270693, 'BR'), number 345
# 	 0 ads, total 1028
# Retrieving Ads for: (100544302137143, 'BR'), number 346
# 	 0 ads, total 1028
# Retrieving Ads for: (100545435114509, 'BR'), number 347
# 	 2 ads, total 1030
# Retrieving Ads for: (100545629193369, 'BR'), number 348
# 	 0 ads, total 1030
# Retrieving Ads for: (100547110728357, 'BR'), number 349
# 	 0 ads, total 1030
# Retrieving Ads for: (100552495636262, 'BR'), number 350
# 	 0 ads, total 1030
# Retrieving Ads for: (100556071772911, 'BR'), number 351
# 	 0 ads, total 1030
# Retrieving Ads for: (100556892345105, 'BR'), number 352
# 	 0 ads, total 1030
# Retrieving Ads for: (100560087991348, 'BR'), number 353
# 	 0 ads, total 1030
# Retrieving Ads for: (100564051910720, 'BR'), number 354
# 	 0 ads, total 1030
# Retrieving Ads for: (100566265896881, 'BR'), number 355
# 	 2 ads, total 1032
# Retrieving Ads for: (100566475029818, 'BR'), number 356
# 	 0 ads, total 1032
# Retrieving Ads for: (100566968288072, 'BR'), number 357
# 	 0 ads, total 1032
# Retrieving Ads for: (100569511735896, 'BR'), number 358
# 	 0 ads, total 1032
# Retrieving Ads for: (100573668896649, 'BR'), number 359
# 	 0 ads, total 1032
# Retrieving Ads for: (100575307986322, 'BR'), number 360
# 	 2 ads, total 1034
# Retrieving Ads for: (100581751600390, 'BR'), number 361
# 	 6 ads, total 1040
# Retrieving Ads for: (100581858875177, 'BR'), number 362
# 	 0 ads, total 1040
# Retrieving Ads for: (100585242638737, 'BR'), number 363
# 	 0 ads, total 1040
# Retrieving Ads for: (100588158756657, 'BR'), number 364
# 	 0 ads, total 1040
# Retrieving Ads for: (100593411881106, 'BR'), number 365
# 	 0 ads, total 1040
# Retrieving Ads for: (100595448671208, 'BR'), number 366
# 	 1 ads, total 1041
# Retrieving Ads for: (100598621394895, 'BR'), number 367
# 	 0 ads, total 1041
# Retrieving Ads for: (100600152567890, 'BR'), number 368
# 	 0 ads, total 1041
# Retrieving Ads for: (100602915032991, 'BR'), number 369
# 	 0 ads, total 1041
# Retrieving Ads for: (100605271766364, 'BR'), number 370
# 	 14 ads, total 1055
# Retrieving Ads for: (100607641644493, 'BR'), number 371
# 	 0 ads, total 1055
# Retrieving Ads for: (100615915548143, 'BR'), number 372
# 	 0 ads, total 1055
# Retrieving Ads for: (100616014675124, 'BR'), number 373
# 	 0 ads, total 1055
# Retrieving Ads for: (100617528897947, 'BR'), number 374
# 	 0 ads, total 1055
# Retrieving Ads for: (100617599250020, 'BR'), number 375
# 	 0 ads, total 1055
# Retrieving Ads for: (100617965272810, 'BR'), number 376
# 	 0 ads, total 1055
# Retrieving Ads for: (100618227441022, 'BR'), number 377
# 	 0 ads, total 1055
# Retrieving Ads for: (100618315361877, 'BR'), number 378
# 	 0 ads, total 1055
# Retrieving Ads for: (100620825680470, 'BR'), number 379
# 	 0 ads, total 1055
# Retrieving Ads for: (100623409031664, 'BR'), number 380
# 	 0 ads, total 1055
# Retrieving Ads for: (100624958792189, 'BR'), number 381
# 	 0 ads, total 1055
# Retrieving Ads for: (100626482555419, 'BR'), number 382
# 	 0 ads, total 1055
# Retrieving Ads for: (100629792069989, 'BR'), number 383
# 	 0 ads, total 1055
# Retrieving Ads for: (100633404952857, 'BR'), number 384
# 	 0 ads, total 1055
# Retrieving Ads for: (100634055117945, 'BR'), number 385
# 	 0 ads, total 1055
# Retrieving Ads for: (100635145858028, 'BR'), number 386
# 	 0 ads, total 1055
# Retrieving Ads for: (100637635096185, 'BR'), number 387
# 	 0 ads, total 1055
# Retrieving Ads for: (100638195840735, 'BR'), number 388
# 	 0 ads, total 1055
# Retrieving Ads for: (100641868339264, 'BR'), number 389
# 	 0 ads, total 1055
# Retrieving Ads for: (100643144901085, 'BR'), number 390
# 	 0 ads, total 1055
# Retrieving Ads for: (100644525056198, 'BR'), number 391
# 	 0 ads, total 1055
# Retrieving Ads for: (100645801775860, 'BR'), number 392
# 	 0 ads, total 1055
# Retrieving Ads for: (100647348432569, 'BR'), number 393
# 	 0 ads, total 1055
# Retrieving Ads for: (100649442486657, 'BR'), number 394
# 	 0 ads, total 1055
# Retrieving Ads for: (100651219156665, 'BR'), number 395
# 	 0 ads, total 1055
# Retrieving Ads for: (100652878947492, 'BR'), number 396
# 	 0 ads, total 1055
# Retrieving Ads for: (100652919239817, 'BR'), number 397
# 	 0 ads, total 1055
# Retrieving Ads for: (100653904746847, 'BR'), number 398
# 	 0 ads, total 1055
# Retrieving Ads for: (100657043922147, 'BR'), number 399
# 	 0 ads, total 1055
# Saving ..... batch 4, current id: 400
# Retrieving Ads for: (100659622079759, 'BR'), number 400
# 	 0 ads, total 1055
# Retrieving Ads for: (100661818730059, 'BR'), number 401
# 	 0 ads, total 1055
# Retrieving Ads for: (100663335130663, 'BR'), number 402
# 	 7 ads, total 1062
# Retrieving Ads for: (100664851580702, 'BR'), number 403
# 	 3 ads, total 1065
# Retrieving Ads for: (100665478811481, 'BR'), number 404
# 	 0 ads, total 1065
# Retrieving Ads for: (100667085826193, 'BR'), number 405
# 	 0 ads, total 1065
# Retrieving Ads for: (100668165170505, 'BR'), number 406
# 	 5 ads, total 1070
# Retrieving Ads for: (100669435386446, 'BR'), number 407
# 	 2 ads, total 1072
# Retrieving Ads for: (100671585819448, 'BR'), number 408
# 	 0 ads, total 1072
# Retrieving Ads for: (100672115885824, 'BR'), number 409
# 	 0 ads, total 1072
# Retrieving Ads for: (100675561333761, 'BR'), number 410
# 	 10 ads, total 1082
# Retrieving Ads for: (100681498935670, 'BR'), number 411
# 	 1 ads, total 1083
# Retrieving Ads for: (100682332101237, 'BR'), number 412
# 	 0 ads, total 1083
# Retrieving Ads for: (100689865413766, 'BR'), number 413
# 	 0 ads, total 1083
# Retrieving Ads for: (100690552356813, 'BR'), number 414
# 	 0 ads, total 1083
# Retrieving Ads for: (100692935469985, 'BR'), number 415
# 	 0 ads, total 1083
# Retrieving Ads for: (100697671985410, 'BR'), number 416
# 	 0 ads, total 1083
# Retrieving Ads for: (100698881704966, 'BR'), number 417
# 	 0 ads, total 1083
# Retrieving Ads for: (100700572286065, 'BR'), number 418
# 	 0 ads, total 1083
# Retrieving Ads for: (100704899231458, 'BR'), number 419
# 	 0 ads, total 1083
# Retrieving Ads for: (100706058941078, 'BR'), number 420
# 	 0 ads, total 1083
# Retrieving Ads for: (100706812506241, 'BR'), number 421
# 	 0 ads, total 1083
# Retrieving Ads for: (100707409013856, 'BR'), number 422
# 	 0 ads, total 1083
# Retrieving Ads for: (100709958332212, 'BR'), number 423
# 	 9 ads, total 1092
# Retrieving Ads for: (100710412444302, 'BR'), number 424
# 	 3 ads, total 1095
# Retrieving Ads for: (100711292644241, 'BR'), number 425
# 	 0 ads, total 1095
# Retrieving Ads for: (100713212642573, 'BR'), number 426
# 	 0 ads, total 1095
# Retrieving Ads for: (100715679098743, 'BR'), number 427
# 	 0 ads, total 1095
# Retrieving Ads for: (100716292514554, 'BR'), number 428
# 	 0 ads, total 1095
# Retrieving Ads for: (100717759182932, 'BR'), number 429
# 	 0 ads, total 1095
# Retrieving Ads for: (100719282065822, 'BR'), number 430
# 	 0 ads, total 1095
# Retrieving Ads for: (100722409286481, 'BR'), number 431
# 	 0 ads, total 1095
# Retrieving Ads for: (100722782289750, 'BR'), number 432
# 	 3 ads, total 1098
# Retrieving Ads for: (100723398684770, 'BR'), number 433
# 	 0 ads, total 1098
# Retrieving Ads for: (100725552156623, 'BR'), number 434
# 	 0 ads, total 1098
# Retrieving Ads for: (100726171542753, 'BR'), number 435
# 	 0 ads, total 1098
# Retrieving Ads for: (100735668926860, 'BR'), number 436
# 	 0 ads, total 1098
# Retrieving Ads for: (100737361919541, 'BR'), number 437
# 	 0 ads, total 1098
# Retrieving Ads for: (100737468176743, 'BR'), number 438
# 	 0 ads, total 1098
# Retrieving Ads for: (100739098981386, 'BR'), number 439
# 	 0 ads, total 1098
# Retrieving Ads for: (100742011804929, 'BR'), number 440
# 	 0 ads, total 1098
# Retrieving Ads for: (100746531614065, 'BR'), number 441
# 	 0 ads, total 1098
# Retrieving Ads for: (100747102607283, 'BR'), number 442
# 	 0 ads, total 1098
# Retrieving Ads for: (100747162161099, 'BR'), number 443
# 	 0 ads, total 1098
# Retrieving Ads for: (100749412577414, 'BR'), number 444
# 	 0 ads, total 1098
# Retrieving Ads for: (100749862063526, 'BR'), number 445
# 	 0 ads, total 1098
# Retrieving Ads for: (100751981706448, 'BR'), number 446
# 	 1 ads, total 1099
# Retrieving Ads for: (100752015284220, 'BR'), number 447
# 	 7 ads, total 1106
# Retrieving Ads for: (100754041649306, 'BR'), number 448
# 	 0 ads, total 1106
# Retrieving Ads for: (100754241369335, 'BR'), number 449
# 	 0 ads, total 1106
# Retrieving Ads for: (100757401653116, 'BR'), number 450
# 	 1 ads, total 1107
# Retrieving Ads for: (100759032238067, 'BR'), number 451
# 	 0 ads, total 1107
# Retrieving Ads for: (100760251909485, 'BR'), number 452
# 	 0 ads, total 1107
# Retrieving Ads for: (100761279304034, 'BR'), number 453
# 	 0 ads, total 1107
# Retrieving Ads for: (100762890036761, 'BR'), number 454
# 	 0 ads, total 1107
# Retrieving Ads for: (100769162611763, 'BR'), number 455
# 	 0 ads, total 1107
# Retrieving Ads for: (100769175814351, 'BR'), number 456
# 	 0 ads, total 1107
# Retrieving Ads for: (100771305928188, 'BR'), number 457
# 	 2 ads, total 1109
# Retrieving Ads for: (100771771932189, 'BR'), number 458
# 	 0 ads, total 1109
# Retrieving Ads for: (100773175175549, 'BR'), number 459
# 	 0 ads, total 1109
# Retrieving Ads for: (100773891887664, 'BR'), number 460
# 	 0 ads, total 1109
# Retrieving Ads for: (100776975344868, 'BR'), number 461
# 	 1 ads, total 1110
# Retrieving Ads for: (100780469302242, 'BR'), number 462
# 	 0 ads, total 1110
# Retrieving Ads for: (100781582363545, 'BR'), number 463
# 	 0 ads, total 1110
# Retrieving Ads for: (100783612524166, 'BR'), number 464
# 	 0 ads, total 1110
# Retrieving Ads for: (100784278297723, 'BR'), number 465
# 	 0 ads, total 1110
# Retrieving Ads for: (100784975087297, 'BR'), number 466
# 	 0 ads, total 1110
# Retrieving Ads for: (100786599279955, 'BR'), number 467
# 	 0 ads, total 1110
# Retrieving Ads for: (100789885896090, 'BR'), number 468
# 	 0 ads, total 1110
# Retrieving Ads for: (100791661913464, 'BR'), number 469
# 	 2 ads, total 1112
# Retrieving Ads for: (100793141878080, 'BR'), number 470
# 	 0 ads, total 1112
# Retrieving Ads for: (100796492544198, 'BR'), number 471
# 	 0 ads, total 1112
# Retrieving Ads for: (100797421370903, 'BR'), number 472
# 	 0 ads, total 1112
# Retrieving Ads for: (100797945004963, 'BR'), number 473
# 	 1 ads, total 1113
# Retrieving Ads for: (100798505455029, 'BR'), number 474
# 	 0 ads, total 1113
# Retrieving Ads for: (100804119272255, 'BR'), number 475
# 	 0 ads, total 1113
# Retrieving Ads for: (100808275850148, 'BR'), number 476
# 	 0 ads, total 1113
# Retrieving Ads for: (100811908368521, 'BR'), number 477
# 	 11 ads, total 1124
# Retrieving Ads for: (100814525036652, 'BR'), number 478
# 	 0 ads, total 1124
# Retrieving Ads for: (100818232195103, 'BR'), number 479
# 	 0 ads, total 1124
# Retrieving Ads for: (100822261659431, 'BR'), number 480
# 	 0 ads, total 1124
# Retrieving Ads for: (100822832557655, 'BR'), number 481
# 	 0 ads, total 1124
# Retrieving Ads for: (100823188001051, 'BR'), number 482
# 	 0 ads, total 1124
# Retrieving Ads for: (100824024850686, 'BR'), number 483
# 	 1 ads, total 1125
# Retrieving Ads for: (100828752534134, 'BR'), number 484
# 	 0 ads, total 1125
# Retrieving Ads for: (100829275599655, 'BR'), number 485
# 	 3 ads, total 1128
# Retrieving Ads for: (100831299226366, 'BR'), number 486
# 	 1 ads, total 1129
# Retrieving Ads for: (100832958381742, 'BR'), number 487
# 	 0 ads, total 1129
# Retrieving Ads for: (100833289177693, 'BR'), number 488
# 	 0 ads, total 1129
# Retrieving Ads for: (100833344855408, 'BR'), number 489
# 	 1 ads, total 1130
# Retrieving Ads for: (100834475854638, 'BR'), number 490
# 	 0 ads, total 1130
# Retrieving Ads for: (100837488416268, 'BR'), number 491
# 	 3 ads, total 1133
# Retrieving Ads for: (100837538260625, 'BR'), number 492
# 	 1 ads, total 1134
# Retrieving Ads for: (100840699258962, 'BR'), number 493
# 	 0 ads, total 1134
# Retrieving Ads for: (100848624927485, 'BR'), number 494
# 	 0 ads, total 1134
# Retrieving Ads for: (100849768829838, 'BR'), number 495
# 	 0 ads, total 1134
# Retrieving Ads for: (100852435109891, 'BR'), number 496
# 	 3 ads, total 1137
# Retrieving Ads for: (100862475882486, 'BR'), number 497
# 	 0 ads, total 1137
# Retrieving Ads for: (100866902468805, 'BR'), number 498
# 	 1 ads, total 1138
# Retrieving Ads for: (100872022457519, 'BR'), number 499
# 	 0 ads, total 1138
# Saving ..... batch 5, current id: 500
# Retrieving Ads for: (100872829289749, 'BR'), number 500
# 	 0 ads, total 1138
# Retrieving Ads for: (100876478951033, 'BR'), number 501
# 	 0 ads, total 1138
# Retrieving Ads for: (100879754920362, 'BR'), number 502
# 	 1 ads, total 1139
# Retrieving Ads for: (100884135106805, 'BR'), number 503
# 	 0 ads, total 1139
# Retrieving Ads for: (100884694811017, 'BR'), number 504
# 	 2 ads, total 1141
# Retrieving Ads for: (100885342422641, 'BR'), number 505
# 	 0 ads, total 1141
# Retrieving Ads for: (100887705486324, 'BR'), number 506
# 	 0 ads, total 1141
# Retrieving Ads for: (100889409258338, 'BR'), number 507
# 	 0 ads, total 1141
# Retrieving Ads for: (100890691434414, 'BR'), number 508
# 	 12 ads, total 1153
# Retrieving Ads for: (100895955392348, 'BR'), number 509
# 	 0 ads, total 1153
# Retrieving Ads for: (100904849119969, 'BR'), number 510
# 	 0 ads, total 1153
# Retrieving Ads for: (100908921449454, 'BR'), number 511
# 	 4 ads, total 1157
# Retrieving Ads for: (100910112493817, 'BR'), number 512
# 	 0 ads, total 1157
# Retrieving Ads for: (100911228332303, 'BR'), number 513
# 	 0 ads, total 1157
# Retrieving Ads for: (100913185701894, 'BR'), number 514
# 	 1 ads, total 1158
# Retrieving Ads for: (100917165324004, 'BR'), number 515
# 	 0 ads, total 1158
# Retrieving Ads for: (100917344935826, 'BR'), number 516
# 	 7 ads, total 1165
# Retrieving Ads for: (100919531776253, 'BR'), number 517
# 	 2 ads, total 1167
# Retrieving Ads for: (100921209182874, 'BR'), number 518
# 	 0 ads, total 1167
# Retrieving Ads for: (100923612530980, 'BR'), number 519
# 	 0 ads, total 1167
# Retrieving Ads for: (100928895925732, 'BR'), number 520
# 	 0 ads, total 1167
# Retrieving Ads for: (100930634646243, 'BR'), number 521
# 	 0 ads, total 1167
# Retrieving Ads for: (100933275345192, 'BR'), number 522
# 	 4 ads, total 1171
# Retrieving Ads for: (100934227257600, 'BR'), number 523
# 	 12 ads, total 1183
# Retrieving Ads for: (100939072439709, 'BR'), number 524
# 	 0 ads, total 1183
# Retrieving Ads for: (100939968279321, 'BR'), number 525
# 	 0 ads, total 1183
# Retrieving Ads for: (100943678850659, 'BR'), number 526
# 	 0 ads, total 1183
# Retrieving Ads for: (100945228762390, 'BR'), number 527
# 	 0 ads, total 1183
# Retrieving Ads for: (100945995420481, 'BR'), number 528
# 	 0 ads, total 1183
# Retrieving Ads for: (100949305633793, 'BR'), number 529
# 	 0 ads, total 1183
# Retrieving Ads for: (100951134723381, 'BR'), number 530
# 	 4 ads, total 1187
# Retrieving Ads for: (100953411423177, 'BR'), number 531
# 	 0 ads, total 1187
# Retrieving Ads for: (100958075578466, 'BR'), number 532
# 	 0 ads, total 1187
# Retrieving Ads for: (100968382011653, 'BR'), number 533
# 	 0 ads, total 1187
# Retrieving Ads for: (100970562118795, 'BR'), number 534
# 	 0 ads, total 1187
# Retrieving Ads for: (100980155340542, 'BR'), number 535
# 	 0 ads, total 1187
# Retrieving Ads for: (100982002070601, 'BR'), number 536
# 	 0 ads, total 1187
# Retrieving Ads for: (100983185460446, 'BR'), number 537
# 	 0 ads, total 1187
# Retrieving Ads for: (100987910054854, 'BR'), number 538
# 	 2 ads, total 1189
# Retrieving Ads for: (100988901911992, 'BR'), number 539
# 	 0 ads, total 1189
# Retrieving Ads for: (100995295631396, 'BR'), number 540
# 	 0 ads, total 1189
# Retrieving Ads for: (100996261797814, 'BR'), number 541
# 	 0 ads, total 1189
# Retrieving Ads for: (101000445063027, 'BR'), number 542
# 	 0 ads, total 1189
# Retrieving Ads for: (101004083330217, 'BR'), number 543
# 	 23 ads, total 1212
# Retrieving Ads for: (101004812231224, 'BR'), number 544
# 	 0 ads, total 1212
# Retrieving Ads for: (101006771678803, 'BR'), number 545
# 	 0 ads, total 1212
# Retrieving Ads for: (101007261498148, 'BR'), number 546
# 	 0 ads, total 1212
# Retrieving Ads for: (101008045698428, 'BR'), number 547
# 	 0 ads, total 1212
# Retrieving Ads for: (101009141772639, 'BR'), number 548
# 	 1 ads, total 1213
# Retrieving Ads for: (101009619289691, 'BR'), number 549
# 	 0 ads, total 1213
# Retrieving Ads for: (101012882409870, 'BR'), number 550
# 	 0 ads, total 1213
# Retrieving Ads for: (101014548385454, 'BR'), number 551
# 	 1 ads, total 1214
# Retrieving Ads for: (101017038299673, 'BR'), number 552
# 	 0 ads, total 1214
# Retrieving Ads for: (101020325035365, 'BR'), number 553
# 	 2 ads, total 1216
# Retrieving Ads for: (101021735692572, 'BR'), number 554
# 	 1 ads, total 1217
# Retrieving Ads for: (101021869005159, 'BR'), number 555
# 	 0 ads, total 1217
# Retrieving Ads for: (101023999217350, 'BR'), number 556
# 	 0 ads, total 1217
# Retrieving Ads for: (101025849131352, 'BR'), number 557
# 	 1 ads, total 1218
# Retrieving Ads for: (101031001337676, 'BR'), number 558
# 	 12 ads, total 1230
# Retrieving Ads for: (101031005874896, 'BR'), number 559
# 	 0 ads, total 1230
# Retrieving Ads for: (101032134578934, 'BR'), number 560
# 	 1 ads, total 1231
# Retrieving Ads for: (101037162532149, 'BR'), number 561
# 	 0 ads, total 1231
# Retrieving Ads for: (101038354967759, 'BR'), number 562
# 	 0 ads, total 1231
# Retrieving Ads for: (101042614950139, 'BR'), number 563
# 	 0 ads, total 1231
# Retrieving Ads for: (101044541892102, 'BR'), number 564
# 	 1 ads, total 1232
# Retrieving Ads for: (101044682414731, 'BR'), number 565
# 	 0 ads, total 1232
# Retrieving Ads for: (101047019241500, 'BR'), number 566
# 	 0 ads, total 1232
# Retrieving Ads for: (101048011531035, 'BR'), number 567
# 	 0 ads, total 1232
# Retrieving Ads for: (101052615544389, 'BR'), number 568
# 	 5 ads, total 1237
# Retrieving Ads for: (101052885094253, 'BR'), number 569
# 	 0 ads, total 1237
# Retrieving Ads for: (101056649075799, 'BR'), number 570
# 	 2 ads, total 1239
# Retrieving Ads for: (101058212479255, 'BR'), number 571
# 	 0 ads, total 1239
# Retrieving Ads for: (101058298713844, 'BR'), number 572
# 	 25 ads, total 1264
# Retrieving Ads for: (101058678318082, 'BR'), number 573
# 	 8 ads, total 1272
# Retrieving Ads for: (101059929156000, 'BR'), number 574
# 	 0 ads, total 1272
# Retrieving Ads for: (101061161765332, 'BR'), number 575
# 	 0 ads, total 1272
# Retrieving Ads for: (101061702530233, 'BR'), number 576
# 	 0 ads, total 1272
# Retrieving Ads for: (101065912488489, 'BR'), number 577
# 	 0 ads, total 1272
# Retrieving Ads for: (101072822528185, 'BR'), number 578
# 	 0 ads, total 1272
# Retrieving Ads for: (101074069039395, 'BR'), number 579
# 	 0 ads, total 1272
# Retrieving Ads for: (101079245860680, 'BR'), number 580
# 	 0 ads, total 1272
# Retrieving Ads for: (101083959932439, 'BR'), number 581
# 	 0 ads, total 1272
# Retrieving Ads for: (101084162055822, 'BR'), number 582
# 	 38 ads, total 1310
# Retrieving Ads for: (101094469141590, 'BR'), number 583
# 	 0 ads, total 1310
# Retrieving Ads for: (101094885884934, 'BR'), number 584
# 	 1 ads, total 1311
# Retrieving Ads for: (101095219032856, 'BR'), number 585
# 	 0 ads, total 1311
# Retrieving Ads for: (101099098682858, 'BR'), number 586
# 	 0 ads, total 1311
# Retrieving Ads for: (101102943299198, 'BR'), number 587
# 	 0 ads, total 1311
# Retrieving Ads for: (101103175209935, 'BR'), number 588
# 	 0 ads, total 1311
# Retrieving Ads for: (101106645637982, 'BR'), number 589
# 	 0 ads, total 1311
# Retrieving Ads for: (101117081453329, 'BR'), number 590
# 	 0 ads, total 1311
# Retrieving Ads for: (101122634999087, 'BR'), number 591
# 	 2 ads, total 1313
# Retrieving Ads for: (101123869206963, 'BR'), number 592
# 	 0 ads, total 1313
# Retrieving Ads for: (101127191780974, 'BR'), number 593
# 	 0 ads, total 1313
# Retrieving Ads for: (101129045871832, 'BR'), number 594
# 	 0 ads, total 1313
# Retrieving Ads for: (101130855300816, 'BR'), number 595
# 	 0 ads, total 1313
# Retrieving Ads for: (101132704939097, 'BR'), number 596
# 	 938 ads, total 2251
# Retrieving Ads for: (101135168803699, 'BR'), number 597
# 	 0 ads, total 2251
# Retrieving Ads for: (101137398311003, 'BR'), number 598
# 	 6 ads, total 2257
# Retrieving Ads for: (101137638440402, 'BR'), number 599
# 	 2 ads, total 2259
# Saving ..... batch 6, current id: 600
# Retrieving Ads for: (101139728029691, 'BR'), number 600
# 	 1 ads, total 2260
# Retrieving Ads for: (101141335930143, 'BR'), number 601
# 	 0 ads, total 2260
# Retrieving Ads for: (101149931673756, 'BR'), number 602
# 	 2 ads, total 2262
# Retrieving Ads for: (101149942378956, 'BR'), number 603
# 	 0 ads, total 2262
# Retrieving Ads for: (101151815885813, 'BR'), number 604
# 	 3 ads, total 2265
# Retrieving Ads for: (101154055878218, 'BR'), number 605
# 	 0 ads, total 2265
# Retrieving Ads for: (101155209069655, 'BR'), number 606
# 	 0 ads, total 2265
# Retrieving Ads for: (101156889079034, 'BR'), number 607
# 	 2 ads, total 2267
# Retrieving Ads for: (101157852100381, 'BR'), number 608
# 	 0 ads, total 2267
# Retrieving Ads for: (101162788644594, 'BR'), number 609
# 	 0 ads, total 2267
# Retrieving Ads for: (101167831846498, 'BR'), number 610
# 	 0 ads, total 2267
# Retrieving Ads for: (101170604801117, 'BR'), number 611
# 	 2 ads, total 2269
# Retrieving Ads for: (101171344603489, 'BR'), number 612
# 	 1 ads, total 2270
# Retrieving Ads for: (101177142518764, 'BR'), number 613
# 	 0 ads, total 2270
# Retrieving Ads for: (101177418280225, 'BR'), number 614
# 	 1 ads, total 2271
# Retrieving Ads for: (101179259239317, 'BR'), number 615
# 	 0 ads, total 2271
# Retrieving Ads for: (101179625001334, 'BR'), number 616
# 	 14 ads, total 2285
# Retrieving Ads for: (101181458551859, 'BR'), number 617
# 	 0 ads, total 2285
# ...
# 	 0 ads, total 36983
# Retrieving Ads for: (307083786329867, 'BR'), number 5774
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=307083786329867&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 36983
# Retrieving Ads for: (307195902697120, 'BR'), number 5775
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=307195902697120&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 36983
# Retrieving Ads for: (307461629321693, 'BR'), number 5776
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=307461629321693&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 36983
# Retrieving Ads for: (307630213183248, 'BR'), number 5777
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=307630213183248&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 36983
# Retrieving Ads for: (308053373034619, 'BR'), number 5778
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=308053373034619&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 36983
# Retrieving Ads for: (308065689820712, 'BR'), number 5779
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=308065689820712&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 36983
# Retrieving Ads for: (308132539372437, 'BR'), number 5780
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=308132539372437&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 36983
# Retrieving Ads for: (308211949550826, 'BR'), number 5781
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=308211949550826&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 36983
# Retrieving Ads for: (308473539215980, 'BR'), number 5782
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=308473539215980&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 36983
# Retrieving Ads for: (308593399238061, 'BR'), number 5783
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=308593399238061&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 36983
# Retrieving Ads for: (308838735886303, 'BR'), number 5784
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=308838735886303&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 36983
# Retrieving Ads for: (309064629217971, 'BR'), number 5785
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=309064629217971&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 36983
# Retrieving Ads for: (309124326396684, 'BR'), number 5786
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-053d614ccbb3> in <module>
#      16     print(f'Retrieving Ads for: {ct}, number {i}')
#      17     try:
# ---> 18         ads = obtain_ads_page_id(ct[0], ct[1], FIELDS, ACCESS_TOKEN)
#      19         total_ads += len(ads)
#      20         print('\t', len(ads), 'ads, total', total_ads)
#
# <ipython-input-4-c5db6f1406fa> in obtain_ads_page_id(page_id, country, fields, access_token)
#       8               'ad_reached_countries': [country]}
#       9
# ---> 10     ads = read_endpoint('', 'ads_archive', access_token, fields, params, 30000)
#      11
#      12     for ad in ads: # add additional information
#
# <ipython-input-2-245143b61514> in read_endpoint(id_, endpoint, access_token, fields, params, n)
#      31     q = dict({'access_token': access_token, 'fields': ','.join(fields)}, **params)
#      32     if id_ == '':
# ---> 33         response = request(method='GET', resource=endpoint, q=q)
#      34     else:
#      35         response = request(method='GET', resource=f'{id_}/{endpoint}', q=q)
#
# <ipython-input-2-245143b61514> in request(method, full_url, resource, q)
#      11             response = requests.get(full_url)
#      12         if resource:
# ---> 13             response = requests.get(f'https://graph.facebook.com/v13.0/{resource}', q)
#      14         if response.status_code==400:
#      15             print(f'Error Status Code 400 for URL: {response.url}')
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
total_ads
len(all_ads)
# Out:
# 8856

# %%
i = 5701
for ct in product(page_id_br, ['BR']):
    if i%100 == 0:
        print(f'Saving ..... batch {i//100}, current id: {i}')
        save_pickle(f'{raw_dir}/adlibrary_ads_br_90_days_{i//1000}.pkl', all_ads)
        if i%1000 == 0:
            all_ads = []
    print(f'Retrieving Ads for: {ct}, number {i}')
    try:
        ads = obtain_ads_page_id(ct[0], ct[1], FIELDS, ACCESS_TOKEN)
        total_ads += len(ads)
        print('\t', len(ads), 'ads, total', total_ads)
        all_ads.extend(ads)
        i+=1
    except Exception as e:
        print('Some error happened:', e)
        
save_pickle(f'{raw_dir}/adlibrary_ads_br_90_days_{i//1000}.pkl', all_ads)
print(f'Retrieved {len(all_ads)} ads')
# Out:
# Retrieving Ads for: (5647744585, 'BR'), number 5701
# 	 3 ads, total 36986
# Retrieving Ads for: (6085906515, 'BR'), number 5702
# 	 0 ads, total 36986
# Retrieving Ads for: (7619396355, 'BR'), number 5703
# 	 0 ads, total 36986
# Retrieving Ads for: (7783116506, 'BR'), number 5704
# 	 0 ads, total 36986
# Retrieving Ads for: (8539814909, 'BR'), number 5705
# 	 0 ads, total 36986
# Retrieving Ads for: (12185972707, 'BR'), number 5706
# 	 0 ads, total 36986
# Retrieving Ads for: (17043549797, 'BR'), number 5707
# 	 4 ads, total 36990
# Retrieving Ads for: (22760563564, 'BR'), number 5708
# 	 2 ads, total 36992
# Retrieving Ads for: (24287259392, 'BR'), number 5709
# 	 0 ads, total 36992
# Retrieving Ads for: (26897053321, 'BR'), number 5710
# 	 0 ads, total 36992
# Retrieving Ads for: (27678194634, 'BR'), number 5711
# 	 2 ads, total 36994
# Retrieving Ads for: (31292782350, 'BR'), number 5712
# 	 26 ads, total 37020
# Retrieving Ads for: (36085812354, 'BR'), number 5713
# 	 2 ads, total 37022
# Retrieving Ads for: (39644961958, 'BR'), number 5714
# 	 0 ads, total 37022
# Retrieving Ads for: (39759254594, 'BR'), number 5715
# 	 0 ads, total 37022
# Retrieving Ads for: (44409199155, 'BR'), number 5716
# 	 4 ads, total 37026
# Retrieving Ads for: (45628695543, 'BR'), number 5717
# 	 0 ads, total 37026
# Retrieving Ads for: (46847613149, 'BR'), number 5718
# 	 0 ads, total 37026
# Retrieving Ads for: (47565718326, 'BR'), number 5719
# 	 0 ads, total 37026
# Retrieving Ads for: (55805876860, 'BR'), number 5720
# 	 0 ads, total 37026
# Retrieving Ads for: (56777943052, 'BR'), number 5721
# 	 0 ads, total 37026
# Retrieving Ads for: (68793499001, 'BR'), number 5722
# 	 16 ads, total 37042
# Retrieving Ads for: (70877580782, 'BR'), number 5723
# 	 0 ads, total 37042
# Retrieving Ads for: (71613839321, 'BR'), number 5724
# 	 6 ads, total 37048
# Retrieving Ads for: (72149536933, 'BR'), number 5725
# 	 1 ads, total 37049
# Retrieving Ads for: (73620441975, 'BR'), number 5726
# 	 0 ads, total 37049
# Retrieving Ads for: (73970658023, 'BR'), number 5727
# 	 12 ads, total 37061
# Retrieving Ads for: (77403447721, 'BR'), number 5728
# 	 0 ads, total 37061
# Retrieving Ads for: (78066290984, 'BR'), number 5729
# 	 0 ads, total 37061
# Retrieving Ads for: (79511407410, 'BR'), number 5730
# 	 1 ads, total 37062
# Retrieving Ads for: (80591352579, 'BR'), number 5731
# 	 0 ads, total 37062
# Retrieving Ads for: (85291563763, 'BR'), number 5732
# 	 1 ads, total 37063
# Retrieving Ads for: (88054178212, 'BR'), number 5733
# 	 0 ads, total 37063
# Retrieving Ads for: (89859403188, 'BR'), number 5734
# 	 13 ads, total 37076
# Retrieving Ads for: (90740178223, 'BR'), number 5735
# 	 11 ads, total 37087
# Retrieving Ads for: (91754571355, 'BR'), number 5736
# 	 0 ads, total 37087
# Retrieving Ads for: (92227023652, 'BR'), number 5737
# 	 1 ads, total 37088
# Retrieving Ads for: (92288319748, 'BR'), number 5738
# 	 2 ads, total 37090
# Retrieving Ads for: (93745060700, 'BR'), number 5739
# 	 1 ads, total 37091
# Retrieving Ads for: (97323256442, 'BR'), number 5740
# 	 1 ads, total 37092
# Retrieving Ads for: (101095043361, 'BR'), number 5741
# 	 0 ads, total 37092
# Retrieving Ads for: (104102576882, 'BR'), number 5742
# 	 2 ads, total 37094
# Retrieving Ads for: (105015822454, 'BR'), number 5743
# 	 0 ads, total 37094
# Retrieving Ads for: (105181842883, 'BR'), number 5744
# 	 0 ads, total 37094
# Retrieving Ads for: (107286223667, 'BR'), number 5745
# 	 1 ads, total 37095
# Retrieving Ads for: (109597815616, 'BR'), number 5746
# 	 80 ads, total 37175
# Retrieving Ads for: (109789152161, 'BR'), number 5747
# 	 71 ads, total 37246
# Retrieving Ads for: (111361091313, 'BR'), number 5748
# 	 0 ads, total 37246
# Retrieving Ads for: (113184216339, 'BR'), number 5749
# 	 0 ads, total 37246
# Retrieving Ads for: (113455336434, 'BR'), number 5750
# 	 0 ads, total 37246
# Retrieving Ads for: (114287484617, 'BR'), number 5751
# 	 0 ads, total 37246
# Retrieving Ads for: (115137755498, 'BR'), number 5752
# 	 1 ads, total 37247
# Retrieving Ads for: (119405895873, 'BR'), number 5753
# 	 0 ads, total 37247
# Retrieving Ads for: (125565308750, 'BR'), number 5754
# 	 1 ads, total 37248
# Retrieving Ads for: (126052760507, 'BR'), number 5755
# 	 6 ads, total 37254
# Retrieving Ads for: (130097745578, 'BR'), number 5756
# 	 6 ads, total 37260
# Retrieving Ads for: (131189377574, 'BR'), number 5757
# 	 2 ads, total 37262
# Retrieving Ads for: (132674867692, 'BR'), number 5758
# 	 0 ads, total 37262
# Retrieving Ads for: (138341914612, 'BR'), number 5759
# 	 0 ads, total 37262
# Retrieving Ads for: (140879763603, 'BR'), number 5760
# 	 0 ads, total 37262
# Retrieving Ads for: (141287742160, 'BR'), number 5761
# 	 2 ads, total 37264
# Retrieving Ads for: (147846104842, 'BR'), number 5762
# 	 1 ads, total 37265
# Retrieving Ads for: (149079507181, 'BR'), number 5763
# 	 0 ads, total 37265
# Retrieving Ads for: (159097782605, 'BR'), number 5764
# 	 0 ads, total 37265
# Retrieving Ads for: (159103797542, 'BR'), number 5765
# 	 2 ads, total 37267
# Retrieving Ads for: (161409009309, 'BR'), number 5766
# 	 0 ads, total 37267
# Retrieving Ads for: (165476513965, 'BR'), number 5767
# 	 0 ads, total 37267
# Retrieving Ads for: (174547583316, 'BR'), number 5768
# 	 0 ads, total 37267
# Retrieving Ads for: (176871714093, 'BR'), number 5769
# 	 0 ads, total 37267
# Retrieving Ads for: (180050601590, 'BR'), number 5770
# 	 0 ads, total 37267
# Retrieving Ads for: (182916843151, 'BR'), number 5771
# 	 0 ads, total 37267
# Retrieving Ads for: (185875761943, 'BR'), number 5772
# 	 155 ads, total 37422
# Retrieving Ads for: (189269999292, 'BR'), number 5773
# 	 0 ads, total 37422
# Retrieving Ads for: (191032704071, 'BR'), number 5774
# 	 1 ads, total 37423
# Retrieving Ads for: (200773697350, 'BR'), number 5775
# 	 0 ads, total 37423
# Retrieving Ads for: (205362186029, 'BR'), number 5776
# 	 12 ads, total 37435
# Retrieving Ads for: (216311481960, 'BR'), number 5777
# 	 3 ads, total 37438
# Retrieving Ads for: (220353389618, 'BR'), number 5778
# 	 0 ads, total 37438
# Retrieving Ads for: (224335474975, 'BR'), number 5779
# 	 0 ads, total 37438
# Retrieving Ads for: (233826257775, 'BR'), number 5780
# 	 0 ads, total 37438
# Retrieving Ads for: (239982637475, 'BR'), number 5781
# 	 0 ads, total 37438
# Retrieving Ads for: (240734989375, 'BR'), number 5782
# 	 0 ads, total 37438
# Retrieving Ads for: (249425191947, 'BR'), number 5783
# 	 0 ads, total 37438
# Retrieving Ads for: (260107092232, 'BR'), number 5784
# 	 0 ads, total 37438
# Retrieving Ads for: (262370800536, 'BR'), number 5785
# 	 0 ads, total 37438
# Retrieving Ads for: (267813379784, 'BR'), number 5786
# 	 0 ads, total 37438
# Retrieving Ads for: (292780334633, 'BR'), number 5787
# 	 0 ads, total 37438
# Retrieving Ads for: (295940566431, 'BR'), number 5788
# 	 0 ads, total 37438
# Retrieving Ads for: (299102027305, 'BR'), number 5789
# 	 0 ads, total 37438
# Retrieving Ads for: (300746227635, 'BR'), number 5790
# 	 0 ads, total 37438
# Retrieving Ads for: (312641429340, 'BR'), number 5791
# 	 0 ads, total 37438
# Retrieving Ads for: (315035249496, 'BR'), number 5792
# 	 0 ads, total 37438
# Retrieving Ads for: (315543515306, 'BR'), number 5793
# 	 1 ads, total 37439
# Retrieving Ads for: (315603771494, 'BR'), number 5794
# 	 1 ads, total 37440
# Retrieving Ads for: (316496640057, 'BR'), number 5795
# 	 2 ads, total 37442
# Retrieving Ads for: (330207313222, 'BR'), number 5796
# 	 1 ads, total 37443
# Retrieving Ads for: (333776090315, 'BR'), number 5797
# 	 106 ads, total 37549
# Retrieving Ads for: (334445814722, 'BR'), number 5798
# 	 0 ads, total 37549
# Retrieving Ads for: (347265340270, 'BR'), number 5799
# 	 2 ads, total 37551
# Saving ..... batch 58, current id: 5800
# Retrieving Ads for: (347742876973, 'BR'), number 5800
# 	 0 ads, total 37551
# Retrieving Ads for: (364966627159, 'BR'), number 5801
# 	 0 ads, total 37551
# Retrieving Ads for: (376243256164, 'BR'), number 5802
# 	 0 ads, total 37551
# Retrieving Ads for: (470736210584, 'BR'), number 5803
# 	 0 ads, total 37551
# Retrieving Ads for: (470750715303, 'BR'), number 5804
# 	 56 ads, total 37607
# Retrieving Ads for: (100063501289209, 'BR'), number 5805
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=100063501289209&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 37607
# Retrieving Ads for: (100076366921990, 'BR'), number 5806
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=100076366921990&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 37607
# Retrieving Ads for: (100100305866299, 'BR'), number 5807
# 	 0 ads, total 37607
# Retrieving Ads for: (100103949013499, 'BR'), number 5808
# 	 0 ads, total 37607
# Retrieving Ads for: (100106159009340, 'BR'), number 5809
# 	 3 ads, total 37610
# Retrieving Ads for: (100113698236734, 'BR'), number 5810
# 	 3 ads, total 37613
# Retrieving Ads for: (100113751630378, 'BR'), number 5811
# 	 3 ads, total 37616
# Retrieving Ads for: (100114543363891, 'BR'), number 5812
# 	 0 ads, total 37616
# Retrieving Ads for: (100114559384425, 'BR'), number 5813
# 	 1 ads, total 37617
# Retrieving Ads for: (100115701334781, 'BR'), number 5814
# 	 0 ads, total 37617
# Retrieving Ads for: (100117012467065, 'BR'), number 5815
# 	 0 ads, total 37617
# Retrieving Ads for: (100117348854103, 'BR'), number 5816
# 	 0 ads, total 37617
# Retrieving Ads for: (100119095165423, 'BR'), number 5817
# 	 2 ads, total 37619
# Retrieving Ads for: (100120285928399, 'BR'), number 5818
# 	 0 ads, total 37619
# Retrieving Ads for: (100121991741943, 'BR'), number 5819
# 	 5 ads, total 37624
# Retrieving Ads for: (100130812154502, 'BR'), number 5820
# 	 0 ads, total 37624
# Retrieving Ads for: (100133892425014, 'BR'), number 5821
# 	 0 ads, total 37624
# Retrieving Ads for: (100134025955843, 'BR'), number 5822
# 	 2 ads, total 37626
# Retrieving Ads for: (100134385923671, 'BR'), number 5823
# 	 0 ads, total 37626
# Retrieving Ads for: (100136441554971, 'BR'), number 5824
# 	 0 ads, total 37626
# Retrieving Ads for: (100137228199210, 'BR'), number 5825
# 	 0 ads, total 37626
# Retrieving Ads for: (100139882504540, 'BR'), number 5826
# 	 0 ads, total 37626
# Retrieving Ads for: (100140259335224, 'BR'), number 5827
# 	 1 ads, total 37627
# Retrieving Ads for: (100140939244476, 'BR'), number 5828
# 	 0 ads, total 37627
# Retrieving Ads for: (100142305930876, 'BR'), number 5829
# 	 3 ads, total 37630
# Retrieving Ads for: (100142328690775, 'BR'), number 5830
# 	 0 ads, total 37630
# Retrieving Ads for: (100142459164291, 'BR'), number 5831
# 	 0 ads, total 37630
# Retrieving Ads for: (100145909336494, 'BR'), number 5832
# 	 0 ads, total 37630
# Retrieving Ads for: (100148871956220, 'BR'), number 5833
# 	 0 ads, total 37630
# Retrieving Ads for: (100149625995444, 'BR'), number 5834
# 	 0 ads, total 37630
# Retrieving Ads for: (100149818404464, 'BR'), number 5835
# 	 17 ads, total 37647
# Retrieving Ads for: (100150228376589, 'BR'), number 5836
# 	 102 ads, total 37749
# Retrieving Ads for: (100153769212360, 'BR'), number 5837
# 	 0 ads, total 37749
# Retrieving Ads for: (100160871738919, 'BR'), number 5838
# 	 0 ads, total 37749
# Retrieving Ads for: (100161351991012, 'BR'), number 5839
# 	 2 ads, total 37751
# Retrieving Ads for: (100162112686423, 'BR'), number 5840
# 	 0 ads, total 37751
# Retrieving Ads for: (100162448248917, 'BR'), number 5841
# 	 0 ads, total 37751
# Retrieving Ads for: (100162705232292, 'BR'), number 5842
# 	 0 ads, total 37751
# Retrieving Ads for: (100162738241949, 'BR'), number 5843
# 	 5 ads, total 37756
# Retrieving Ads for: (100165724716819, 'BR'), number 5844
# 	 0 ads, total 37756
# Retrieving Ads for: (100166062605045, 'BR'), number 5845
# 	 0 ads, total 37756
# Retrieving Ads for: (100166375147375, 'BR'), number 5846
# 	 4 ads, total 37760
# Retrieving Ads for: (100166632533194, 'BR'), number 5847
# 	 0 ads, total 37760
# Retrieving Ads for: (100168485433453, 'BR'), number 5848
# 	 0 ads, total 37760
# Retrieving Ads for: (100172352675383, 'BR'), number 5849
# 	 0 ads, total 37760
# Retrieving Ads for: (100173495228851, 'BR'), number 5850
# 	 0 ads, total 37760
# Retrieving Ads for: (100174255950895, 'BR'), number 5851
# 	 0 ads, total 37760
# Retrieving Ads for: (100178435901111, 'BR'), number 5852
# 	 0 ads, total 37760
# Retrieving Ads for: (100179145489145, 'BR'), number 5853
# 	 2 ads, total 37762
# Retrieving Ads for: (100182702588628, 'BR'), number 5854
# 	 0 ads, total 37762
# Retrieving Ads for: (100184808436340, 'BR'), number 5855
# 	 1 ads, total 37763
# Retrieving Ads for: (100189585116003, 'BR'), number 5856
# 	 0 ads, total 37763
# Retrieving Ads for: (100191035056570, 'BR'), number 5857
# 	 0 ads, total 37763
# Retrieving Ads for: (100191775024351, 'BR'), number 5858
# 	 3 ads, total 37766
# Retrieving Ads for: (100192575152720, 'BR'), number 5859
# 	 5 ads, total 37771
# Retrieving Ads for: (100195245992854, 'BR'), number 5860
# 	 0 ads, total 37771
# Retrieving Ads for: (100197638345022, 'BR'), number 5861
# 	 1 ads, total 37772
# Retrieving Ads for: (100200362171068, 'BR'), number 5862
# 	 3 ads, total 37775
# Retrieving Ads for: (100202634981422, 'BR'), number 5863
# 	 0 ads, total 37775
# Retrieving Ads for: (100207665005656, 'BR'), number 5864
# 	 1 ads, total 37776
# Retrieving Ads for: (100209282298570, 'BR'), number 5865
# 	 0 ads, total 37776
# Retrieving Ads for: (100211855097278, 'BR'), number 5866
# 	 0 ads, total 37776
# Retrieving Ads for: (100212561752911, 'BR'), number 5867
# 	 0 ads, total 37776
# Retrieving Ads for: (100213982559177, 'BR'), number 5868
# 	 0 ads, total 37776
# Retrieving Ads for: (100217788465087, 'BR'), number 5869
# 	 0 ads, total 37776
# Retrieving Ads for: (100219245857449, 'BR'), number 5870
# 	 0 ads, total 37776
# Retrieving Ads for: (100219619129181, 'BR'), number 5871
# 	 0 ads, total 37776
# Retrieving Ads for: (100219665411715, 'BR'), number 5872
# 	 0 ads, total 37776
# Retrieving Ads for: (100221835178558, 'BR'), number 5873
# 	 0 ads, total 37776
# Retrieving Ads for: (100222508113288, 'BR'), number 5874
# 	 0 ads, total 37776
# Retrieving Ads for: (100224626022749, 'BR'), number 5875
# 	 0 ads, total 37776
# Retrieving Ads for: (100225342578975, 'BR'), number 5876
# 	 0 ads, total 37776
# Retrieving Ads for: (100225352113621, 'BR'), number 5877
# 	 0 ads, total 37776
# Retrieving Ads for: (100227685834492, 'BR'), number 5878
# 	 0 ads, total 37776
# Retrieving Ads for: (100229085517346, 'BR'), number 5879
# 	 0 ads, total 37776
# Retrieving Ads for: (100229324876697, 'BR'), number 5880
# 	 0 ads, total 37776
# Retrieving Ads for: (100229475912903, 'BR'), number 5881
# 	 0 ads, total 37776
# Retrieving Ads for: (100230579224406, 'BR'), number 5882
# 	 0 ads, total 37776
# Retrieving Ads for: (100236928781937, 'BR'), number 5883
# 	 0 ads, total 37776
# Retrieving Ads for: (100238429289981, 'BR'), number 5884
# 	 0 ads, total 37776
# Retrieving Ads for: (100240962631974, 'BR'), number 5885
# 	 1 ads, total 37777
# Retrieving Ads for: (100243131390334, 'BR'), number 5886
# 	 0 ads, total 37777
# Retrieving Ads for: (100248249278128, 'BR'), number 5887
# 	 0 ads, total 37777
# Retrieving Ads for: (100257088166537, 'BR'), number 5888
# 	 0 ads, total 37777
# Retrieving Ads for: (100258439238516, 'BR'), number 5889
# 	 0 ads, total 37777
# Retrieving Ads for: (100260985221269, 'BR'), number 5890
# 	 0 ads, total 37777
# Retrieving Ads for: (100264302662053, 'BR'), number 5891
# 	 0 ads, total 37777
# Retrieving Ads for: (100265121565521, 'BR'), number 5892
# 	 12 ads, total 37789
# Retrieving Ads for: (100265282588841, 'BR'), number 5893
# 	 0 ads, total 37789
# Retrieving Ads for: (100265562609843, 'BR'), number 5894
# 	 0 ads, total 37789
# Retrieving Ads for: (100266515129036, 'BR'), number 5895
# 	 0 ads, total 37789
# Retrieving Ads for: (100268101723896, 'BR'), number 5896
# 	 0 ads, total 37789
# Retrieving Ads for: (100270759072188, 'BR'), number 5897
# 	 1 ads, total 37790
# Retrieving Ads for: (100271692648521, 'BR'), number 5898
# 	 0 ads, total 37790
# Retrieving Ads for: (100271922263757, 'BR'), number 5899
# 	 0 ads, total 37790
# Saving ..... batch 59, current id: 5900
# Retrieving Ads for: (100272378719563, 'BR'), number 5900
# 	 0 ads, total 37790
# Retrieving Ads for: (100273016728909, 'BR'), number 5901
# 	 0 ads, total 37790
# Retrieving Ads for: (100273806001620, 'BR'), number 5902
# 	 0 ads, total 37790
# Retrieving Ads for: (100275083494691, 'BR'), number 5903
# 	 16 ads, total 37806
# Retrieving Ads for: (100275178876108, 'BR'), number 5904
# 	 0 ads, total 37806
# Retrieving Ads for: (100279589321213, 'BR'), number 5905
# 	 0 ads, total 37806
# Retrieving Ads for: (100281858452239, 'BR'), number 5906
# 	 0 ads, total 37806
# Retrieving Ads for: (100282012031785, 'BR'), number 5907
# 	 0 ads, total 37806
# Retrieving Ads for: (100283312645780, 'BR'), number 5908
# 	 0 ads, total 37806
# Retrieving Ads for: (100285212597283, 'BR'), number 5909
# 	 0 ads, total 37806
# Retrieving Ads for: (100293621704902, 'BR'), number 5910
# 	 0 ads, total 37806
# Retrieving Ads for: (100294668152772, 'BR'), number 5911
# 	 0 ads, total 37806
# Retrieving Ads for: (100295402695450, 'BR'), number 5912
# 	 1 ads, total 37807
# Retrieving Ads for: (100296319269692, 'BR'), number 5913
# 	 1 ads, total 37808
# Retrieving Ads for: (100300555155590, 'BR'), number 5914
# 	 0 ads, total 37808
# Retrieving Ads for: (100306552231937, 'BR'), number 5915
# 	 1 ads, total 37809
# Retrieving Ads for: (100308005591904, 'BR'), number 5916
# 	 0 ads, total 37809
# Retrieving Ads for: (100308035003468, 'BR'), number 5917
# 	 0 ads, total 37809
# Retrieving Ads for: (100308622165800, 'BR'), number 5918
# 	 0 ads, total 37809
# Retrieving Ads for: (100308948548999, 'BR'), number 5919
# 	 0 ads, total 37809
# Retrieving Ads for: (100311892627240, 'BR'), number 5920
# 	 0 ads, total 37809
# Retrieving Ads for: (100312752604845, 'BR'), number 5921
# 	 0 ads, total 37809
# Retrieving Ads for: (100313605093201, 'BR'), number 5922
# 	 1 ads, total 37810
# Retrieving Ads for: (100318709287418, 'BR'), number 5923
# 	 0 ads, total 37810
# Retrieving Ads for: (100321494992982, 'BR'), number 5924
# 	 1 ads, total 37811
# Retrieving Ads for: (100323028514837, 'BR'), number 5925
# 	 0 ads, total 37811
# Retrieving Ads for: (100328205111009, 'BR'), number 5926
# 	 0 ads, total 37811
# Retrieving Ads for: (100328575160090, 'BR'), number 5927
# 	 0 ads, total 37811
# Retrieving Ads for: (100328766978187, 'BR'), number 5928
# 	 10 ads, total 37821
# Retrieving Ads for: (100331819324783, 'BR'), number 5929
# 	 0 ads, total 37821
# Retrieving Ads for: (100332882670597, 'BR'), number 5930
# 	 0 ads, total 37821
# Retrieving Ads for: (100335762124018, 'BR'), number 5931
# 	 0 ads, total 37821
# Retrieving Ads for: (100336898694570, 'BR'), number 5932
# 	 0 ads, total 37821
# Retrieving Ads for: (100336935877169, 'BR'), number 5933
# 	 0 ads, total 37821
# Retrieving Ads for: (100340052629467, 'BR'), number 5934
# 	 0 ads, total 37821
# Retrieving Ads for: (100341865935056, 'BR'), number 5935
# 	 0 ads, total 37821
# Retrieving Ads for: (100344248360500, 'BR'), number 5936
# 	 0 ads, total 37821
# Retrieving Ads for: (100346095949719, 'BR'), number 5937
# 	 0 ads, total 37821
# Retrieving Ads for: (100346314742474, 'BR'), number 5938
# 	 0 ads, total 37821
# Retrieving Ads for: (100349301672599, 'BR'), number 5939
# 	 0 ads, total 37821
# Retrieving Ads for: (100351452588134, 'BR'), number 5940
# 	 0 ads, total 37821
# Retrieving Ads for: (100353309360986, 'BR'), number 5941
# 	 0 ads, total 37821
# Retrieving Ads for: (100353941322511, 'BR'), number 5942
# 	 0 ads, total 37821
# Retrieving Ads for: (100355411410875, 'BR'), number 5943
# 	 1 ads, total 37822
# Retrieving Ads for: (100355699230899, 'BR'), number 5944
# 	 0 ads, total 37822
# Retrieving Ads for: (100355911461900, 'BR'), number 5945
# 	 0 ads, total 37822
# Retrieving Ads for: (100356588277155, 'BR'), number 5946
# 	 1 ads, total 37823
# Retrieving Ads for: (100359201951930, 'BR'), number 5947
# 	 0 ads, total 37823
# Retrieving Ads for: (100359566010068, 'BR'), number 5948
# 	 0 ads, total 37823
# Retrieving Ads for: (100362412461656, 'BR'), number 5949
# 	 0 ads, total 37823
# Retrieving Ads for: (100362659134830, 'BR'), number 5950
# 	 0 ads, total 37823
# Retrieving Ads for: (100362912629349, 'BR'), number 5951
# 	 1 ads, total 37824
# Retrieving Ads for: (100364081812814, 'BR'), number 5952
# 	 3 ads, total 37827
# Retrieving Ads for: (100365655944150, 'BR'), number 5953
# 	 2 ads, total 37829
# Retrieving Ads for: (100367068159844, 'BR'), number 5954
# 	 3 ads, total 37832
# Retrieving Ads for: (100368631479576, 'BR'), number 5955
# 	 71 ads, total 37903
# Retrieving Ads for: (100369288054394, 'BR'), number 5956
# 	 3 ads, total 37906
# Retrieving Ads for: (100369772595013, 'BR'), number 5957
# 	 1 ads, total 37907
# Retrieving Ads for: (100372545422728, 'BR'), number 5958
# 	 1 ads, total 37908
# Retrieving Ads for: (100374259127963, 'BR'), number 5959
# 	 0 ads, total 37908
# Retrieving Ads for: (100376298249463, 'BR'), number 5960
# 	 10 ads, total 37918
# Retrieving Ads for: (100376992469454, 'BR'), number 5961
# 	 0 ads, total 37918
# Retrieving Ads for: (100381658780941, 'BR'), number 5962
# 	 0 ads, total 37918
# Retrieving Ads for: (100384708754245, 'BR'), number 5963
# 	 0 ads, total 37918
# Retrieving Ads for: (100388212572911, 'BR'), number 5964
# 	 1 ads, total 37919
# Retrieving Ads for: (100389319329846, 'BR'), number 5965
# 	 0 ads, total 37919
# Retrieving Ads for: (100391268449984, 'BR'), number 5966
# 	 0 ads, total 37919
# Retrieving Ads for: (100393289290856, 'BR'), number 5967
# 	 0 ads, total 37919
# Retrieving Ads for: (100400499225045, 'BR'), number 5968
# 	 0 ads, total 37919
# Retrieving Ads for: (100401895982254, 'BR'), number 5969
# 	 0 ads, total 37919
# Retrieving Ads for: (100403765970621, 'BR'), number 5970
# 	 0 ads, total 37919
# Retrieving Ads for: (100404205760725, 'BR'), number 5971
# 	 0 ads, total 37919
# Retrieving Ads for: (100405652683012, 'BR'), number 5972
# 	 0 ads, total 37919
# Retrieving Ads for: (100406519262763, 'BR'), number 5973
# 	 1 ads, total 37920
# Retrieving Ads for: (100413892667625, 'BR'), number 5974
# 	 0 ads, total 37920
# Retrieving Ads for: (100418485359223, 'BR'), number 5975
# 	 0 ads, total 37920
# Retrieving Ads for: (100418845055485, 'BR'), number 5976
# 	 0 ads, total 37920
# Retrieving Ads for: (100421044649941, 'BR'), number 5977
# 	 0 ads, total 37920
# Retrieving Ads for: (100423922624119, 'BR'), number 5978
# 	 0 ads, total 37920
# Retrieving Ads for: (100424768870196, 'BR'), number 5979
# 	 2 ads, total 37922
# Retrieving Ads for: (100429111698632, 'BR'), number 5980
# 	 0 ads, total 37922
# Retrieving Ads for: (100429345833451, 'BR'), number 5981
# 	 0 ads, total 37922
# Retrieving Ads for: (100431181316321, 'BR'), number 5982
# 	 2 ads, total 37924
# Retrieving Ads for: (100431834854769, 'BR'), number 5983
# 	 0 ads, total 37924
# Retrieving Ads for: (100434428687372, 'BR'), number 5984
# 	 0 ads, total 37924
# Retrieving Ads for: (100434535890185, 'BR'), number 5985
# 	 0 ads, total 37924
# Retrieving Ads for: (100434681806345, 'BR'), number 5986
# 	 25 ads, total 37949
# Retrieving Ads for: (100437801524133, 'BR'), number 5987
# 	 0 ads, total 37949
# Retrieving Ads for: (100438945177886, 'BR'), number 5988
# 	 0 ads, total 37949
# Retrieving Ads for: (100441569307110, 'BR'), number 5989
# 	 0 ads, total 37949
# Retrieving Ads for: (100441632644020, 'BR'), number 5990
# 	 0 ads, total 37949
# Retrieving Ads for: (100442905634476, 'BR'), number 5991
# 	 0 ads, total 37949
# Retrieving Ads for: (100443909012264, 'BR'), number 5992
# 	 0 ads, total 37949
# Retrieving Ads for: (100447489031314, 'BR'), number 5993
# 	 0 ads, total 37949
# Retrieving Ads for: (100449265412063, 'BR'), number 5994
# 	 0 ads, total 37949
# Retrieving Ads for: (100452562571422, 'BR'), number 5995
# 	 0 ads, total 37949
# Retrieving Ads for: (100453619313281, 'BR'), number 5996
# 	 0 ads, total 37949
# Retrieving Ads for: (100453629161275, 'BR'), number 5997
# 	 0 ads, total 37949
# Retrieving Ads for: (100455722629449, 'BR'), number 5998
# 	 0 ads, total 37949
# Retrieving Ads for: (100455745405560, 'BR'), number 5999
# 	 0 ads, total 37949
# Saving ..... batch 60, current id: 6000
# Retrieving Ads for: (100457485904082, 'BR'), number 6000
# 	 0 ads, total 37949
# Retrieving Ads for: (100459902106274, 'BR'), number 6001
# 	 0 ads, total 37949
# Retrieving Ads for: (100461681862985, 'BR'), number 6002
# 	 0 ads, total 37949
# Retrieving Ads for: (100462031858922, 'BR'), number 6003
# 	 1 ads, total 37950
# Retrieving Ads for: (100463018794349, 'BR'), number 6004
# 	 0 ads, total 37950
# Retrieving Ads for: (100467221879248, 'BR'), number 6005
# 	 3 ads, total 37953
# Retrieving Ads for: (100469365542976, 'BR'), number 6006
# 	 0 ads, total 37953
# Retrieving Ads for: (100470085776947, 'BR'), number 6007
# 	 0 ads, total 37953
# Retrieving Ads for: (100471782499807, 'BR'), number 6008
# 	 0 ads, total 37953
# Retrieving Ads for: (100474221848197, 'BR'), number 6009
# 	 44 ads, total 37997
# Retrieving Ads for: (100475082251155, 'BR'), number 6010
# 	 0 ads, total 37997
# Retrieving Ads for: (100475402294243, 'BR'), number 6011
# 	 0 ads, total 37997
# Retrieving Ads for: (100478009254664, 'BR'), number 6012
# 	 0 ads, total 37997
# Retrieving Ads for: (100478458356433, 'BR'), number 6013
# 	 2 ads, total 37999
# Retrieving Ads for: (100479411618465, 'BR'), number 6014
# 	 0 ads, total 37999
# Retrieving Ads for: (100480825586733, 'BR'), number 6015
# 	 0 ads, total 37999
# Retrieving Ads for: (100481471619855, 'BR'), number 6016
# 	 0 ads, total 37999
# Retrieving Ads for: (100484845123222, 'BR'), number 6017
# 	 0 ads, total 37999
# Retrieving Ads for: (100485415109106, 'BR'), number 6018
# 	 0 ads, total 37999
# Retrieving Ads for: (100485928025444, 'BR'), number 6019
# 	 0 ads, total 37999
# Retrieving Ads for: (100487282049483, 'BR'), number 6020
# 	 0 ads, total 37999
# Retrieving Ads for: (100489464695466, 'BR'), number 6021
# 	 0 ads, total 37999
# Retrieving Ads for: (100493319325173, 'BR'), number 6022
# 	 0 ads, total 37999
# Retrieving Ads for: (100505289289765, 'BR'), number 6023
# 	 0 ads, total 37999
# Retrieving Ads for: (100505418999694, 'BR'), number 6024
# 	 0 ads, total 37999
# Retrieving Ads for: (100506212659974, 'BR'), number 6025
# 	 0 ads, total 37999
# Retrieving Ads for: (100509705346931, 'BR'), number 6026
# 	 0 ads, total 37999
# Retrieving Ads for: (100513511837101, 'BR'), number 6027
# 	 0 ads, total 37999
# Retrieving Ads for: (100513715984630, 'BR'), number 6028
# 	 0 ads, total 37999
# Retrieving Ads for: (100514315816180, 'BR'), number 6029
# 	 0 ads, total 37999
# Retrieving Ads for: (100514515013810, 'BR'), number 6030
# 	 12 ads, total 38011
# Retrieving Ads for: (100516889134775, 'BR'), number 6031
# 	 0 ads, total 38011
# Retrieving Ads for: (100518531513820, 'BR'), number 6032
# 	 0 ads, total 38011
# Retrieving Ads for: (100518882637136, 'BR'), number 6033
# 	 0 ads, total 38011
# Retrieving Ads for: (100520825048827, 'BR'), number 6034
# 	 0 ads, total 38011
# Retrieving Ads for: (100522681454252, 'BR'), number 6035
# 	 0 ads, total 38011
# Retrieving Ads for: (100526075546062, 'BR'), number 6036
# 	 0 ads, total 38011
# Retrieving Ads for: (100527502548024, 'BR'), number 6037
# 	 0 ads, total 38011
# Retrieving Ads for: (100529705553104, 'BR'), number 6038
# 	 0 ads, total 38011
# Retrieving Ads for: (100529808604172, 'BR'), number 6039
# 	 1 ads, total 38012
# Retrieving Ads for: (100531458484300, 'BR'), number 6040
# 	 0 ads, total 38012
# Retrieving Ads for: (100535322029249, 'BR'), number 6041
# 	 0 ads, total 38012
# Retrieving Ads for: (100535502255665, 'BR'), number 6042
# 	 0 ads, total 38012
# Retrieving Ads for: (100538454704487, 'BR'), number 6043
# 	 0 ads, total 38012
# Retrieving Ads for: (100538552171453, 'BR'), number 6044
# 	 0 ads, total 38012
# Retrieving Ads for: (100539379230539, 'BR'), number 6045
# 	 0 ads, total 38012
# Retrieving Ads for: (100543139270693, 'BR'), number 6046
# 	 0 ads, total 38012
# Retrieving Ads for: (100544302137143, 'BR'), number 6047
# 	 0 ads, total 38012
# Retrieving Ads for: (100545435114509, 'BR'), number 6048
# 	 2 ads, total 38014
# Retrieving Ads for: (100545629193369, 'BR'), number 6049
# 	 0 ads, total 38014
# Retrieving Ads for: (100547110728357, 'BR'), number 6050
# 	 0 ads, total 38014
# Retrieving Ads for: (100552495636262, 'BR'), number 6051
# 	 0 ads, total 38014
# Retrieving Ads for: (100556071772911, 'BR'), number 6052
# 	 0 ads, total 38014
# Retrieving Ads for: (100556892345105, 'BR'), number 6053
# 	 0 ads, total 38014
# Retrieving Ads for: (100560087991348, 'BR'), number 6054
# 	 0 ads, total 38014
# Retrieving Ads for: (100564051910720, 'BR'), number 6055
# 	 0 ads, total 38014
# Retrieving Ads for: (100566265896881, 'BR'), number 6056
# 	 2 ads, total 38016
# Retrieving Ads for: (100566475029818, 'BR'), number 6057
# 	 0 ads, total 38016
# Retrieving Ads for: (100566968288072, 'BR'), number 6058
# 	 0 ads, total 38016
# Retrieving Ads for: (100569511735896, 'BR'), number 6059
# 	 0 ads, total 38016
# Retrieving Ads for: (100573668896649, 'BR'), number 6060
# 	 0 ads, total 38016
# Retrieving Ads for: (100575307986322, 'BR'), number 6061
# 	 2 ads, total 38018
# Retrieving Ads for: (100581751600390, 'BR'), number 6062
# 	 6 ads, total 38024
# Retrieving Ads for: (100581858875177, 'BR'), number 6063
# 	 0 ads, total 38024
# Retrieving Ads for: (100585242638737, 'BR'), number 6064
# 	 0 ads, total 38024
# Retrieving Ads for: (100588158756657, 'BR'), number 6065
# 	 0 ads, total 38024
# Retrieving Ads for: (100593411881106, 'BR'), number 6066
# 	 0 ads, total 38024
# Retrieving Ads for: (100595448671208, 'BR'), number 6067
# 	 1 ads, total 38025
# Retrieving Ads for: (100598621394895, 'BR'), number 6068
# 	 0 ads, total 38025
# Retrieving Ads for: (100600152567890, 'BR'), number 6069
# 	 0 ads, total 38025
# Retrieving Ads for: (100602915032991, 'BR'), number 6070
# 	 0 ads, total 38025
# Retrieving Ads for: (100605271766364, 'BR'), number 6071
# 	 14 ads, total 38039
# Retrieving Ads for: (100607641644493, 'BR'), number 6072
# 	 0 ads, total 38039
# Retrieving Ads for: (100615915548143, 'BR'), number 6073
# 	 0 ads, total 38039
# Retrieving Ads for: (100616014675124, 'BR'), number 6074
# 	 0 ads, total 38039
# Retrieving Ads for: (100617528897947, 'BR'), number 6075
# 	 0 ads, total 38039
# Retrieving Ads for: (100617599250020, 'BR'), number 6076
# 	 0 ads, total 38039
# Retrieving Ads for: (100617965272810, 'BR'), number 6077
# 	 0 ads, total 38039
# Retrieving Ads for: (100618227441022, 'BR'), number 6078
# 	 0 ads, total 38039
# Retrieving Ads for: (100618315361877, 'BR'), number 6079
# 	 0 ads, total 38039
# Retrieving Ads for: (100620825680470, 'BR'), number 6080
# 	 0 ads, total 38039
# Retrieving Ads for: (100623409031664, 'BR'), number 6081
# 	 0 ads, total 38039
# Retrieving Ads for: (100624958792189, 'BR'), number 6082
# 	 0 ads, total 38039
# Retrieving Ads for: (100626482555419, 'BR'), number 6083
# 	 0 ads, total 38039
# Retrieving Ads for: (100629792069989, 'BR'), number 6084
# 	 0 ads, total 38039
# Retrieving Ads for: (100633404952857, 'BR'), number 6085
# 	 0 ads, total 38039
# Retrieving Ads for: (100634055117945, 'BR'), number 6086
# 	 0 ads, total 38039
# Retrieving Ads for: (100635145858028, 'BR'), number 6087
# 	 0 ads, total 38039
# Retrieving Ads for: (100637635096185, 'BR'), number 6088
# 	 0 ads, total 38039
# Retrieving Ads for: (100638195840735, 'BR'), number 6089
# 	 0 ads, total 38039
# Retrieving Ads for: (100641868339264, 'BR'), number 6090
# 	 0 ads, total 38039
# Retrieving Ads for: (100643144901085, 'BR'), number 6091
# 	 0 ads, total 38039
# Retrieving Ads for: (100644525056198, 'BR'), number 6092
# 	 0 ads, total 38039
# Retrieving Ads for: (100645801775860, 'BR'), number 6093
# 	 0 ads, total 38039
# Retrieving Ads for: (100647348432569, 'BR'), number 6094
# 	 0 ads, total 38039
# Retrieving Ads for: (100649442486657, 'BR'), number 6095
# 	 0 ads, total 38039
# Retrieving Ads for: (100651219156665, 'BR'), number 6096
# 	 0 ads, total 38039
# Retrieving Ads for: (100652878947492, 'BR'), number 6097
# 	 0 ads, total 38039
# Retrieving Ads for: (100652919239817, 'BR'), number 6098
# 	 0 ads, total 38039
# Retrieving Ads for: (100653904746847, 'BR'), number 6099
# 	 0 ads, total 38039
# Saving ..... batch 61, current id: 6100
# Retrieving Ads for: (100657043922147, 'BR'), number 6100
# 	 0 ads, total 38039
# Retrieving Ads for: (100659622079759, 'BR'), number 6101
# 	 0 ads, total 38039
# Retrieving Ads for: (100661818730059, 'BR'), number 6102
# 	 0 ads, total 38039
# Retrieving Ads for: (100663335130663, 'BR'), number 6103
# 	 7 ads, total 38046
# Retrieving Ads for: (100664851580702, 'BR'), number 6104
# 	 3 ads, total 38049
# Retrieving Ads for: (100665478811481, 'BR'), number 6105
# 	 0 ads, total 38049
# Retrieving Ads for: (100667085826193, 'BR'), number 6106
# 	 0 ads, total 38049
# Retrieving Ads for: (100668165170505, 'BR'), number 6107
# 	 5 ads, total 38054
# Retrieving Ads for: (100669435386446, 'BR'), number 6108
# 	 2 ads, total 38056
# Retrieving Ads for: (100671585819448, 'BR'), number 6109
# 	 0 ads, total 38056
# Retrieving Ads for: (100672115885824, 'BR'), number 6110
# 	 0 ads, total 38056
# Retrieving Ads for: (100675561333761, 'BR'), number 6111
# 	 10 ads, total 38066
# Retrieving Ads for: (100681498935670, 'BR'), number 6112
# 	 1 ads, total 38067
# Retrieving Ads for: (100682332101237, 'BR'), number 6113
# 	 0 ads, total 38067
# Retrieving Ads for: (100689865413766, 'BR'), number 6114
# 	 0 ads, total 38067
# Retrieving Ads for: (100690552356813, 'BR'), number 6115
# 	 0 ads, total 38067
# Retrieving Ads for: (100692935469985, 'BR'), number 6116
# 	 0 ads, total 38067
# Retrieving Ads for: (100697671985410, 'BR'), number 6117
# 	 0 ads, total 38067
# Retrieving Ads for: (100698881704966, 'BR'), number 6118
# 	 0 ads, total 38067
# Retrieving Ads for: (100700572286065, 'BR'), number 6119
# 	 0 ads, total 38067
# Retrieving Ads for: (100704899231458, 'BR'), number 6120
# 	 0 ads, total 38067
# Retrieving Ads for: (100706058941078, 'BR'), number 6121
# 	 0 ads, total 38067
# Retrieving Ads for: (100706812506241, 'BR'), number 6122
# 	 0 ads, total 38067
# Retrieving Ads for: (100707409013856, 'BR'), number 6123
# 	 0 ads, total 38067
# Retrieving Ads for: (100709958332212, 'BR'), number 6124
# 	 9 ads, total 38076
# Retrieving Ads for: (100710412444302, 'BR'), number 6125
# 	 3 ads, total 38079
# Retrieving Ads for: (100711292644241, 'BR'), number 6126
# 	 0 ads, total 38079
# Retrieving Ads for: (100713212642573, 'BR'), number 6127
# 	 0 ads, total 38079
# Retrieving Ads for: (100715679098743, 'BR'), number 6128
# 	 0 ads, total 38079
# Retrieving Ads for: (100716292514554, 'BR'), number 6129
# 	 0 ads, total 38079
# Retrieving Ads for: (100717759182932, 'BR'), number 6130
# 	 0 ads, total 38079
# Retrieving Ads for: (100719282065822, 'BR'), number 6131
# 	 0 ads, total 38079
# Retrieving Ads for: (100722409286481, 'BR'), number 6132
# 	 0 ads, total 38079
# Retrieving Ads for: (100722782289750, 'BR'), number 6133
# 	 3 ads, total 38082
# Retrieving Ads for: (100723398684770, 'BR'), number 6134
# 	 0 ads, total 38082
# Retrieving Ads for: (100725552156623, 'BR'), number 6135
# 	 0 ads, total 38082
# Retrieving Ads for: (100726171542753, 'BR'), number 6136
# 	 0 ads, total 38082
# Retrieving Ads for: (100735668926860, 'BR'), number 6137
# 	 0 ads, total 38082
# Retrieving Ads for: (100737361919541, 'BR'), number 6138
# 	 0 ads, total 38082
# Retrieving Ads for: (100737468176743, 'BR'), number 6139
# 	 0 ads, total 38082
# Retrieving Ads for: (100739098981386, 'BR'), number 6140
# 	 0 ads, total 38082
# Retrieving Ads for: (100742011804929, 'BR'), number 6141
# 	 0 ads, total 38082
# Retrieving Ads for: (100746531614065, 'BR'), number 6142
# 	 0 ads, total 38082
# Retrieving Ads for: (100747102607283, 'BR'), number 6143
# 	 0 ads, total 38082
# Retrieving Ads for: (100747162161099, 'BR'), number 6144
# 	 0 ads, total 38082
# Retrieving Ads for: (100749412577414, 'BR'), number 6145
# 	 0 ads, total 38082
# Retrieving Ads for: (100749862063526, 'BR'), number 6146
# 	 0 ads, total 38082
# Retrieving Ads for: (100751981706448, 'BR'), number 6147
# 	 1 ads, total 38083
# Retrieving Ads for: (100752015284220, 'BR'), number 6148
# 	 7 ads, total 38090
# Retrieving Ads for: (100754041649306, 'BR'), number 6149
# 	 0 ads, total 38090
# Retrieving Ads for: (100754241369335, 'BR'), number 6150
# 	 0 ads, total 38090
# Retrieving Ads for: (100757401653116, 'BR'), number 6151
# 	 1 ads, total 38091
# Retrieving Ads for: (100759032238067, 'BR'), number 6152
# 	 0 ads, total 38091
# Retrieving Ads for: (100760251909485, 'BR'), number 6153
# 	 0 ads, total 38091
# Retrieving Ads for: (100761279304034, 'BR'), number 6154
# 	 0 ads, total 38091
# Retrieving Ads for: (100762890036761, 'BR'), number 6155
# 	 0 ads, total 38091
# Retrieving Ads for: (100769162611763, 'BR'), number 6156
# 	 0 ads, total 38091
# Retrieving Ads for: (100769175814351, 'BR'), number 6157
# 	 0 ads, total 38091
# Retrieving Ads for: (100771305928188, 'BR'), number 6158
# 	 2 ads, total 38093
# Retrieving Ads for: (100771771932189, 'BR'), number 6159
# 	 0 ads, total 38093
# Retrieving Ads for: (100773175175549, 'BR'), number 6160
# 	 0 ads, total 38093
# Retrieving Ads for: (100773891887664, 'BR'), number 6161
# 	 0 ads, total 38093
# Retrieving Ads for: (100776975344868, 'BR'), number 6162
# 	 1 ads, total 38094
# Retrieving Ads for: (100780469302242, 'BR'), number 6163
# 	 0 ads, total 38094
# Retrieving Ads for: (100781582363545, 'BR'), number 6164
# 	 0 ads, total 38094
# Retrieving Ads for: (100783612524166, 'BR'), number 6165
# 	 0 ads, total 38094
# Retrieving Ads for: (100784278297723, 'BR'), number 6166
# 	 0 ads, total 38094
# Retrieving Ads for: (100784975087297, 'BR'), number 6167
# 	 0 ads, total 38094
# Retrieving Ads for: (100786599279955, 'BR'), number 6168
# 	 0 ads, total 38094
# Retrieving Ads for: (100789885896090, 'BR'), number 6169
# 	 0 ads, total 38094
# Retrieving Ads for: (100791661913464, 'BR'), number 6170
# 	 2 ads, total 38096
# Retrieving Ads for: (100793141878080, 'BR'), number 6171
# 	 0 ads, total 38096
# Retrieving Ads for: (100796492544198, 'BR'), number 6172
# 	 0 ads, total 38096
# Retrieving Ads for: (100797421370903, 'BR'), number 6173
# 	 0 ads, total 38096
# Retrieving Ads for: (100797945004963, 'BR'), number 6174
# 	 1 ads, total 38097
# Retrieving Ads for: (100798505455029, 'BR'), number 6175
# 	 0 ads, total 38097
# Retrieving Ads for: (100804119272255, 'BR'), number 6176
# 	 0 ads, total 38097
# Retrieving Ads for: (100808275850148, 'BR'), number 6177
# 	 0 ads, total 38097
# Retrieving Ads for: (100811908368521, 'BR'), number 6178
# 	 11 ads, total 38108
# Retrieving Ads for: (100814525036652, 'BR'), number 6179
# 	 0 ads, total 38108
# Retrieving Ads for: (100818232195103, 'BR'), number 6180
# 	 0 ads, total 38108
# Retrieving Ads for: (100822261659431, 'BR'), number 6181
# 	 0 ads, total 38108
# Retrieving Ads for: (100822832557655, 'BR'), number 6182
# 	 0 ads, total 38108
# Retrieving Ads for: (100823188001051, 'BR'), number 6183
# 	 0 ads, total 38108
# Retrieving Ads for: (100824024850686, 'BR'), number 6184
# 	 1 ads, total 38109
# Retrieving Ads for: (100828752534134, 'BR'), number 6185
# 	 0 ads, total 38109
# Retrieving Ads for: (100829275599655, 'BR'), number 6186
# 	 3 ads, total 38112
# Retrieving Ads for: (100831299226366, 'BR'), number 6187
# 	 1 ads, total 38113
# Retrieving Ads for: (100832958381742, 'BR'), number 6188
# 	 0 ads, total 38113
# Retrieving Ads for: (100833289177693, 'BR'), number 6189
# 	 0 ads, total 38113
# Retrieving Ads for: (100833344855408, 'BR'), number 6190
# 	 1 ads, total 38114
# Retrieving Ads for: (100834475854638, 'BR'), number 6191
# 	 0 ads, total 38114
# Retrieving Ads for: (100837488416268, 'BR'), number 6192
# 	 3 ads, total 38117
# Retrieving Ads for: (100837538260625, 'BR'), number 6193
# 	 1 ads, total 38118
# Retrieving Ads for: (100840699258962, 'BR'), number 6194
# 	 0 ads, total 38118
# Retrieving Ads for: (100848624927485, 'BR'), number 6195
# 	 0 ads, total 38118
# Retrieving Ads for: (100849768829838, 'BR'), number 6196
# 	 0 ads, total 38118
# Retrieving Ads for: (100852435109891, 'BR'), number 6197
# 	 3 ads, total 38121
# Retrieving Ads for: (100862475882486, 'BR'), number 6198
# 	 0 ads, total 38121
# Retrieving Ads for: (100866902468805, 'BR'), number 6199
# 	 1 ads, total 38122
# Saving ..... batch 62, current id: 6200
# Retrieving Ads for: (100872022457519, 'BR'), number 6200
# 	 0 ads, total 38122
# Retrieving Ads for: (100872829289749, 'BR'), number 6201
# 	 0 ads, total 38122
# Retrieving Ads for: (100876478951033, 'BR'), number 6202
# 	 0 ads, total 38122
# Retrieving Ads for: (100879754920362, 'BR'), number 6203
# 	 1 ads, total 38123
# Retrieving Ads for: (100884135106805, 'BR'), number 6204
# 	 0 ads, total 38123
# Retrieving Ads for: (100884694811017, 'BR'), number 6205
# 	 2 ads, total 38125
# Retrieving Ads for: (100885342422641, 'BR'), number 6206
# 	 0 ads, total 38125
# Retrieving Ads for: (100887705486324, 'BR'), number 6207
# 	 0 ads, total 38125
# Retrieving Ads for: (100889409258338, 'BR'), number 6208
# 	 0 ads, total 38125
# Retrieving Ads for: (100890691434414, 'BR'), number 6209
# 	 12 ads, total 38137
# Retrieving Ads for: (100895955392348, 'BR'), number 6210
# 	 0 ads, total 38137
# Retrieving Ads for: (100904849119969, 'BR'), number 6211
# 	 0 ads, total 38137
# Retrieving Ads for: (100908921449454, 'BR'), number 6212
# 	 4 ads, total 38141
# Retrieving Ads for: (100910112493817, 'BR'), number 6213
# 	 0 ads, total 38141
# Retrieving Ads for: (100911228332303, 'BR'), number 6214
# 	 0 ads, total 38141
# Retrieving Ads for: (100913185701894, 'BR'), number 6215
# 	 1 ads, total 38142
# Retrieving Ads for: (100917165324004, 'BR'), number 6216
# 	 0 ads, total 38142
# Retrieving Ads for: (100917344935826, 'BR'), number 6217
# 	 7 ads, total 38149
# Retrieving Ads for: (100919531776253, 'BR'), number 6218
# 	 2 ads, total 38151
# Retrieving Ads for: (100921209182874, 'BR'), number 6219
# 	 0 ads, total 38151
# Retrieving Ads for: (100923612530980, 'BR'), number 6220
# 	 0 ads, total 38151
# Retrieving Ads for: (100928895925732, 'BR'), number 6221
# 	 0 ads, total 38151
# Retrieving Ads for: (100930634646243, 'BR'), number 6222
# 	 0 ads, total 38151
# Retrieving Ads for: (100933275345192, 'BR'), number 6223
# 	 4 ads, total 38155
# Retrieving Ads for: (100934227257600, 'BR'), number 6224
# 	 12 ads, total 38167
# Retrieving Ads for: (100939072439709, 'BR'), number 6225
# 	 0 ads, total 38167
# Retrieving Ads for: (100939968279321, 'BR'), number 6226
# 	 0 ads, total 38167
# Retrieving Ads for: (100943678850659, 'BR'), number 6227
# 	 0 ads, total 38167
# Retrieving Ads for: (100945228762390, 'BR'), number 6228
# 	 0 ads, total 38167
# Retrieving Ads for: (100945995420481, 'BR'), number 6229
# 	 0 ads, total 38167
# Retrieving Ads for: (100949305633793, 'BR'), number 6230
# 	 0 ads, total 38167
# Retrieving Ads for: (100951134723381, 'BR'), number 6231
# 	 4 ads, total 38171
# Retrieving Ads for: (100953411423177, 'BR'), number 6232
# 	 0 ads, total 38171
# Retrieving Ads for: (100958075578466, 'BR'), number 6233
# 	 0 ads, total 38171
# Retrieving Ads for: (100968382011653, 'BR'), number 6234
# 	 0 ads, total 38171
# Retrieving Ads for: (100970562118795, 'BR'), number 6235
# 	 0 ads, total 38171
# Retrieving Ads for: (100980155340542, 'BR'), number 6236
# 	 0 ads, total 38171
# Retrieving Ads for: (100982002070601, 'BR'), number 6237
# 	 0 ads, total 38171
# Retrieving Ads for: (100983185460446, 'BR'), number 6238
# 	 0 ads, total 38171
# Retrieving Ads for: (100987910054854, 'BR'), number 6239
# 	 2 ads, total 38173
# Retrieving Ads for: (100988901911992, 'BR'), number 6240
# 	 0 ads, total 38173
# Retrieving Ads for: (100995295631396, 'BR'), number 6241
# 	 0 ads, total 38173
# Retrieving Ads for: (100996261797814, 'BR'), number 6242
# 	 0 ads, total 38173
# Retrieving Ads for: (101000445063027, 'BR'), number 6243
# 	 0 ads, total 38173
# Retrieving Ads for: (101004083330217, 'BR'), number 6244
# 	 23 ads, total 38196
# Retrieving Ads for: (101004812231224, 'BR'), number 6245
# 	 0 ads, total 38196
# Retrieving Ads for: (101006771678803, 'BR'), number 6246
# 	 0 ads, total 38196
# Retrieving Ads for: (101007261498148, 'BR'), number 6247
# 	 0 ads, total 38196
# Retrieving Ads for: (101008045698428, 'BR'), number 6248
# 	 0 ads, total 38196
# Retrieving Ads for: (101009141772639, 'BR'), number 6249
# 	 1 ads, total 38197
# Retrieving Ads for: (101009619289691, 'BR'), number 6250
# 	 0 ads, total 38197
# Retrieving Ads for: (101012882409870, 'BR'), number 6251
# 	 0 ads, total 38197
# Retrieving Ads for: (101014548385454, 'BR'), number 6252
# 	 1 ads, total 38198
# Retrieving Ads for: (101017038299673, 'BR'), number 6253
# 	 0 ads, total 38198
# Retrieving Ads for: (101020325035365, 'BR'), number 6254
# 	 2 ads, total 38200
# Retrieving Ads for: (101021735692572, 'BR'), number 6255
# 	 1 ads, total 38201
# Retrieving Ads for: (101021869005159, 'BR'), number 6256
# 	 0 ads, total 38201
# Retrieving Ads for: (101023999217350, 'BR'), number 6257
# 	 0 ads, total 38201
# Retrieving Ads for: (101025849131352, 'BR'), number 6258
# 	 1 ads, total 38202
# Retrieving Ads for: (101031001337676, 'BR'), number 6259
# 	 12 ads, total 38214
# Retrieving Ads for: (101031005874896, 'BR'), number 6260
# 	 0 ads, total 38214
# Retrieving Ads for: (101032134578934, 'BR'), number 6261
# 	 1 ads, total 38215
# Retrieving Ads for: (101037162532149, 'BR'), number 6262
# 	 0 ads, total 38215
# Retrieving Ads for: (101038354967759, 'BR'), number 6263
# 	 0 ads, total 38215
# Retrieving Ads for: (101042614950139, 'BR'), number 6264
# 	 0 ads, total 38215
# Retrieving Ads for: (101044541892102, 'BR'), number 6265
# 	 1 ads, total 38216
# Retrieving Ads for: (101044682414731, 'BR'), number 6266
# 	 0 ads, total 38216
# Retrieving Ads for: (101047019241500, 'BR'), number 6267
# 	 0 ads, total 38216
# Retrieving Ads for: (101048011531035, 'BR'), number 6268
# 	 0 ads, total 38216
# Retrieving Ads for: (101052615544389, 'BR'), number 6269
# 	 5 ads, total 38221
# Retrieving Ads for: (101052885094253, 'BR'), number 6270
# 	 0 ads, total 38221
# Retrieving Ads for: (101056649075799, 'BR'), number 6271
# 	 2 ads, total 38223
# Retrieving Ads for: (101058212479255, 'BR'), number 6272
# 	 0 ads, total 38223
# Retrieving Ads for: (101058298713844, 'BR'), number 6273
# 	 25 ads, total 38248
# Retrieving Ads for: (101058678318082, 'BR'), number 6274
# 	 8 ads, total 38256
# Retrieving Ads for: (101059929156000, 'BR'), number 6275
# 	 0 ads, total 38256
# Retrieving Ads for: (101061161765332, 'BR'), number 6276
# 	 0 ads, total 38256
# Retrieving Ads for: (101061702530233, 'BR'), number 6277
# 	 0 ads, total 38256
# Retrieving Ads for: (101065912488489, 'BR'), number 6278
# 	 0 ads, total 38256
# Retrieving Ads for: (101072822528185, 'BR'), number 6279
# 	 0 ads, total 38256
# Retrieving Ads for: (101074069039395, 'BR'), number 6280
# 	 0 ads, total 38256
# Retrieving Ads for: (101079245860680, 'BR'), number 6281
# 	 0 ads, total 38256
# Retrieving Ads for: (101083959932439, 'BR'), number 6282
# 	 0 ads, total 38256
# Retrieving Ads for: (101084162055822, 'BR'), number 6283
# 	 38 ads, total 38294
# Retrieving Ads for: (101094469141590, 'BR'), number 6284
# 	 0 ads, total 38294
# Retrieving Ads for: (101094885884934, 'BR'), number 6285
# 	 1 ads, total 38295
# Retrieving Ads for: (101095219032856, 'BR'), number 6286
# 	 0 ads, total 38295
# Retrieving Ads for: (101099098682858, 'BR'), number 6287
# 	 0 ads, total 38295
# Retrieving Ads for: (101102943299198, 'BR'), number 6288
# 	 0 ads, total 38295
# Retrieving Ads for: (101103175209935, 'BR'), number 6289
# 	 0 ads, total 38295
# Retrieving Ads for: (101106645637982, 'BR'), number 6290
# 	 0 ads, total 38295
# Retrieving Ads for: (101117081453329, 'BR'), number 6291
# 	 0 ads, total 38295
# Retrieving Ads for: (101122634999087, 'BR'), number 6292
# 	 2 ads, total 38297
# Retrieving Ads for: (101123869206963, 'BR'), number 6293
# 	 0 ads, total 38297
# Retrieving Ads for: (101127191780974, 'BR'), number 6294
# 	 0 ads, total 38297
# Retrieving Ads for: (101129045871832, 'BR'), number 6295
# 	 0 ads, total 38297
# Retrieving Ads for: (101130855300816, 'BR'), number 6296
# 	 0 ads, total 38297
# Retrieving Ads for: (101132704939097, 'BR'), number 6297
# 	 940 ads, total 39237
# ...
# Retrieving Ads for: (110375540781637, 'BR'), number 8898
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=110375540781637&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 43167
# Retrieving Ads for: (110376220648768, 'BR'), number 8899
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=110376220648768&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 43167
# Saving ..... batch 89, current id: 8900
# Retrieving Ads for: (110377654916163, 'BR'), number 8900
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=110377654916163&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 43167
# Retrieving Ads for: (110379374083288, 'BR'), number 8901
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=110379374083288&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 43167
# Retrieving Ads for: (110388877787931, 'BR'), number 8902
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=110388877787931&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 43167
# Retrieving Ads for: (110392949649411, 'BR'), number 8903
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=110392949649411&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 43167
# Retrieving Ads for: (110393578218545, 'BR'), number 8904
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=110393578218545&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 43167
# Retrieving Ads for: (110404507885898, 'BR'), number 8905
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=110404507885898&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 43167
# Retrieving Ads for: (110407433725651, 'BR'), number 8906
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=110407433725651&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 43167
# Retrieving Ads for: (110428748083535, 'BR'), number 8907
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=110428748083535&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 43167
# Retrieving Ads for: (110429434468282, 'BR'), number 8908
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=110429434468282&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 43167
# Retrieving Ads for: (110430004951761, 'BR'), number 8909
# Error Status Code 400 for URL: https://graph.facebook.com/v13.0/ads_archive?access_token=EAAEau61SMogBAKXf5ZCiYZC2WkmfCAkZCEz1cQoZBTgg4AdxRAAmG5ZAcH8hrSEsXPDZBPFodOdKr7s49i4ZBecZAZBnnV86z5HMCZAaYp1s2WoUj5P5PzYXTX6Gao2awkZBBudMZBubxwlG3UeRUZBCsBTb5GCeHbAsJFdf0Bal6Rpou4ORNt56cpVpK&fields=id%2Cad_creation_time%2Cad_delivery_start_time%2Cad_delivery_stop_time%2Cad_snapshot_url%2Cad_creative_bodies%2Cad_creative_link_captions%2Cad_creative_link_titles%2Cad_creative_link_descriptions%2Clanguages%2Cpage_id%2Cpage_name%2Cbylines%2Ccurrency%2Cspend%2Cimpressions%2Cestimated_audience_size%2Cpublisher_platforms%2Cdemographic_distribution%2Cdelivery_by_region&search_page_ids=110430004951761&media_type=IMAGE&ad_active_status=ALL&ad_reached_countries=BR
# 	 0 ads, total 43167
# Retrieving Ads for: (110439771524778, 'BR'), number 8910
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-798e736c0395> in <module>
#       8     print(f'Retrieving Ads for: {ct}, number {i}')
#       9     try:
# ---> 10         ads = obtain_ads_page_id(ct[0], ct[1], FIELDS, ACCESS_TOKEN)
#      11         total_ads += len(ads)
#      12         print('\t', len(ads), 'ads, total', total_ads)
#
# <ipython-input-4-c5db6f1406fa> in obtain_ads_page_id(page_id, country, fields, access_token)
#       8               'ad_reached_countries': [country]}
#       9
# ---> 10     ads = read_endpoint('', 'ads_archive', access_token, fields, params, 30000)
#      11
#      12     for ad in ads: # add additional information
#
# <ipython-input-2-245143b61514> in read_endpoint(id_, endpoint, access_token, fields, params, n)
#      31     q = dict({'access_token': access_token, 'fields': ','.join(fields)}, **params)
#      32     if id_ == '':
# ---> 33         response = request(method='GET', resource=endpoint, q=q)
#      34     else:
#      35         response = request(method='GET', resource=f'{id_}/{endpoint}', q=q)
#
# <ipython-input-2-245143b61514> in request(method, full_url, resource, q)
#      11             response = requests.get(full_url)
#      12         if resource:
# ---> 13             response = requests.get(f'https://graph.facebook.com/v13.0/{resource}', q)
#      14         if response.status_code==400:
#      15             print(f'Error Status Code 400 for URL: {response.url}')
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # US

# %%
from itertools import product
# countries = ['US', 'GB', 'BR'] # all available countries for now
# themes = ['ad-tech','ed-tech','agri-tech','fin-tech','bio-tech','health-tech','electric-vehicles','clean-energy',
#           'cloud-computing','quantum-computing','artificial-intelligence','machine-learning','digital-assets',
#           'virtual-reality','cyber-security','software','social-trends','analytics']
raw_dir = 'Y:/Internship/SoMin/Notebook/raw/20220526'
all_ads = []
i = 0
total_ads = 0
for ct in product(page_id_us, ['US']):
    if i%100 == 0:
        print(f'Saving ..... batch {i//100}, current id: {i}')
        save_pickle(f'{raw_dir}/adlibrary_ads_us_90_days_{i//1000}.pkl', all_ads)
        if i%1000 == 0:
            all_ads = []
    print(f'Retrieving Ads for: {ct}, number {i}')
    try:
        ads = obtain_ads_page_id(ct[0], ct[1], FIELDS, ACCESS_TOKEN)
        total_ads += len(ads)
        print('\t', len(ads), 'ads, total', total_ads)
        all_ads.extend(ads)
        i+=1
    except Exception as e:
        print('Some error happened:', e)
        
save_pickle(f'{raw_dir}/adlibrary_ads_us_90_days_{i//1000}.pkl', all_ads)
print(f'Retrieved {len(all_ads)} ads')

# %%
import os
import pickle
from datetime import datetime
def ensure_folder_exists(folder_path):
    """
    Creates the specified folder if it does not already exist
    """
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)


def load_pickle(file_path):
    """
    Loads a pickle from the file system
    """
    return pickle.load(open(file_path, 'rb')) if os.path.isfile(file_path) else None


def save_pickle(file_path, data):
    """
    Saves the specified object as a pickle to the file system
    """
    with open(file_path, 'wb') as f:
        pickle.dump(data, f)

raw_dir = f'Y:/Internship/SoMin/Notebook/raw/{str(datetime.today().date()).replace("-","")}'
if not os.path.exists(raw_dir):
    os.makedirs(raw_dir)

# pickle.dumps(all_ads, f'{raw_dir}/adlibrary_ads.pkl')
save_pickle(f'{raw_dir}/adlibrary_ads_us_90_days.pkl', all_ads)

# %%
all_ads = []
for ct in product(page_id_br, ['BR']):
    print('Retrieving for BR')
    print(f'Retrieving Ads for: {ct}')
    ads = obtain_ads_page_id(ct[0], ct[1], FIELDS, ACCESS_TOKEN)
    print('\t', len(ads), 'ads')
    all_ads.extend(ads)
print(f'Retrieved {len(all_ads)} ads')

# %%
all_ads = []
for ct in product(page_id_gb, ['GB']):
    print('Retrieving for GB')
    print(f'Retrieving Ads for: {ct}')
    ads = obtain_ads_page_id(ct[0], ct[1], FIELDS, ACCESS_TOKEN)
    print('\t', len(ads), 'ads')
    all_ads.extend(ads)
    
print(f'Retrieved {len(all_ads)} ads')

# %%
def get_image_url(source):
    """
    function to extract image_url from the retreived data from Ad Library API
    Why?: the URL obtained via the endpoint is not an image_url but instead a url for a snapshot of the entire ad
    """
    pattern = r'"resized_image_url":"(?:\\.|[^"\\])*"' # find resized_image_url : <image_url>
    img_url = re.findall(pattern, str(source))[0].split('"resized_image_url":')[1].replace('\\', '').replace('"', '').replace("'", '')
    return img_url

def process_ads(ads):
    """
    processes Ads retrieved from Ads Archive (FB Ad Library)
    """
    df = pd.DataFrame(ads)    
    clean = []
    for _, row in df.iterrows():
        m = {}
        m['search_term'] = row['topic']
        m['country'] = row['country']
        m['page_id'] = row['page_id']
        m['page_name'] = row['page_name']
        
        m['ad_id'] = row['id']
        
        m['ad_creation_date'] = row['ad_creation_time']
        if m['ad_creation_date'] is np.nan:
            continue
        m['ad_creation_month'] = int(m['ad_creation_date'][5:7])
        
        
        m['delivery_start'] = row['ad_delivery_start_time']
        if m['delivery_start'] is np.nan:
            continue
            
        m['delivery_stop'] = row['ad_delivery_stop_time']
        if m['delivery_stop'] is np.nan:
            continue
        
        start = datetime.strptime(m['delivery_start'], '%Y-%m-%d')
        stop = datetime.strptime(m['delivery_stop'], '%Y-%m-%d')
        m['delivery_period'] = (stop-start).days
        
        m['ad_url'] = row['ad_snapshot_url']
        
#         try:
#             source = soup(requests.get(row['ad_snapshot_url']).content, 'html.parser')
#             m['image_url'] = get_image_url(source)
#         except:
#             m['image_url'] = np.nan # some ads are wrongly classified as having images
        
        ad_body = row['ad_creative_bodies']
        m['ad_body'] = ad_body[0] if (type(ad_body) == list) else ''
        m['uses_multi_body'] = 1 if ((type(ad_body) == list) and (len(set(ad_body)) > 1)) else 0
        
        link_capt = row['ad_creative_link_captions']
        m['link_caption'] = link_capt[0] if (type(link_capt) == list) else ''
        m['uses_multi_capt'] = 1 if ((type(link_capt) == list) and (len(set(link_capt)) > 1)) else 0
        
        link_title = row['ad_creative_link_titles']
        m['link_title'] = link_title[0] if (type(link_title) == list) else ''
        m['uses_multi_title'] = 1 if ((type(link_title) == list) and (len(set(link_title)) > 1)) else 0
        
        link_desc = row['ad_creative_link_descriptions']
        m['link_description'] = link_desc[0] if (type(link_desc) == list) else ''
        m['uses_multi_desc'] = 1 if ((type(link_desc) == list) and (len(set(link_desc)) > 1)) else 0
        
        lang = row['languages']
        m['language'] = ','.join(lang) if (type(lang) == list) else ''
        m['uses_multi_lang'] = 1 if ((type(lang) == list) and (len(set(lang)) > 1)) else 0
        
        m['funded_by'] = row['bylines'] if type(row['bylines']) == str else ''
        m['currency'] = row['currency']
        
        spend = row['spend']
        m['min_spend'] = spend.get('lower_bound', np.nan)
        m['max_spend'] = spend.get('upper_bound', np.nan)
        
        impressions = row['impressions']
        m['min_impressions'] = impressions.get('lower_bound', np.nan)
        m['max_impressions'] = impressions.get('upper_bound', np.nan)
        
        audience_size = row['estimated_audience_size']
        m['min_audience_size'] = audience_size.get('lower_bound', np.nan) if type(audience_size)==dict else np.nan
        m['max_audience_size'] = audience_size.get('upper_bound', np.nan) if type(audience_size)==dict else np.nan
        
        
        if m['max_impressions'] is np.nan or m['min_impressions'] is np.nan: 
            m['impressions'] = 0
            continue
        else:
            m['impressions'] = (int(m['max_impressions']) + int(m['min_impressions']))/2
            
        if m['max_spend'] is np.nan or m['min_spend'] is np.nan: 
            m['spend'] = 0
            continue
        else:
            m['spend'] = (int(m['max_spend']) + int(m['min_spend']))/2
        
        
        if m['max_impressions'] is np.nan or m['max_impressions'] == 0:
            m['CPM'] = 0
            continue
        else:
            m['CPM'] = int(m['max_spend']) / int(m['max_impressions']) * 1000
        
        
        if m['max_impressions'] is np.nan or m['max_impressions'] == 0:
            m['CPM2'] = 0
            continue
        else:
            m['CPM2'] = int(m['spend']) / int(m['impressions']) * 1000
        
        
        
        platforms = row['publisher_platforms']
        m['facebook'] = 1 if ((type(platforms) == list) and ('facebook' in platforms)) else 0
        m['instagram'] = 1 if ((type(platforms) == list) and ('instagram' in platforms)) else 0
        m['messenger'] = 1 if ((type(platforms) == list) and ('messenger' in platforms)) else 0
        m['audience_network'] = 1 if ((type(platforms) == list) and ('audience_network' in platforms)) else 0
        
        m['demographic_dist'] = row['demographic_distribution']
        clean.append(m)
        
    return pd.DataFrame(clean)
